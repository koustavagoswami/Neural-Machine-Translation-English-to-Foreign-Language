# %% [markdown]
# # Neural Machine Translation - Assignment 2
#
# In this task you will develop a neural machine translation (NMT) system to translate text from one language to another. For this, you wil need to chose the data to train the models, perform data processing and train a sequence2sequence neural model.

# %% [markdown]
# ## Section 1- Data Collection and Preprocessing
#
#
# ---

# %% [markdown]
# **Task 1  (5 marks)**
#
# ---
#
# There are few datasets to train an NMT system available from Tatoeba Project (http://www.manythings.org/anki/) or OPUS project (http://opus.nlpl.eu/).
#
# *  Download a langauge pair (preferably European language) and **extract** the file(s) and upload it to colab
# *  Create a list of lines by splitting the text file at every occurance of '\n'
# *  Print number of sentences
# *  Limit the amount of senteces to 10,000 lines (but more than 5,000 lines)
# *  Split the data into train and test [You can split validation set here or while training use kerase validation_split option]
# *  Print 100th sentence in original script[ not unicode] for source and target language

# %%
#This code has been written to upload the file in collab. If some one is running the code in local then no need to run this code block.
from google.colab import files
uploaded = files.upload()
from nltk.tokenize import sent_tokenize
# Out:
#      <input type="file" id="files-c0575f3c-f0c2-46d9-999e-e5553059fb3c" name="files[]" multiple disabled />
#      <output id="result-c0575f3c-f0c2-46d9-999e-e5553059fb3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
#This code has been written to read the file and then split the file to make a list of all the lines where "\n" occurs. It is giving me a list of list of
#all. Then I have flatten the list to get a single list having all the lines.
def linesSplitting(filename):
  route = []
  with open(filename, 'r') as french_file:
      lines=french_file.read().split('\n')
  #NE_flat_list = [item.strip() for sublist in route for item in sublist]
  return lines
lines = linesSplitting('fra.txt')

# %%
#To print the number of lines in the list for the lines and the 100th of the original script for source and target language
print(len(lines))
print(lines[100])
# Out:
# 160873
# Come on.	Viens !

# %%
#Here I have taken a sample of 10000 sentences from the lsi and renamed the list as sampled_list. This will be used to create the train and test dataset.
sample_list = lines[0:10000]

# %%
#To split the train and test from the sample_list
from sklearn.model_selection import train_test_split 
train,test = train_test_split(sample_list, test_size=0.20)

# %% [markdown]
# **Task 2 (5 marks)**
#
# ---
#
# * Add '\t' to denote begining of sentence and '\n'  or '<eos\>' to denote end of the sentence to the each target line.
# * Preprocess (word tokenisation, lowecasing) the text.

# %%
#This code block has been written to split the sample list in to input text and target text. The total data is needed to make the vocabulary which will be
#passed to embedding layer to get the embedding of the words. These will then use in test as well as train data to train the model and to decode the 
#test data translation
#In the target sentence I have added "start_" to indicate the starting of the sentence and "_end" to denote end of the sentence.
#I have spliited the sentence based on tab seperator.
from collections import Counter
input_texts = list()
target_texts = list()
for line in sample_list[: min(20000, len(sample_list) - 1)]:
  input_text, target_text = line.split('\t')
  target_text = 'start_ ' + target_text.lower() + ' _end'
  input_texts.append(input_text.lower())
  target_texts.append(target_text)

# %%
#This code I have written to split the train and test data seperately into traget data and input data.
#Here I have done the same thing like previous adding start and end token in the target sentence.
#The seperator here also is tab seperator.
from collections import Counter
tar_count_train = Counter()
tar_count_test = Counter()
input_texts_train = list()
target_texts_train = list()
input_texts_test = list()
target_texts_test = list()

for line in train[: min(10000, len(train) - 1)]:
  input_text_train, target_text_train = line.split('\t')
  target_text_train = 'start_ ' + target_text_train.lower() + ' _end'
  input_texts_train.append(input_text_train.lower())
  target_texts_train.append(target_text_train)
  
  
for line in test[: min(10000, len(test) - 1)]:
  input_text_test, target_text_test = line.split('\t')
  target_text_test = 'start_ ' + target_text_test.lower() + ' _end'
  input_texts_test.append(input_text_test.lower())
  target_texts_test.append(target_text_test)

# %%
#This code has been written to download the nltk dependencies which will be used further. If some is using collab then this code needs to be run.
#If some on is running the code in local machine then no need to run this if nltk is already installed.
import nltk
nltk.download('punkt')
nltk.download('all')

# %%
#In this code I have tokenized the words of input text set and target text set in target and source vocabulary. I have used the nltk word tokenizer for this.
#The source vocabulary and target vocabulary consists all the unique words that are there in the sample list.
#Also I ahve made a list where I have put the source and target text data that will be used further.
import numpy as np
Source_vocabulary=set()
source_length_list=[]
for line in input_texts:
    source_length_list.append(len(nltk.word_tokenize(line)))
    for word in nltk.word_tokenize(line):
        if word not in Source_vocabulary:
          Source_vocabulary.add(word)
    
target_vocabulary=set()
target_length_list=[]
for line in target_texts:
    target_length_list.append(len(nltk.word_tokenize(line)))
    for word in nltk.word_tokenize(line):
        if word not in target_vocabulary:
            target_vocabulary.add(word)

# %%
#Here I am taking the length of the source and target vocabulary to get the number of tokens present which will then be used in encoder and decoder
#part.
num_source_tokens = len((Source_vocabulary))
num_target_tokens = len((target_vocabulary))
#This code has been written to get the maximum sequence of the source and data set.
max_source_seq_length = np.max(source_length_list)
max_target_seq_length = np.max(target_length_list)
#I am sorting the source and target vocabulary to get the final source and target vocabulary.
Source_vocabulary = sorted(list(Source_vocabulary))
target_vocabulary = sorted(list(target_vocabulary))

# %%
#Printing all the values 
print('Number of samples:', len(input_texts))
print('Number of unique source language tokens:', num_source_tokens)
print('Number of unique target language tokens:', num_target_tokens)
print('Max sequence length of source language:', max_source_seq_length)
print('Max sequence length of target language:', max_target_seq_length)
print("Source Vocabulary",Source_vocabulary)
print("Target Vocabulary",target_vocabulary)
# Out:
# Number of samples: 9999
# Number of unique source language tokens: 2106
# Number of unique target language tokens: 4585
# Max sequence length of source language: 6
# Max sequence length of target language: 13
# Source Vocabulary ['!', '$', '%', '&', "'d", "'ll", "'m", "'re", "'s", "'ve", ',', '.', '100', '17', '19', '30', '3:30', '5', '50', '65', '8:30', '99', '?', 'a', 'abandon', 'aboard', 'about', 'above', 'absent', 'absurd', 'accept', 'ache', 'ached', 'aches', 'act', 'action', 'active', 'actor', 'acts', 'adaptable', 'addicted', 'adjust', 'admire', 'adopted', 'adorable', 'adore', 'adores', 'adult', 'adults', 'advice', 'afford', 'afraid', 'after', 'afternoon', 'again', 'against', 'age', 'agent', 'agree', 'agreed', 'agrees', 'ahead', 'ai', 'aim', 'air', 'airs', 'alert', 'alive', 'all', 'allow', 'almost', 'alone', 'along', 'already', 'alright', 'also', 'always', 'am', 'amazed', 'amazing', 'ambition', 'ambitious', 'ambush', 'american', 'amnesia', 'amuse', 'amused', 'amusing', 'an', 'and', 'angel', 'angry', 'animals', 'annoy', 'annoying', 'annoys', 'another', 'answer', 'answers', 'anxious', 'any', 'anybody', 'anyone', 'anything', 'anytime', 'anyway', 'apart', 'apologize', 'apologized', 'appeared', 'apples', 'approve', 'approves', 'arabic', 'arabs', 'are', 'argue', 'arguing', 'arm', 'armed', 'around', 'arrested', 'arrived', 'art', 'artist', 'as', 'asap', 'ashamed', 'asian', 'aside', 'ask', 'asked', 'asleep', 'assume', 'astonished', 'at', 'ate', 'atm', 'attack', 'attacked', 'attend', 'attentive', 'author', 'autumn', 'available', 'avoids', 'awake', 'away', 'awesome', 'awful', 'awkward', 'ax', 'b', 'babies', 'baby', 'bach', 'back', 'bacon', 'bad', 'baffled', 'bag', 'bags', 'baked', 'baker', 'baking', 'bald', 'ball', 'balls', 'banana', 'bananas', 'bankrupt', 'barefoot', 'bargain', 'bark', 'barked', 'bat', 'bath', 'be', 'beans', 'bear', 'beard', 'beat', 'beaten', 'beats', 'beautiful', 'beauty', 'became', 'bed', 'bedtime', 'beef', 'been', 'beer', 'bees', 'before', 'beg', 'began', 'begin', 'begun', 'behave', 'behind', 'being', 'believe', 'believed', 'bell', 'belong', 'below', 'beside', 'best', 'bet', 'betrayed', 'better', 'beware', 'beyond', 'biased', 'big', 'bigot', 'bike', 'bird', 'birds', 'birthday', 'bit', 'bite', 'bites', 'bitter', 'black', 'blame', 'blast', 'bled', 'bleeding', 'bless', 'blessed', 'blind', 'blinked', 'blood', 'blow', 'blue', 'bluffing', 'blushed', 'boat', 'boats', 'body', 'bogus', 'boil', 'bomb', 'bonus', 'book', 'books', 'bore', 'bored', 'boring', 'borrow', 'borrowed', 'boss', 'bossy', 'boston', 'both', 'bother', 'bottom', 'bottoms', 'bought', 'bounce', 'box', 'boxes', 'boy', 'boys', 'braces', 'brains', 'brand', 'brave', 'bread', 'break', 'breath', 'bribed', 'brief', 'bright', 'bring', 'british', 'broke', 'broken', 'brothers', 'brought', 'built', 'bulky', 'bullet', 'bummer', 'bunch', 'buried', 'burn', 'burned', 'bus', 'business', 'busy', 'buy', 'buying', 'by', 'ca', 'cab', 'cake', 'call', 'called', 'callous', 'calls', 'calm', 'came', 'camels', 'camera', 'can', 'canadian', 'cancel', 'canceled', 'cancer', 'candy', 'canned', 'capsized', 'captured', 'car', 'card', 'carded', 'care', 'cared', 'careful', 'carefully', 'careless', 'cares', 'carry', 'cars', 'cash', 'castles', 'cat', 'catch', 'cats', 'cattle', 'caught', 'caused', 'causes', 'caution', 'caviar', 'cd', 'cds', 'celery', 'certain', 'chair', 'chance', 'change', 'changed', 'chat', 'cheap', 'cheat', 'cheated', 'cheating', 'cheats', 'check', 'checked', 'cheer', 'cheered', 'cheers', 'chess', 'chicken', 'child', 'china', 'chinese', 'choice', 'choked', 'choose', 'christmas', 'chubby', 'chuckled', 'circle', 'cities', 'class', 'classes', 'classic', 'clean', 'cleaning', 'clear', 'clearly', 'clever', 'clock', 'clocks', 'close', 'closed', 'closely', 'cloudy', 'clue', 'clues', 'coat', 'coffee', 'coin', 'coke', 'cold', 'college', 'come', 'comedian', 'comes', 'coming', 'comment', 'complain', 'complex', 'concerned', 'confessed', 'confident', 'confused', 'congratulations', 'contact', 'contagious', 'content', 'contented', 'continue', 'contributed', 'control', 'convinced', 'cook', 'cookie', 'cookies', 'cooking', 'cooks', 'cool', 'cooperate', 'cop', 'cops', 'copy', 'correct', 'corrected', ' ...
# Target Vocabulary ['!', '$', '%', '&', '(', ')', ',', '.', '...', '100', '19', '30', '50', '8', '99', ':', '?', '_end', 'a', 'a-t-il', 'a-t-on', 'abandonna', 'abandonne', 'abandonner', 'abandonnez', 'abandonnons', 'abandonnèrent', 'abandonné', 'abeilles', 'aboient', 'aboya', 'aboyait', 'abruti', 'abrutie', 'absent', 'absurde', 'accepté', 'accident', 'accises', 'acclamèrent', 'accompagner', 'accompli', 'accord', 'accoutumé', 'accro', 'accroche-toi', 'accrochez-vous', 'acheta', 'acheter', 'achetons', 'acheté', 'achète-toi', 'acquérir', 'acteur', 'active', 'actuellement', 'admirateurs', 'admire', 'adopté', 'adorable', 'adorait', 'adore', 'adorent', 'adorerais', 'adorons', 'adoré', 'adulte', 'adultes', 'affaiblie', 'affaire', 'affaires', 'affairé', 'affairée', 'affamé', 'affamées', 'affamés', 'affolé', 'affolée', 'affreusement', 'affreux', 'affûtée', 'agace', 'agent', 'agir', 'agis', 'agissez', 'agit', 'agrandis-le', 'agrandissez-le', 'agriculteur', 'agréable', 'ah', 'ai', 'ai-je', 'aida', 'aide', 'aide-moi', 'aide-nous', 'aider', 'aiderai', 'aiderons', 'aidez', 'aidez-moi', 'aidez-nous', 'aidé', 'aille', 'ailles', 'ailleurs', 'aima', 'aimaient', 'aime', 'aiment', 'aimerais', 'aimeriez', 'aimes', 'aimions', 'aimons', 'aimé', 'aimée', 'ainsi', 'airs', 'aisé', 'ajuste', 'ajustez', 'alentour', 'alité', 'alitée', 'alitées', 'alités', 'alla', 'aller', 'allez', 'allez-vous', 'allez-y', 'allongé', 'allongée', 'allongées', 'allongés', 'allons', 'allons-nous', 'allons-nous-en', 'allons-y', 'allume', 'allumez', 'allumé', 'allumée', 'allé', 'allée', 'alors', 'ambitieuse', 'ambitieux', 'amende', 'amendé', 'amendée', 'amenez-le-moi', 'amer', 'ami', 'amical', 'amicale', 'amicales', 'amicaux', 'amies', 'amis', 'amour', 'amoureuse', 'amoureuses', 'amoureux', 'amusant', 'amusante', 'amuse-toi', 'amusez-vous', 'amusons-nous', 'amusé', 'amusée', 'amène', 'amène-le-moi', 'amène-moi', 'amère', 'américain', 'américaine', 'analphabète', 'ancien', 'andouille', 'ange', 'anglais', 'animaux', 'anniversaire', 'annuler', 'annulé', 'annulée', 'année', 'années', 'ans', 'anxieux', 'anéanti', 'anéantie', 'apeuré', 'apeurée', 'appareil', 'appartient-il', 'apparut', 'appelez', 'appelez-nous', 'appelle', 'appelle-moi', 'appelle-nous', 'appellera', 'appellerai', 'appellerons', 'appellez', 'appellez-moi', 'appelons', 'appelé', 'appelée', 'appelées', 'appelés', 'application', 'apporte', 'apporte-le', 'apporte-moi', 'apporterons', 'apportez', 'apportez-le', 'apportez-le-moi', 'apporté', 'apprends', 'approche', 'approchez', 'approuvent', 'apprécia', 'apprécie', 'apprécions', 'apprécié', 'apprêtées', 'apprêtés', 'appétit', 'après', 'arabes', 'araignées', 'arbre', 'arme', 'armé', 'armée', 'armées', 'armés', 'arnaque', 'arnaqué', 'arnaquée', 'arranger', 'arrive', 'arrivent', 'arriver', 'arrivera', 'arriverons', 'arrives-tu', 'arrives-y', 'arrivez-vous', 'arrivez-y', 'arrivé', 'arrivée', 'arrivées', 'arrivés', 'arrière', 'arrières', 'arrête', 'arrête-toi', 'arrêter', 'arrêtez', 'arrêtez-les', 'arrêtez-vous', 'arrêtions', 'arrêtons', 'arrêté', 'arrêtée', 'articulations', 'artiste', 'as', 'as-tu', 'asiatiques', 'asseoir', 'asseyez-vous', 'asseyons-nous', 'assez', 'assieds-toi', 'assis', 'assisterai', 'assisterons', 'associé', 'assure', 'assuré', 'assurée', 'assuétude', 'astucieuse', 'astucieux', 'attache', 'attachez', 'attaque', 'attaquer', 'attaquerons', 'attaquez', 'attaqué', 'attaquée', 'attardés', 'attend', 'attendez', 'attendez-nous', 'attendit', 'attendons', 'attendra', 'attendre', 'attendrons', 'attends', 'attends-nous', 'attendu', 'attendîmes', 'attentif', 'attention', 'attentive', 'attentivement', 'attirante', 'attrape', 'attrape-le', 'attrapent', 'attraper', 'attrapez', 'attrapez-le', 'attrapé', 'attrapée', 'attrapées', 'attrapés', 'attristé', 'au', 'au-dessus', 'aucun', 'aucune', 'augmentation', 'augmente-le', 'augmentez-le', 'augmenté', "aujourd'hui", 'auparavant', 'aura', 'aussi', 'auteur', 'autour', 'autre', 'aux', 'avais', 'avais-je', 'avais-tu', 'avait', 'avait ...

# %% [markdown]
# ** Task 3 (10 marks)**
#
# ---
#
# *  Assign each unique word to an integer value (5 marks).
# *  Create word embedding for your vocabulary using pretrained Glove embeddigns (5 marks) (http://nlp.stanford.edu/data/glove.6B.zip) [see Lab 7]
# * Print the first line of the embeddings (see below)

# %%
#Here I have assigned each unique character to an integer and mapped in such way that it can be treated as index.
#This has been done for both source and target vocabulary.
input_token_index = dict([(word,i) for i, word in enumerate(Source_vocabulary)])
target_token_index= dict([(word,i) for i, word in enumerate(target_vocabulary)])

# %%
#In this part I have built three matrix which are initiated with zeros.
#The input matrix has been made according to the lenth of the train data and the maximum sequence that is present in the train source and target data,
#The decoder target data is a 3 dimensional array and the other two matrices are 2 dimensional array
import numpy as np
encoder_input_data=np.zeros((len(input_texts_train),6),dtype='float32')
decoder_input_data=np.zeros((len(target_texts_train), 13),dtype='float32')
decoder_target_data=np.zeros((len(target_texts_train), 13, num_target_tokens),dtype='float32')

# %%
#This code has been written to download the glove vector from the standford side.
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2019-04-19 13:52:54--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2019-04-19 13:52:54--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  11.4MB/s    in 93s
#
# 2019-04-19 13:54:27 (8.83 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]

# %%
#This code is to unzip the glove vector data
# !unzip glove.6B.zip
# Out:
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
#Here I have made a dictionary to get the embeddings from the glove vector reading the 50 dimensional data
embeddings_index = dict()
f = open('./glove.6B.50d.txt', 'r', encoding='utf8', errors='ignore')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
#With the help of the input token index dictionary, I have extracted all the embeddings of the words from glove vector and put it into embedding matrix
embedding_matrix = np.zeros((num_source_tokens, 50))
for word,i in input_token_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
#print(#print first line of embeddings here)
print(embedding_matrix[0])
#print(target_embedding[15])
# Out:
# [-0.58402002  0.39030999  0.65281999 -0.34029999  0.19493    -0.83489001
#   0.11929    -0.57291001 -0.56844002  0.72988999 -0.56975001  0.53435999
#  -0.38034001  0.22471     0.98031002 -0.29660001  0.126       0.55221999
#  -0.62737    -0.082242   -0.085359    0.31514999  0.96077001  0.31986001
#   0.87878001 -1.51890004 -1.78310001  0.35639     0.96740001 -1.54970002
#   2.33500004  0.84939998 -1.23710001  1.06229997 -1.4267     -0.49056
#   0.85465002 -1.28779995  0.60203999 -0.35962999  0.28586    -0.052162
#  -0.50818002 -0.63459003  0.33888999  0.28415999 -0.2034     -1.23380005
#   0.46715     0.78858   ]

# %%
#In the below code I have taken the data of train input and train target data. Then put into two different set named as input text and target text.
#As I am doing based on the word prediction, I have taken the sequence of the words and put it into the input matrix with the defining time steps as well.
#In the target decoder input part the same has been done for the target data.
#Now as the last layer which will come out from the target output will be based on softmax to give the probability distibuition of the targte words,
#I have defined one hot vector in the decoder targte data matrix for the index position time steps and the words index.
#This matices will be passed into the model to train the model
for i, (input_text,target_text) in enumerate(zip(input_texts_train,target_texts_train)):
  for t, word in enumerate(nltk.word_tokenize(input_text)):
        encoder_input_data[i, t] = input_token_index[word]
  for t, word in enumerate(nltk.word_tokenize(target_text)):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t] = target_token_index[word]
        #print(decoder_input_data[i, t,target_token_index[word.lower()]])
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[word]] = 1.

# %% [markdown]
# ## Section 2 Translation Model training
#
#
#
# ---

# %% [markdown]
# **Task 3 (20 marks)**
# * Provide code for the encoder using Keras LSTM (5 marks)
# * Provide code for the decoder using Keras LSTM (5 marks)
# * Train the sequence2sequence (encoder-decoder) model (10 marks)

# %%
#Setting the hyper parameters for the model
batch_size=64
epochs= 10
latent_dim =50 # latent dimensionality of the encoding space

# %%
#In this code I have defined the encoder model. Here I have used the glove embedding for my words as weight matrix and then put it into the keras 
#embedding layer. By default keras goes to train the embedding model as well. To stop that I have freez the embedding layer making that non-trainable.
#The input length has been defined as the maximum source sequence length.
#A LSTM layer has been added in this model.
#Only the states has been kept and output has been ommitted as the states will be used in decoder.
import numpy as np
import keras, tensorflow
from keras.models import Model
from keras.layers import Input, LSTM, Dense
from keras.layers import Embedding
# encoder code goes here
encoder_inputs = Input(shape=(None,))
en_x=  Embedding(num_source_tokens,
                            50,
                            weights=[embedding_matrix],
                            input_length=max_source_seq_length,
                            trainable=False)(encoder_inputs)
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(en_x)
encoder_states = [state_h, state_c]
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# decoder code goes here
# In this code I have written the model of the decoder. The Decoder will have an input where the source data will be fitted in the training times.
#The Embedding keras inbuild layer has been used as I do not have the glove vector for the source language so I have passed through the keras in built embedding
#layer. The Layers has one LTSM layer with return state and sequence as true. Then the outputs and states has been recorded with the initial state as encoder
#hidden state as it consists of the activation of the source words. Then a dense layer has been given with the softmax which will give hte output probability
#to predict which words should be taken when we will decode the sequence.
decoder_inputs = Input(shape=(None,))

dex=  Embedding(num_target_tokens, 50) #, mask_zero=True

final_dex= dex(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)

decoder_outputs, _, _ = decoder_lstm(final_dex,
                                     initial_state=encoder_states)

decoder_dense = Dense(num_target_tokens, activation='softmax')

decoder_outputs = decoder_dense(decoder_outputs)

# %%
#Model has been made with categorical crossentropy as the loss as it is predicting like classification probability and optimizer is used rmsprop.
#The accuracy matrix has been used to check the training set and validation set accuracy.
model= Model(inputs=[encoder_inputs, decoder_inputs],outputs=decoder_outputs)
model.compile(optimizer='rmsprop',loss='categorical_crossentropy', metrics=['acc'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 6, 50)        105300      input_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, None, 50)     229250      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50), (None,  20200       embedding_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, None, 50), ( 20200       embedding_2[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 4585)   233835      lstm_2[0][0]
# ==================================================================================================
# Total params: 608,785
# Trainable params: 503,485
# Non-trainable params: 105,300
# __________________________________________________________________________________________________

# %%
#Here we are fidding the input and output of the encoder and decoder to the model and spliting the data into 5% percent for the validation.
#The epoch has been made as 50 to train the model
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=50,
          validation_split=.05)  
#model.save('seq2seq_source_target.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 7599 samples, validate on 400 samples
# Epoch 1/50
# 7599/7599 [==============================] - 7s 951us/step - loss: 2.2886 - acc: 0.0647 - val_loss: 2.0037 - val_acc: 0.0769
# Epoch 2/50
# 7599/7599 [==============================] - 5s 673us/step - loss: 1.8403 - acc: 0.0937 - val_loss: 1.8139 - val_acc: 0.1363
# Epoch 3/50
# 7599/7599 [==============================] - 5s 671us/step - loss: 1.6487 - acc: 0.1505 - val_loss: 1.6813 - val_acc: 0.1612
# Epoch 4/50
# 7599/7599 [==============================] - 5s 674us/step - loss: 1.5301 - acc: 0.1658 - val_loss: 1.5990 - val_acc: 0.1708
# Epoch 5/50
# 7599/7599 [==============================] - 5s 670us/step - loss: 1.4457 - acc: 0.1773 - val_loss: 1.5374 - val_acc: 0.1785
# Epoch 6/50
# 7599/7599 [==============================] - 5s 677us/step - loss: 1.3773 - acc: 0.1886 - val_loss: 1.4917 - val_acc: 0.1890
# Epoch 7/50
# 7599/7599 [==============================] - 5s 670us/step - loss: 1.3215 - acc: 0.1962 - val_loss: 1.4499 - val_acc: 0.1946
# Epoch 8/50
# 7599/7599 [==============================] - 5s 700us/step - loss: 1.2766 - acc: 0.2011 - val_loss: 1.4202 - val_acc: 0.1981
# Epoch 9/50
# 7599/7599 [==============================] - 5s 720us/step - loss: 1.2401 - acc: 0.2047 - val_loss: 1.3947 - val_acc: 0.2033
# Epoch 10/50
# 7599/7599 [==============================] - 5s 688us/step - loss: 1.2087 - acc: 0.2082 - val_loss: 1.3722 - val_acc: 0.2092
# Epoch 11/50
# 7599/7599 [==============================] - 5s 676us/step - loss: 1.1810 - acc: 0.2124 - val_loss: 1.3529 - val_acc: 0.2112
# Epoch 12/50
# 7599/7599 [==============================] - 5s 675us/step - loss: 1.1547 - acc: 0.2152 - val_loss: 1.3366 - val_acc: 0.2163
# Epoch 13/50
# 7599/7599 [==============================] - 5s 671us/step - loss: 1.1296 - acc: 0.2195 - val_loss: 1.3224 - val_acc: 0.2179
# Epoch 14/50
# 7599/7599 [==============================] - 5s 668us/step - loss: 1.1069 - acc: 0.2231 - val_loss: 1.3034 - val_acc: 0.2250
# Epoch 15/50
# 7599/7599 [==============================] - 5s 668us/step - loss: 1.0852 - acc: 0.2273 - val_loss: 1.2884 - val_acc: 0.2246
# Epoch 16/50
# 7599/7599 [==============================] - 5s 671us/step - loss: 1.0663 - acc: 0.2292 - val_loss: 1.2766 - val_acc: 0.2283
# Epoch 17/50
# 7599/7599 [==============================] - 5s 670us/step - loss: 1.0487 - acc: 0.2319 - val_loss: 1.2684 - val_acc: 0.2281
# Epoch 18/50
# 7599/7599 [==============================] - 5s 669us/step - loss: 1.0326 - acc: 0.2342 - val_loss: 1.2562 - val_acc: 0.2312
# Epoch 19/50
# 7599/7599 [==============================] - 5s 666us/step - loss: 1.0179 - acc: 0.2356 - val_loss: 1.2464 - val_acc: 0.2287
# Epoch 20/50
# 7599/7599 [==============================] - 5s 668us/step - loss: 1.0038 - acc: 0.2378 - val_loss: 1.2463 - val_acc: 0.2317
# Epoch 21/50
# 7599/7599 [==============================] - 5s 669us/step - loss: 0.9902 - acc: 0.2392 - val_loss: 1.2356 - val_acc: 0.2304
# Epoch 22/50
# 7599/7599 [==============================] - 5s 667us/step - loss: 0.9776 - acc: 0.2408 - val_loss: 1.2274 - val_acc: 0.2327
# Epoch 23/50
# 7599/7599 [==============================] - 5s 661us/step - loss: 0.9648 - acc: 0.2419 - val_loss: 1.2254 - val_acc: 0.2317
# Epoch 24/50
# 7599/7599 [==============================] - 5s 715us/step - loss: 0.9528 - acc: 0.2432 - val_loss: 1.2172 - val_acc: 0.2342
# Epoch 25/50
# 7599/7599 [==============================] - 5s 715us/step - loss: 0.9414 - acc: 0.2440 - val_loss: 1.2128 - val_acc: 0.2335
# Epoch 26/50
# 7599/7599 [==============================] - 5s 661us/step - loss: 0.9304 - acc: 0.2460 - val_loss: 1.2072 - val_acc: 0.2331
# Epoch 27/50
# 7599/7599 [==============================] - 5s 671us/step - loss: 0.9190 - acc: 0.2464 - val_loss: 1.2001 - val_acc: 0.2367
# Epoch 28/50
# 7599/7599 [==============================] - 5s 663us/step - loss: 0.9082 - acc: 0.2479 - val_loss: 1.1987 - val_acc: 0.2346
# Epoch 29/50
# 7599/7599 [==============================] - 5s 666us/step - loss: 0.8979 - acc: 0.2490 - val_loss: 1.1919 - val_acc: 0.2340
# Epoch 30/50
# 7599/7599 [==============================] - 5s 662us/step - loss: 0.8877 - acc: 0.2508 - val_loss: 1.1910 - val_acc: 0.2362
# Epoch 31/50
# 7599/7599 [==============================] - 5s 668us/step - loss: 0.8781 - acc: 0.2517 - val_loss: 1.1807 - val_acc: 0.2358
# Epoch 32/50
# 7599/7599 [==============================] - 5s 664us/step - loss: 0.8677 - acc: 0.2524 - val_loss: 1.1790 - val_acc: 0.2342
# Epoch 33/50
# 7599/7599 [==============================] - 5s 666us/step - loss: 0.8582 - acc: 0.2536 - val_loss: 1.1722 - val_acc: 0.2387
# Epoch 34/50
# 7599/7599 [==============================] - 5s 661us/step - loss: 0.8495 - acc: 0.2537 - val_loss: 1.1726 - val_acc: 0.2371
# Epoch 35/50
# 7599/7599 [==============================] - 5s 660us/step - loss: 0.8406 - acc: 0.2555 - val_loss: 1.1681 - val_acc: 0.2379
# Epoch 36/50
# 7599/7599 [==============================] - 5s 663us/step - loss: 0.8316 - acc: 0.2558 - val_loss: 1.1615 - val_acc: 0.2373
# Epoch 37/50
# 7599/7599 [==============================] - 5s 666us/step - loss: 0.8237 - acc: 0.2575 - val_loss: 1.1623 - val_acc: 0.2385
# Epoch 38/50
# 7599/7599 [==============================] - 5s 657us/step - loss: 0.8148 - acc: 0.2581 - val_loss: 1.1586 - val_acc: 0.2381
# Epoch 39/50
# 7599/7599 [==============================] - 5s 668us/step - loss: 0.8064 - acc: 0.2591 - val_loss: 1.1527 - val_acc: 0.2387
# Epoch 40/50
# 7599/7599 [==============================] - 5s 710us/step - loss: 0.7983 - acc: 0.2600 - val_loss: 1.1535 - val_acc: 0.2377
# Epoch 41/50
# 7599/7599 [==============================] - 5s 700us/step - loss: 0.7920 - acc: 0.2604 - val_loss: 1.1517 - val_acc: 0.2383
# Epoch 42/50
# 7599/7599 [==============================] - 5s 691us/step - loss: 0.7863 - acc: 0.2605 - val_loss: 1.1505 - val_acc: 0.2390
# Epoch 43/50
# 7599/7599 [==============================] - 5s 690us/step - loss: 0.7805 - acc: 0.2616 - val_loss: 1.1506 - val_acc: 0.2377
# Epoch 44/50
# 7599/7599 [==============================] - 5s 683us/step - loss: 0.7750 - acc: 0.2626 - val_loss: 1.1478 - val_acc: 0.2388
# Epoch 45/50
# 7599/7599 [==============================] - 5s 662us/step - loss: 0.7697 - acc: 0.2627 - val_loss: 1.1506 - val_acc: 0.2363
# Epoch 46/50
# 7599/7599 [==============================] - 5s 659us/step - loss: 0.7645 - acc: 0.2634 - val_loss: 1.1562 - val_acc: 0.2365
# Epoch 47/50
# 7599/7599 [==============================] - 5s 663us/step - loss: 0.7589 - acc: 0.2643 - val_loss: 1.1526 - val_acc: 0.2369
# Epoch 48/50
# 7599/7599 [==============================] - 5s 663us/step - loss: 0.7544 - acc: 0.2649 - val_loss: 1.1504 - val_acc: 0.2392
# Epoch 49/50
# 7599/7599 [==============================] - 5s 660us/step - loss: 0.7484 - acc: 0.2654 - val_loss: 1.1533 - val_acc: 0.2367
# Epoch 50/50
# 7599/7599 [==============================] - 5s 663us/step - loss: 0.7419 - acc: 0.2665 - val_loss: 1.1547 - val_acc: 0.2387

# %% [markdown]
# # Section 3 Testing
#
#
# ---
#
#
# ** Task 4 (20 marks) **
#
#
# ---
#
#
#
# *   Use the trained model to translate the text from source into target language (10 marks). Use the test/evaluation set (see Section 1) and perform an automatic evaluation with the BLEU metric (10 marks). use the NLTK library to calculate BLEU.

# %%
#Your code goes here
#In this code I have made the dummy model with the encoder input and encoder states. This model will be used to predict the target sentence
encoder_model = Model(encoder_inputs, encoder_states)
encoder_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None)              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 6, 50)             105300
# _________________________________________________________________
# lstm_1 (LSTM)                [(None, 50), (None, 50),  20200
# =================================================================
# Total params: 125,500
# Trainable params: 20,200
# Non-trainable params: 105,300
# _________________________________________________________________

# %%
#Here a dummy same model has been made with the decoder input shape and different states.
#A LSTM layer as been added in the decoder model. The output has been made with the help of LSTM. Then the model has been build with the states and the inputs.
#Lastly I have reversed the dictionary of the input token index and the target token index as depending on the sequence the words will be predicted
#with the help of this token index matrix. So the sequence will be key and the words will be value.
decoder_state_input_h = Input(shape=(50,))
decoder_state_input_c = Input(shape=(50,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

final_dex2= dex(decoder_inputs)

decoder_outputs2, state_h2, state_c2 = decoder_lstm(final_dex2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs2] + decoder_states2)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
#This code has been built to write the decode sequence model where input will be given of the test data set sequence and based on the enoder model it will
#preduct the input sequence word. The target first character has been hardcoded with start to define the start of the sentence and then with the help of 
#decoder model the output word and states will be predicted. The condition will run it will reach  the maximum sequence or the end of sentence token.
#The word prediction will be taken based on the argmax as softmax is giving probability distirbution of the target words.
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0] = target_token_index['start_']

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += ' '+sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '_end' or
           len(decoded_sentence) > max_target_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
#This part is just to test whether decoder code is working or not with train data
for seq_index in range(10):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts_train[seq_index: seq_index + 1])
    print('Decoded sentence:', decoded_sentence)
    print('Original Sentence',target_texts_train[seq_index: seq_index + 1])

# %% [markdown]
# **Test Data Building and Test**

# %%
#Here I have build a zero matrix for the test dataset exactly same like training dataset
encoder_input_data_test=np.zeros((len(input_texts_test),6),dtype='float32')

# %%
#The matrix is populated with the seqeunce of the words from input token index which will be used latter to predict the next target sentence
for i, (input_text,target_text) in enumerate(zip(input_texts_test,target_texts_test)):
  for t, word in enumerate(nltk.word_tokenize(input_text)):
        encoder_input_data_test[i, t] = input_token_index[word]

# %%
#Here I am calling the decode function for the entire test set and giving the input the sequence of the words for test set.
#The model is giving the decoded output sequence from the same.
#I have used the NLTK library for the copus blue score calculation as a whole to be calucalted. This score is cumulative score.
#Cumulative scores refer to the calculation of individual n-gram scores at all orders from 1 to n and weighting them by calculating the weighted geometric mean.
#The weights for the BLEU-4 are 1/4 (25%) or 0.25 for each of the 1-gram, 2-gram, 3-gram and 4-gram scores
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.bleu_score import sentence_bleu
actual, predicted, ss = list(), list(),list()
for seq_index in range(len(encoder_input_data_test)):
    input_seq = encoder_input_data_test[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts_test[seq_index: seq_index + 1])
    print('Decoded sentence:', decoded_sentence)
    decoded_sentence = 'start_ '+decoded_sentence+' _end'
    print('Original Sentence',target_texts_test[seq_index: seq_index + 1])
    #str(l)[1:-1]
    actual.append([nltk.word_tokenize(str(target_texts_test[seq_index: seq_index + 1])[1:-1])])
    predicted.append(nltk.word_tokenize(str(decoded_sentence)))
    # calculate BLEU score
print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))
# Out:
# -
# Input sentence: ['we did it.']
# Decoded sentence:  nous avons besoin
# Original Sentence ['start_ nous avons réussi\u202f! _end']
# -
# Input sentence: ['did someone die?']
# Decoded sentence:  qui a fait mal
# Original Sentence ["start_ quelqu'un est-il mort ? _end"]
# -
# Input sentence: ['you scare me.']
# Decoded sentence:  vous me prie .
# Original Sentence ['start_ tu me fais peur. _end']
# -
# Input sentence: ["i'm exhausted."]
# Decoded sentence:  je suis crevé
# Original Sentence ['start_ je suis vannée. _end']
# -
# Input sentence: ["i didn't do it."]
# Decoded sentence:  je ne suis pas
# Original Sentence ["start_ je ne l'ai pas fait. _end"]
# -
# Input sentence: ['i was sober.']
# Decoded sentence:  j'étais en train
# Original Sentence ["start_ j'étais sobre. _end"]
# -
# Input sentence: ['are you bald?']
# Decoded sentence:  êtes-vous énervé
# Original Sentence ['start_ êtes-vous chauve ? _end']
# -
# Input sentence: ['we kept quiet.']
# Decoded sentence:  nous avons perdu
# Original Sentence ['start_ nous restâmes silencieux. _end']
# -
# Input sentence: ['i want to quit.']
# Decoded sentence:  je veux la maison
# Original Sentence ['start_ je veux laisser tomber. _end']
# -
# Input sentence: ['are those yours?']
# Decoded sentence:  êtes-vous sont
# Original Sentence ['start_ est-ce les tiennes ? _end']
# -
# Input sentence: ["i'm rational."]
# Decoded sentence:  je suis célibataire
# Original Sentence ['start_ je suis rationnelle. _end']
# -
# Input sentence: ["i'm not strong."]
# Decoded sentence:  je ne suis pas
# Original Sentence ['start_ je ne suis pas fort. _end']
# -
# Input sentence: ["how's your job?"]
# Decoded sentence:  c'est tom ? _end
# Original Sentence ['start_ comment va ton boulot\u202f? _end']
# -
# Input sentence: ['i know that.']
# Decoded sentence:  je le peux . _end
# Original Sentence ['start_ je le sais. _end']
# -
# Input sentence: ["that's cool."]
# Decoded sentence:  c'est de nouveau
# Original Sentence ["start_ c'est super. _end"]
# -
# Input sentence: ['you did that.']
# Decoded sentence:  tu peux ça . _end
# Original Sentence ['start_ vous avez fait cela. _end']
# -
# Input sentence: ['i know her.']
# Decoded sentence:  je me sens bien
# Original Sentence ['start_ je la connais. _end']
# -
# Input sentence: ['be content.']
# Decoded sentence:  soyez prudent
# Original Sentence ['start_ soyez satisfaite ! _end']
# -
# Input sentence: ["that's enough."]
# Decoded sentence:  c'est juste .
# Original Sentence ['start_ ça suffit. _end']
# -
# Input sentence: ['he has no money.']
# Decoded sentence:  il a fait de fait
# Original Sentence ["start_ il n'a pas d'argent. _end"]
# -
# Input sentence: ['be careful.']
# Decoded sentence:  soyez prudent
# Original Sentence ['start_ soyez prudentes ! _end']
# -
# Input sentence: ['just say no.']
# Decoded sentence:  ne le n'est pas
# Original Sentence ['start_ dites simplement non ! _end']
# -
# Input sentence: ['shut your eyes.']
# Decoded sentence:  restez tranquille
# Original Sentence ['start_ ferme les yeux. _end']
# -
# Input sentence: ['come over!']
# Decoded sentence:  viens ! _end
# Original Sentence ['start_ venez\u202f! _end']
# -
# Input sentence: ['i love my home.']
# Decoded sentence:  j'adore mon boulot
# Original Sentence ["start_ j'adore mon foyer. _end"]
# -
# Input sentence: ["he's helping me."]
# Decoded sentence:  il est là . _end
# Original Sentence ["start_ il m'aide. _end"]
# -
# Input sentence: ['i found it.']
# Decoded sentence:  je l'ai fait de
# Original Sentence ["start_ je l'ai trouvé. _end"]
# -
# Input sentence: ["i'll scold him."]
# Decoded sentence:  je serai en train
# Original Sentence ['start_ je le gronderai. _end']
# -
# Input sentence: ['do you trust me?']
# Decoded sentence:  est-ce que tu
# Original Sentence ['start_ te fies-tu à moi ? _end']
# -
# Input sentence: ["you're precise."]
# Decoded sentence:  tu es . _end
# Original Sentence ['start_ vous êtes précis. _end']
# -
# Input sentence: ['this is a dvd.']
# Decoded sentence:  c'est un livre
# Original Sentence ["start_ c'est un dvd. _end"]
# -
# Input sentence: ["they're back."]
# Decoded sentence:  ils sont en train
# Original Sentence ['start_ elles sont de retour. _end']
# -
# Input sentence: ['what a shame!']
# Decoded sentence:  quelle voilà !
# Original Sentence ['start_ dommage\u202f! _end']
# -
# Input sentence: ['be ruthless.']
# Decoded sentence:  soyez prudent
# Original Sentence ['start_ sois impitoyable ! _end']
# -
# Input sentence: ["don't be scared."]
# Decoded sentence:  ne sois pas naïve
# Original Sentence ["start_ n'ayez pas peur. _end"]
# -
# Input sentence: ['tom is dying.']
# Decoded sentence:  tom est en train
# Original Sentence ['start_ thomas est mourant. _end']
# -
# Input sentence: ['who are they?']
# Decoded sentence:  qui est ? _end
# Original Sentence ['start_ qui sont-ils\u202f? _end']
# -
# Input sentence: ["it's bulky."]
# Decoded sentence:  c'est devenu elle
# Original Sentence ["start_ c'est encombrant. _end"]
# -
# Input sentence: ["i'm retired."]
# Decoded sentence:  je suis en train
# Original Sentence ['start_ je suis pensionné. _end']
# -
# Input sentence: ['is it raining?']
# Decoded sentence:  est-ce que ça
# Original Sentence ['start_ pleut-il ? _end']
# -
# Input sentence: ["you're sneaky."]
# Decoded sentence:  vous êtes sournois
# Original Sentence ['start_ vous êtes sournoises. _end']
# -
# Input sentence: ['i feel so cold.']
# Decoded sentence:  je me sens mal
# Original Sentence ["start_ j'ai tellement froid. _end"]
# -
# Input sentence: ["we'll starve."]
# Decoded sentence:  nous nous sommes
# Original Sentence ['start_ nous mourrons de faim. _end']
# -
# Input sentence: ['come to us.']
# Decoded sentence:  venez ! _end
# Original Sentence ['start_ venez à nous. _end']
# -
# Input sentence: ['let me help.']
# Decoded sentence:  laissez-moi partir
# Original Sentence ["start_ laisse-moi t'aider ! _end"]
# -
# Input sentence: ['are you envious?']
# Decoded sentence:  êtes-vous énervé
# Original Sentence ['start_ es-tu envieux ? _end']
# -
# Input sentence: ['oh please!']
# Decoded sentence:  je vous prie !
# Original Sentence ["start_ je t'en prie ! _end"]
# -
# Input sentence: ['he walked away.']
# Decoded sentence:  il a eu de fait
# Original Sentence ["start_ il s'en alla. _end"]
# -
# Input sentence: ['drive on.']
# Decoded sentence:  ! _end
# Original Sentence ['start_ continue à rouler ! _end']
# -
# Input sentence: ['i need some.']
# Decoded sentence:  j'ai besoin de
# Original Sentence ["start_ j'en ai besoin. _end"]
# -
# Input sentence: ["she's adorable."]
# Decoded sentence:  elle est en train
# Original Sentence ['start_ elle est adorable. _end']
# -
# Input sentence: ['i will obey.']
# Decoded sentence:  je veux de le
# Original Sentence ["start_ j'obéirai. _end"]
# -
# Input sentence: ['who did this?']
# Decoded sentence:  qui l'a fait ?
# Original Sentence ['start_ qui a fait ça ? _end']
# -
# Input sentence: ['we must go.']
# Decoded sentence:  nous nous faut
# Original Sentence ['start_ nous devons y aller. _end']
# -
# Input sentence: ["you're so mean."]
# Decoded sentence:  vous êtes si en
# Original Sentence ['start_ vous êtes si méchants. _end']
# -
# Input sentence: ['have a nice day.']
# Decoded sentence:  bonne bonne journée
# Original Sentence ['start_ je vous souhaite le bonjour\u202f! _end']
# -
# Input sentence: ["tom's left."]
# Decoded sentence:  tom est mort .
# Original Sentence ['start_ tom partit. _end']
# -
# Input sentence: ["i'm doing fine."]
# Decoded sentence:  je suis en train
# Original Sentence ['start_ je vais bien. _end']
# -
# Input sentence: ['she came alone.']
# Decoded sentence:  elle a aimé ça
# Original Sentence ['start_ elle est venue seule. _end']
# -
# Input sentence: ['give me the key.']
# Decoded sentence:  ne peux pas !
# Original Sentence ['start_ donnez-moi la clé. _end']
# -
# Input sentence: ["don't leave."]
# Decoded sentence:  ne me suis pas
# Original Sentence ['start_ ne partez pas ! _end']
# -
# Input sentence: ['i outrank you.']
# Decoded sentence:  je vous ai sauvé
# Original Sentence ['start_ je passe avant toi. _end']
# -
# Input sentence: ['i feel lost.']
# Decoded sentence:  je me sens mal
# Original Sentence ['start_ je me sens perdue. _end']
# -
# Input sentence: ['tom knows that.']
# Decoded sentence:  tom fait confiance
# Original Sentence ['start_ tom sait ça. _end']
# -
# Input sentence: ['he stood up.']
# Decoded sentence:  il a eu de fait
# Original Sentence ['start_ il se mit debout. _end']
# -
# Input sentence: ['i asked tom.']
# Decoded sentence:  j'ai dit tom .
# Original Sentence ["start_ j'ai demandé à tom. _end"]
# -
# Input sentence: ['look up there.']
# Decoded sentence:  regarde avec moi
# Original Sentence ['start_ regardez là-haut. _end']
# -
# Input sentence: ['are you sure?']
# Decoded sentence:  êtes-vous sûr
# Original Sentence ['start_ êtes-vous sûrs\u202f? _end']
# -
# Input sentence: ["i'm very tired."]
# Decoded sentence:  je suis très trop
# Original Sentence ['start_ je suis fourbu. _end']
# -
# Input sentence: ['he is not in.']
# Decoded sentence:  il n'est pas à
# Original Sentence ["start_ il n'est pas chez lui. _end"]
# -
# Input sentence: ['make me happy.']
# Decoded sentence:  sois avec moi
# Original Sentence ['start_ rends-moi heureux. _end']
# -
# Input sentence: ['he surrendered.']
# Decoded sentence:  il a été largué
# Original Sentence ["start_ il s'est rendu. _end"]
# -
# Input sentence: ['forget it!']
# Decoded sentence:  ça ! _end
# Original Sentence ['start_ oublie ! _end']
# -
# Input sentence: ["i'm speechless."]
# Decoded sentence:  je suis réveillé
# Original Sentence ['start_ je ne trouve pas les mots. _end']
# -
# Input sentence: ['i am off today.']
# Decoded sentence:  je suis juste
# Original Sentence ["start_ je ne suis pas en service, aujourd'hui. _end"]
# -
# Input sentence: ["we're safe now."]
# Decoded sentence:  nous sommes en
# Original Sentence ['start_ nous sommes désormais en sécurité. _end']
# -
# Input sentence: ['they crashed.']
# Decoded sentence:  ils ont été eu
# Original Sentence ['start_ elles se sont écrasées. _end']
# -
# Input sentence: ['i had no idea.']
# Decoded sentence:  je ne ai vu pas
# Original Sentence ["start_ je n'en avais aucune idée. _end"]
# -
# Input sentence: ['he has guts.']
# Decoded sentence:  il a eu de fait
# Original Sentence ['start_ il a des tripes. _end']
# -
# Input sentence: ['take mine.']
# Decoded sentence:  prenez la mienne
# Original Sentence ['start_ prends le mien. _end']
# -
# Input sentence: ['i need a pen.']
# Decoded sentence:  je veux une il
# Original Sentence ["start_ j'ai besoin d'un stylo. _end"]
# -
# Input sentence: ['i want to go.']
# Decoded sentence:  je veux y aller
# Original Sentence ["start_ je veux m'en aller. _end"]
# -
# Input sentence: ['did she like it?']
# Decoded sentence:  est-ce que tom
# Original Sentence ['start_ elle a aimé ? _end']
# -
# Input sentence: ['stop crying.']
# Decoded sentence:  arrête de hurler
# Original Sentence ['start_ arrêtez de pleurer ! _end']
# -
# Input sentence: ['fix this.']
# Decoded sentence:  ? _end
# Original Sentence ['start_ réparez ceci. _end']
# -
# Input sentence: ["we're too weak."]
# Decoded sentence:  nous sommes trop
# Original Sentence ['start_ nous sommes trop faibles. _end']
# -
# Input sentence: ["i'm not skinny."]
# Decoded sentence:  je ne suis pas
# Original Sentence ['start_ je ne suis pas maigrichonne. _end']
# -
# Input sentence: ['i bike to work.']
# Decoded sentence:  j'ai besoin de
# Original Sentence ['start_ je vais au travail à bicyclette. _end']
# -
# Input sentence: ['let me talk.']
# Decoded sentence:  laissez-moi parler
# Original Sentence ['start_ laisse-moi parler. _end']
# -
# Input sentence: ['what is that?']
# Decoded sentence:  qu'est-ce que
# Original Sentence ["start_ qu'est-ce que c'est que ça ? _end"]
# -
# Input sentence: ['you seem busy.']
# Decoded sentence:  tu as l'air en
# Original Sentence ['start_ vous semblez occupés. _end']
# -
# Input sentence: ['please leave.']
# Decoded sentence:  veuillez vous
# Original Sentence ['start_ je vous prie de partir. _end']
# -
# Input sentence: ['welcome back.']
# Decoded sentence:  arrête de la nous
# Original Sentence ['start_ sois de nouveau le bienvenu ! _end']
# -
# Input sentence: ["i'll get these."]
# Decoded sentence:  je vais bien en
# Original Sentence ["start_ j'irai chercher ceux-ci. _end"]
# -
# Input sentence: ['make it larger.']
# Decoded sentence:  ça . _end
# Original Sentence ['start_ élargis-le. _end']
# -
# Input sentence: ["isn't it black?"]
# Decoded sentence:  est-ce que ça
# Original Sentence ["start_ n'est-ce pas noir ? _end"]
# -
# Input sentence: ['let me explain.']
# Decoded sentence:  laissez-moi partir
# Original Sentence ['start_ laisse-moi expliquer. _end']
# -
# Input sentence: ['keep tom safe.']
# Decoded sentence:  tom a du arme
# Original Sentence ['start_ protège tom. _end']
# -
# Input sentence: ["it's no secret."]
# Decoded sentence:  c'est pas un blague
# Original Sentence ["start_ ce n'est pas un secret. _end"]
# -
# Input sentence: ["you're boring."]
# Decoded sentence:  vous êtes êtes
# Original Sentence ["start_ vous m'ennuyez. _end"]
# -
# Input sentence: ["he's not ready."]
# Decoded sentence:  il n'est pas en
# Original Sentence ["start_ il n'est pas prêt. _end"]
# -
# Input sentence: ['she dumped me.']
# Decoded sentence:  elle me suis senti
# Original Sentence ["start_ elle m'a laissé tomber. _end"]
# -
# Input sentence: ["we'll rebuild."]
# Decoded sentence:  nous nous sommes
# Original Sentence ['start_ nous reconstruirons. _end']
# -
# Input sentence: ["it's very dry."]
# Decoded sentence:  il est trop trop
# Original Sentence ['start_ il fait très sec. _end']
# -
# Input sentence: ['loosen up.']
# Decoded sentence:  ! _end
# Original Sentence ['start_ laissez-vous aller ! _end']
# -
# Input sentence: ['i am so sick.']
# Decoded sentence:  je suis très de
# Original Sentence ["start_ c'est moi qui suis si malade. _end"]
# -
# Input sentence: ["it's 50 yen."]
# Decoded sentence:  c'est . _end
# Original Sentence ["start_ c'est 50 yen. _end"]
# -
# Input sentence: ["you're cruel."]
# Decoded sentence:  tu es naïf . _end
# Original Sentence ['start_ vous êtes cruel. _end']
# -
# Input sentence: ["don't push it."]
# Decoded sentence:  ne le fais pas
# Original Sentence ['start_ ne le pousse pas ! _end']
# -
# Input sentence: ['he likes jelly.']
# Decoded sentence:  il adore les chiens
# Original Sentence ['start_ il aime la gelée. _end']
# -
# Input sentence: ['i freaked out.']
# Decoded sentence:  j'ai été mis de
# Original Sentence ["start_ j'ai eu les foies. _end"]
# -
# Input sentence: ['we need to go.']
# Decoded sentence:  nous nous faut
# Original Sentence ['start_ nous devons partir. _end']
# -
# Input sentence: ['come and see me.']
# Decoded sentence:  venez vous te
# Original Sentence ['start_ viens me voir. _end']
# -
# Input sentence: ['i was wrong.']
# Decoded sentence:  j'étais en train
# Original Sentence ["start_ j'ai eu tort. _end"]
# -
# Input sentence: ['do your best!']
# Decoded sentence:  fais comme c'est
# Original Sentence ['start_ fais de ton mieux\u202f! _end']
# -
# Input sentence: ["i'll be fine."]
# Decoded sentence:  je peux le faire
# Original Sentence ['start_ ça va aller. _end']
# -
# Input sentence: ['tom is packing.']
# Decoded sentence:  tom est triste
# Original Sentence ['start_ tom fait ses valises. _end']
# -
# Input sentence: ['are you kidding?']
# Decoded sentence:  êtes-vous sûr
# Original Sentence ['start_ tu plaisantes ? _end']
# -
# Input sentence: ["don't do this."]
# Decoded sentence:  ne le nous pas
# Original Sentence ['start_ ne faites pas ça ! _end']
# -
# Input sentence: ["it's poison."]
# Decoded sentence:  c'est une voiture
# Original Sentence ["start_ c'est du poison. _end"]
# -
# Input sentence: ["i'm dieting."]
# Decoded sentence:  je suis très en
# Original Sentence ['start_ je suis au régime. _end']
# -
# Input sentence: ["that's lame."]
# Decoded sentence:  c'est elle . _end
# Original Sentence ["start_ c'est minable. _end"]
# -
# Input sentence: ['go home.']
# Decoded sentence:  à la maison .
# Original Sentence ['start_ rentrez chez vous. _end']
# -
# Input sentence: ["i'll sue you."]
# Decoded sentence:  je vous ai sauvé
# Original Sentence ['start_ je vous ferai un procès. _end']
# -
# Input sentence: ["he's a bit shy."]
# Decoded sentence:  il est en lit
# Original Sentence ['start_ il est quelque peu timide. _end']
# -
# Input sentence: ['he could do it.']
# Decoded sentence:  il a fait ça .
# Original Sentence ['start_ lui pourrait le faire. _end']
# -
# Input sentence: ['do you know him?']
# Decoded sentence:  tu me suis ? _end
# Original Sentence ['start_ vous le connaissez\u202f? _end']
# -
# Input sentence: ["i can't swim."]
# Decoded sentence:  je ne sens pas
# Original Sentence ['start_ je ne sais pas nager. _end']
# -
# Input sentence: ["i'll live."]
# Decoded sentence:  je vais des chiens
# Original Sentence ['start_ je vivrai. _end']
# -
# Input sentence: ['is there more?']
# Decoded sentence:  est-ce que j'étais
# Original Sentence ['start_ y a-t-il plus\xa0? _end']
# -
# Input sentence: ['come off it!']
# Decoded sentence:  arrête de ça !
# Original Sentence ['start_ laisse tomber ! _end']
# -
# Input sentence: ['wash up.']
# Decoded sentence:  . _end
# Original Sentence ['start_ lavez-vous ! _end']
# -
# Input sentence: ['get a life!']
# Decoded sentence:  fais un peu prudente
# Original Sentence ['start_ achète-toi une vie ! _end']
# -
# Input sentence: ['i need to go.']
# Decoded sentence:  il me faut partir
# Original Sentence ["start_ je dois m'en aller. _end"]
# -
# Input sentence: ["it's very cold."]
# Decoded sentence:  c'est trop de
# Original Sentence ['start_ il fait très froid. _end']
# -
# Input sentence: ['i was at home.']
# Decoded sentence:  j'ai été écrit
# Original Sentence ["start_ j'étais à l'appartement. _end"]
# -
# Input sentence: ['girls are crazy.']
# Decoded sentence:  les filles sont
# Original Sentence ['start_ les filles sont folles. _end']
# -
# Input sentence: ['i helped out.']
# Decoded sentence:  j'ai besoin de
# Original Sentence ["start_ j'ai donné un coup de main. _end"]
# -
# Input sentence: ["we're not safe."]
# Decoded sentence:  nous ne sommes
# Original Sentence ['start_ nous ne sommes pas en sécurité. _end']
# -
# Input sentence: ['this is easy.']
# Decoded sentence:  c'est le livre
# Original Sentence ["start_ c'est simple. _end"]
# -
# Input sentence: ["don't leave!"]
# Decoded sentence:  ne me suis pas
# Original Sentence ["start_ ne t'en va pas\u202f! _end"]
# -
# Input sentence: ['sweet dreams!']
# Decoded sentence:  bien ! _end
# Original Sentence ['start_ faites de beaux rêves\u202f! _end']
# -
# Input sentence: ["i didn't vote."]
# Decoded sentence:  je n'ai pas fait
# Original Sentence ["start_ je n'ai pas voté. _end"]
# -
# Input sentence: ['she is strong.']
# Decoded sentence:  elle est naïf
# Original Sentence ['start_ elle est forte. _end']
# -
# Input sentence: ['who is he?']
# Decoded sentence:  qui a été sécurité
# Original Sentence ['start_ qui est-il\u202f? _end']
# -
# Input sentence: ["you're young."]
# Decoded sentence:  vous êtes en train
# Original Sentence ['start_ vous êtes jeunes. _end']
# -
# Input sentence: ['come back later.']
# Decoded sentence:  venez à la maison
# Original Sentence ['start_ reviens plus tard. _end']
# -
# Input sentence: ['i love winter.']
# Decoded sentence:  j'adore les chiens
# Original Sentence ["start_ j'adore l'hiver. _end"]
# -
# Input sentence: ['he studied hard.']
# Decoded sentence:  il a perdu . _end
# Original Sentence ['start_ il étudia avec application. _end']
# -
# Input sentence: ['are you happy?']
# Decoded sentence:  êtes-vous sûr
# Original Sentence ['start_ êtes-vous heureux\u202f? _end']
# -
# Input sentence: ['did you vote?']
# Decoded sentence:  est-ce que tom
# Original Sentence ['start_ as-tu voté ? _end']
# -
# Input sentence: ['it amazed me.']
# Decoded sentence:  ça m'a monde m'a
# Original Sentence ["start_ ça m'a épaté. _end"]
# -
# Input sentence: ["i'm contagious."]
# Decoded sentence:  je suis paresseux
# Original Sentence ['start_ je suis contagieux. _end']
# -
# Input sentence: ['you may swim.']
# Decoded sentence:  tu as l'air en
# Original Sentence ['start_ tu as la permission de nager. _end']
# -
# Input sentence: ['quiet, please.']
# Decoded sentence:  à la maison .
# Original Sentence ["start_ silence, s'il vous plaît ! _end"]
# -
# Input sentence: ['please help me.']
# Decoded sentence:  s'il vous plaît
# Original Sentence ["start_ je te prie de m'aider. _end"]
# -
# Input sentence: ['who plays golf?']
# Decoded sentence:  qui a gagné ?
# Original Sentence ['start_ qui joue au golf ? _end']
# -
# Input sentence: ['of course.']
# Decoded sentence:  la vie est ! _end
# Original Sentence ['start_ bien sûr. _end']
# -
# Input sentence: ['tom fired mary.']
# Decoded sentence:  tom a été mis
# Original Sentence ['start_ tom a renvoyé mary. _end']
# -
# Input sentence: ['i am very tall.']
# Decoded sentence:  je suis très en
# Original Sentence ['start_ je suis très grand. _end']
# -
# Input sentence: ["he's a bigot."]
# Decoded sentence:  c'est un veux
# Original Sentence ["start_ c'est un sectaire. _end"]
# -
# Input sentence: ['i made a list.']
# Decoded sentence:  j'ai un chien
# Original Sentence ["start_ j'ai fait une liste. _end"]
# -
# Input sentence: ['be respectful.']
# Decoded sentence:  soyez prudent
# Original Sentence ['start_ sois respectueux ! _end']
# -
# Input sentence: ["don't be upset."]
# Decoded sentence:  ne soyez pas désolé
# Original Sentence ['start_ ne soyez pas fâchée ! _end']
# -
# Input sentence: ['he was alone.']
# Decoded sentence:  il a été devenu
# Original Sentence ['start_ il était seul. _end']
# -
# Input sentence: ['i did my best.']
# Decoded sentence:  je me suis mon
# Original Sentence ['start_ je fis de mon mieux. _end']
# -
# Input sentence: ['you can do it.']
# Decoded sentence:  tu peux le faire
# Original Sentence ['start_ vous pouvez y arriver. _end']
# -
# Input sentence: ['hand me a towel.']
# Decoded sentence:  m'a horreur une
# Original Sentence ['start_ passe-moi une serviette. _end']
# -
# Input sentence: ["it's our car."]
# Decoded sentence:  c'est la temps
# Original Sentence ["start_ c'est notre voiture. _end"]
# -
# Input sentence: ["i'm late."]
# Decoded sentence:  je suis paresseux
# Original Sentence ['start_ je suis en retard. _end']
# -
# Input sentence: ['he talks well.']
# Decoded sentence:  il a eu de des
# Original Sentence ['start_ il parle bien. _end']
# -
# Input sentence: ["don't be sad."]
# Decoded sentence:  ne sois pas naïve
# Original Sentence ['start_ ne sois pas vexé. _end']
# -
# Input sentence: ['i drank a lot.']
# Decoded sentence:  j'ai la bière
# Original Sentence ["start_ j'ai beaucoup bu. _end"]
# -
# Input sentence: ['speak quietly.']
# Decoded sentence:  regarde . _end
# Original Sentence ['start_ parle à voix basse. _end']
# -
# Input sentence: ['get in the car.']
# Decoded sentence:  le voiture , le
# Original Sentence ['start_ montez dans la voiture ! _end']
# -
# Input sentence: ['step back.']
# Decoded sentence:  arrête de ça !
# Original Sentence ['start_ reculez\u2009! _end']
# -
# Input sentence: ['they are bored.']
# Decoded sentence:  ils sont sont
# Original Sentence ["start_ elles s'ennuient. _end"]
# -
# Input sentence: ['i did warn you.']
# Decoded sentence:  je suis besoin
# Original Sentence ["start_ je t'avais prévenue. _end"]
# -
# Input sentence: ["won't you go?"]
# Decoded sentence:  ne me me me est-ce
# Original Sentence ["start_ n'allez-vous pas y aller ? _end"]
# -
# Input sentence: ['is it nearby?']
# Decoded sentence:  est-ce que ça
# Original Sentence ['start_ est-ce proche ? _end']
# -
# Input sentence: ['they swam.']
# Decoded sentence:  ils ont l'air
# Original Sentence ['start_ elles nageaient. _end']
# -
# Input sentence: ['can they see us?']
# Decoded sentence:  pouvons-nous nous
# Original Sentence ['start_ sont-ils en mesure de nous voir ? _end']
# -
# Input sentence: ["i'm just tired."]
# Decoded sentence:  je suis tellement
# Original Sentence ['start_ je suis seulement fatigué. _end']
# -
# Input sentence: ["we're sinking."]
# Decoded sentence:  nous sommes senti
# Original Sentence ['start_ nous sommes en train de couler. _end']
# -
# Input sentence: ["don't run risks."]
# Decoded sentence:  ne fais pas une
# Original Sentence ['start_ ne cours pas de risques. _end']
# -
# Input sentence: ["you're in luck."]
# Decoded sentence:  vous êtes en retard
# Original Sentence ['start_ vous êtes veinards. _end']
# -
# Input sentence: ["i'll talk."]
# Decoded sentence:  je vais en train
# Original Sentence ['start_ je parlerai. _end']
# -
# Input sentence: ["i can't say."]
# Decoded sentence:  je ne peux pas
# Original Sentence ['start_ je ne peux le dire. _end']
# -
# Input sentence: ['i called home.']
# Decoded sentence:  je l'ai ai de
# Original Sentence ["start_ j'ai appelé la maison. _end"]
# -
# Input sentence: ["they're wrong."]
# Decoded sentence:  ils sont en train
# Original Sentence ['start_ ils ont tort ! _end']
# -
# Input sentence: ["i'm busy, too."]
# Decoded sentence:  je suis en train
# Original Sentence ['start_ je suis également occupée. _end']
# -
# Input sentence: ['you promised.']
# Decoded sentence:  tu as besoin de
# Original Sentence ['start_ vous avez promis. _end']
# -
# Input sentence: ['is this wine?']
# Decoded sentence:  est-ce que c'est
# Original Sentence ["start_ s'agit-il de vin ? _end"]
# -
# Input sentence: ['we can try.']
# Decoded sentence:  nous pouvons nous
# Original Sentence ['start_ nous pouvons essayer. _end']
# -
# Input sentence: ['tom is drunk.']
# Decoded sentence:  tom est en train
# Original Sentence ['start_ tom est soûl. _end']
# -
# Input sentence: ['he likes soccer.']
# Decoded sentence:  il a perdu les
# Original Sentence ['start_ il aime le foot. _end']
# -
# Input sentence: ['did you drop it?']
# Decoded sentence:  est-ce que je
# Original Sentence ["start_ l'as-tu laissé tomber ? _end"]
# -
# Input sentence: ["i'm frantic."]
# Decoded sentence:  je suis crevé
# Original Sentence ['start_ je suis affolé. _end']
# -
# Input sentence: ['i outrank you.']
# Decoded sentence:  je vous ai sauvé
# Original Sentence ['start_ je passe avant vous. _end']
# -
# Input sentence: ['they let me go.']
# Decoded sentence:  ils m'ont laissée
# Original Sentence ["start_ elles me laissèrent m'en aller. _end"]
# -
# Input sentence: ["we're powerful."]
# Decoded sentence:  nous sommes sommes
# Original Sentence ['start_ nous sommes puissantes. _end']
# -
# Input sentence: ['this is simple.']
# Decoded sentence:  c'est un livre
# Original Sentence ["start_ c'est simple. _end"]
# -
# Input sentence: ["i'm loyal."]
# Decoded sentence:  je suis en train
# Original Sentence ['start_ je suis loyal. _end']
# -
# Input sentence: ["that's evident."]
# Decoded sentence:  c'est vais . _end
# Original Sentence ["start_ c'est manifeste. _end"]
# -
# Input sentence: ['they smiled.']
# Decoded sentence:  ils ont été touché
# Original Sentence ['start_ ils ont souri. _end']
# -
# Input sentence: ['i need it.']
# Decoded sentence:  je veux des plans
# Original Sentence ['start_ il me le faut. _end']
# -
# Input sentence: ['i nailed it.']
# Decoded sentence:  j'ai fait une
# Original Sentence ["start_ je l'ai cloué. _end"]
# -
# Input sentence: ['buy me a drink.']
# Decoded sentence:  comme c'est un
# Original Sentence ['start_ offrez-moi un verre ! _end']
# -
# Input sentence: ['he was brave.']
# Decoded sentence:  il a été naïf
# Original Sentence ['start_ il était brave. _end']
# -
# Input sentence: ["tom's lying."]
# Decoded sentence:  tom est en train
# Original Sentence ['start_ tom ment. _end']
# -
# Input sentence: ['he scolded her.']
# Decoded sentence:  il a été mis de
# Original Sentence ['start_ il la gronda. _end']
# -
# Input sentence: ['should i wait?']
# Decoded sentence:  ai-je l'air ?
# Original Sentence ['start_ devrais-je attendre ? _end']
# -
# Input sentence: ['i let you down.']
# Decoded sentence:  je vous ai laissées
# Original Sentence ['start_ je vous ai laissés tomber. _end']
# -
# Input sentence: ['get to bed.']
# Decoded sentence:  va dans la chercher
# Original Sentence ['start_ au lit ! _end']
# -
# Input sentence: ['may i help you?']
# Decoded sentence:  puis-je vous ?
# Original Sentence ["start_ est-ce que je peux t'aider\u202f? _end"]
# -
# Input sentence: ["that's enough."]
# Decoded sentence:  c'est juste .
# Original Sentence ['start_ ça suffit\u202f! _end']
# -
# Input sentence: ["you're tough."]
# Decoded sentence:  vous êtes sournois
# Original Sentence ['start_ vous êtes dure. _end']
# -
# Input sentence: ["i'm clean."]
# Decoded sentence:  je suis crevé
# Original Sentence ["start_ j'ai décroché. _end"]
# -
# Input sentence: ['let me help.']
# Decoded sentence:  laissez-moi partir
# Original Sentence ['start_ laissez-moi vous aider ! _end']
# -
# Input sentence: ["who's going?"]
# Decoded sentence:  qui est-il ? _end
# Original Sentence ['start_ qui va y aller ? _end']
# -
# Input sentence: ['use this.']
# Decoded sentence:  du temps ? _end
# Original Sentence ['start_ employez ceci ! _end']
# -
# Input sentence: ['we have wine.']
# Decoded sentence:  nous avons des
# Original Sentence ['start_ nous avons du vin. _end']
# -
# Input sentence: ["you're quiet."]
# Decoded sentence:  vous êtes naïf
# Original Sentence ['start_ tu es tranquille. _end']
# -
# Input sentence: ["i'm not tall."]
# Decoded sentence:  je ne suis pas
# Original Sentence ['start_ je ne suis pas grand. _end']
# -
# Input sentence: ["i'm very fat."]
# Decoded sentence:  je suis très en
# Original Sentence ['start_ je suis très gros. _end']
# -
# Input sentence: ['she wants him.']
# Decoded sentence:  elle le blessé
# Original Sentence ['start_ elle le veut. _end']
# -
# Input sentence: ['tom was thirty.']
# Decoded sentence:  tom était en train
# Original Sentence ['start_ tom avait trente ans. _end']
# -
# Input sentence: ['take a seat.']
# Decoded sentence:  prenez une seconde
# Original Sentence ['start_ prends place ! _end']
# -
# Input sentence: ['she looks sad.']
# Decoded sentence:  elle est en train
# Original Sentence ['start_ elle paraît triste. _end']
# -
# Input sentence: ['stay in bed.']
# Decoded sentence:  restez au lit
# Original Sentence ['start_ restez alité ! _end']
# -
# Input sentence: ['she grew roses.']
# Decoded sentence:  elle est en train
# Original Sentence ['start_ elle fit pousser des roses. _end']
# -
# Input sentence: ['pull over here.']
# Decoded sentence:  arrête de nouveau
# Original Sentence ['start_ arrêtez ici ! _end']
# -
# Input sentence: ['i lost the bet.']
# Decoded sentence:  je me suis vu
# Original Sentence ["start_ j'ai perdu le pari. _end"]
# -
# Input sentence: ['start writing.']
# Decoded sentence:  attrape la porte
# Original Sentence ['start_ commencez à écrire. _end']
# -
# Input sentence: ['read your book.']
# Decoded sentence:  à la toi ? _end
# Original Sentence ['start_ lis ton livre ! _end']
# -
# Input sentence: ['i got lucky.']
# Decoded sentence:  je me suis mis
# Original Sentence ["start_ j'ai eu du bol. _end"]
# -
# Input sentence: ["i'm freezing."]
# Decoded sentence:  je suis en train
# Original Sentence ['start_ je suis gelé. _end']
# -
# Input sentence: ["tom's a doctor."]
# Decoded sentence:  tom est un . _end
# Original Sentence ['start_ tom est docteur. _end']
# -
# Input sentence: ['blow your nose.']
# Decoded sentence:  attrape la main
# Original Sentence ['start_ mouche-toi ! _end']
# -
# Input sentence: ["it can't wait."]
# Decoded sentence:  ça ne pas mal
# Original Sentence ['start_ ça ne peut pas attendre. _end']
# -
# Input sentence: ['i was at home.']
# Decoded sentence:  j'ai été écrit
# Original Sentence ["start_ j'étais à la maison. _end"]
# -
# Input sentence: ['jesus wept.']
# Decoded sentence:  dieu est naïf
# Original Sentence ['start_ jésus a pleuré. _end']
# -
# Input sentence: ["don't be upset."]
# Decoded sentence:  ne soyez pas désolé
# Original Sentence ['start_ ne sois pas contrariée ! _end']
# -
# Input sentence: ['can i touch it?']
# Decoded sentence:  puis-je le voir
# Original Sentence ['start_ puis-je le toucher ? _end']
# -
# Input sentence: ['are you happy?']
# Decoded sentence:  êtes-vous sûr
# Original Sentence ['start_ êtes-vous heureuses ? _end']
# -
# Input sentence: ['how big is it?']
# Decoded sentence:  comment ça va
# Original Sentence ["start_ c'est grand comment ? _end"]
# -
# Input sentence: ['i decorated it.']
# Decoded sentence:  j'ai la voiture
# Original Sentence ["start_ je l'ai décoré. _end"]
# -
# Input sentence: ["you're foolish."]
# Decoded sentence:  vous êtes naïf
# Original Sentence ['start_ tu es imprudente. _end']
# -
# Input sentence: ['stay in bed.']
# Decoded sentence:  restez au lit
# Original Sentence ['start_ reste au lit ! _end']
# -
# Input sentence: ['tom is bald.']
# Decoded sentence:  tom est en train
# Original Sentence ['start_ tom est chauve. _end']
# -
# Input sentence: ['i sure hope so.']
# Decoded sentence:  je me sens de
# Original Sentence ["start_ je l'espère vraiment. _end"]
# -
# Input sentence: ["we're the last."]
# Decoded sentence:  nous sommes en
# Original Sentence ['start_ nous sommes les dernières. _end']
# -
# Input sentence: ['they know him.']
# Decoded sentence:  ils ont l'air
# Original Sentence ['start_ ils le connaissent. _end']
# -
# Input sentence: ['you amuse me.']
# Decoded sentence:  vous pouvez je
# Original Sentence ["start_ tu m'amuses. _end"]
# -
# Input sentence: ['i got busy.']
# Decoded sentence:  j'ai été largué
# Original Sentence ['start_ je suis devenu occupée. _end']
# -
# Input sentence: ["i can't use it."]
# Decoded sentence:  je ne peux pas
# Original Sentence ["start_ je ne peux pas l'utiliser. _end"]
# -
# Input sentence: ['are drinks free?']
# Decoded sentence:  les enfants ?
# Original Sentence ['start_ est-ce que les boissons sont gratuites\u202f? _end']
# -
# Input sentence: ['what do i get?']
# Decoded sentence:  vous me pouvons
# Original Sentence ["start_ qu'est-ce que j'y gagne ? _end"]
# -
# Input sentence: ["you're awesome."]
# Decoded sentence:  vous êtes triste
# Original Sentence ['start_ vous êtes génial. _end']
# -
# Input sentence: ["that's a plan."]
# Decoded sentence:  c'est une _end
# Original Sentence ["start_ c'est un plan. _end"]
# -
# Input sentence: ["i'm retired."]
# Decoded sentence:  je suis en train
# Original Sentence ['start_ je suis pensionnée. _end']
# -
# Input sentence: ['i swim a lot.']
# Decoded sentence:  je me suis trop
# Original Sentence ['start_ je nage beaucoup. _end']
# -
# Input sentence: ['cash is better.']
# Decoded sentence:  ça a besoin de
# Original Sentence ["start_ de l'argent liquide, c'est mieux. _end"]
# -
# Input sentence: ['he is nasty.']
# Decoded sentence:  il est trop en
# Original Sentence ['start_ il est méchant. _end']
# -
# Input sentence: ['i have the key.']
# Decoded sentence:  j'ai fait puis-je
# Original Sentence ["start_ j'ai la clé. _end"]
# -
# Input sentence: ["she's hot."]
# Decoded sentence:  elle est en train
# Original Sentence ['start_ elle est chaude. _end']
# -
# Input sentence: ["they're brave."]
# Decoded sentence:  elles sont en
# Original Sentence ["start_ ils n'ont pas froid aux yeux. _end"]
# -
# Input sentence: ['please stop.']
# Decoded sentence:  s'il vous plaît
# Original Sentence ["start_ arrêtez, s'il vous plaît. _end"]
# -
# Input sentence: ["tom isn't rich."]
# Decoded sentence:  tom est tom .
# Original Sentence ["start_ tom n'est pas riche. _end"]
# -
# Input sentence: ["it's obvious."]
# Decoded sentence:  c'est pas voiture
# Original Sentence ["start_ c'est patent. _end"]
# -
# Input sentence: ["we're late."]
# Decoded sentence:  nous sommes en
# Original Sentence ['start_ nous sommes en retard. _end']
# -
# Input sentence: ['tom likes them.']
# Decoded sentence:  tom a aimé tom
# Original Sentence ['start_ tom les apprécie. _end']
# -
# Input sentence: ["you're early."]
# Decoded sentence:  vous êtes triste
# Original Sentence ['start_ vous êtes en avance. _end']
# -
# Input sentence: ['i like talking.']
# Decoded sentence:  j'aime les êtes
# Original Sentence ['start_ je me plais à causer. _end']
# -
# Input sentence: ['i have a car.']
# Decoded sentence:  je le ai idée
# Original Sentence ["start_ j'ai une voiture. _end"]
# -
# Input sentence: ['i get the idea.']
# Decoded sentence:  je suis besoin
# Original Sentence ['start_ je pige. _end']
# -
# Input sentence: ['many fish died.']
# Decoded sentence:  les hommes sont
# Original Sentence ['start_ de nombreux poissons sont morts. _end']
# -
# Input sentence: ['use them all.']
# Decoded sentence:  les hommes . _end
# Original Sentence ['start_ utilise-les toutes ! _end']
# -
# Input sentence: ['you may go.']
# Decoded sentence:  tu peux partir
# Original Sentence ['start_ tu peux y aller. _end']
# -
# Input sentence: ['wash your face.']
# Decoded sentence:  il plaît . _end
# Original Sentence ['start_ lavez-vous le visage. _end']
# -
# Input sentence: ["tom's sweating."]
# Decoded sentence:  tom a l'air fait
# Original Sentence ['start_ tom transpire. _end']
# -
# Input sentence: ['they let me go.']
# Decoded sentence:  ils m'ont laissée
# Original Sentence ["start_ ils m'ont laissé partir. _end"]
# -
# Input sentence: ['we could die.']
# Decoded sentence:  nous nous avons
# Original Sentence ['start_ nous pourrions mourir. _end']
# -
# Input sentence: ['no problem!']
# Decoded sentence:  c'est pas ! _end
# Original Sentence ['start_ aucun problème\u202f! _end']
# -
# Input sentence: ['i felt ill.']
# Decoded sentence:  je me suis senti
# Original Sentence ['start_ je me sentais malade. _end']
# -
# Input sentence: ['we all knew it.']
# Decoded sentence:  nous avons toutes
# Original Sentence ['start_ nous le savions toutes. _end']
# -
# Input sentence: ['tie your shoe.']
# Decoded sentence:  attache ton lacet
# Original Sentence ['start_ nouez votre chaussure. _end']
# -
# Input sentence: ['i like to talk.']
# Decoded sentence:  j'aime le livre
# Original Sentence ["start_ j'aime discuter. _end"]
# -
# Input sentence: ["we're shaken."]
# Decoded sentence:  nous sommes senti
# Original Sentence ['start_ nous sommes remuées. _end']
# -
# Input sentence: ['please sing.']
# Decoded sentence:  , s'il vous plaît
# Original Sentence ["start_ s'il te plaît, chante ! _end"]
# -
# Input sentence: ['help!']
# Decoded sentence:  à ça ! _end
# Original Sentence ["start_ à l'aide\u202f! _end"]
# -
# Input sentence: ['we saw it.']
# Decoded sentence:  nous avons vu
# Original Sentence ["start_ nous l'avons vu. _end"]
# -
# Input sentence: ['i was there.']
# Decoded sentence:  j'ai été crédule
# Original Sentence ["start_ j'étais là. _end"]
# -
# Input sentence: ["i'm falling."]
# Decoded sentence:  je suis paresseux
# Original Sentence ['start_ je tombe. _end']
# -
# Input sentence: ['that was cool.']
# Decoded sentence:  c'était devenu
# Original Sentence ["start_ c'était cool. _end"]
# -
# Input sentence: ['i am new here.']
# Decoded sentence:  je suis à tom
# Original Sentence ['start_ je suis nouveau, ici. _end']
# -
# Input sentence: ['what is it?']
# Decoded sentence:  qu'est-ce ? _end
# Original Sentence ["start_ qu'est-ce que c'est ? _end"]
# -
# Input sentence: ['i was stunned.']
# Decoded sentence:  j'étais en train
# Original Sentence ["start_ j'étais sciée. _end"]
# -
# Input sentence: ['we must attack.']
# Decoded sentence:  nous avons besoin
# Original Sentence ['start_ il nous faut attaquer. _end']
# -
# Input sentence: ['take mine.']
# Decoded sentence:  prenez la mienne
# Original Sentence ['start_ prenez les miennes. _end']
# -
# Input sentence: ['he likes to run.']
# Decoded sentence:  il a besoin de
# Original Sentence ['start_ il aime courir. _end']
# -
# Input sentence: ['can he do it?']
# Decoded sentence:  pouvons-nous le
# Original Sentence ['start_ est-il en mesure de le faire ? _end']
# -
# Input sentence: ["aren't you late?"]
# Decoded sentence:  êtes-vous pas
# Original Sentence ["start_ n'êtes-vous pas en retard ? _end"]
# -
# Input sentence: ['is it hot?']
# Decoded sentence:  est-ce que c'est
# Original Sentence ['start_ est-ce chaud\xa0? _end']
# -
# Input sentence: ['this annoys me.']
# Decoded sentence:  ça me peux mal
# Original Sentence ["start_ ça m'agace. _end"]
# -
# Input sentence: ["we're lost."]
# Decoded sentence:  nous sommes en
# Original Sentence ['start_ nous sommes perdus. _end']
# -
# Input sentence: ["you're pretty."]
# Decoded sentence:  vous êtes triste
# Original Sentence ['start_ vous êtes jolie. _end']
# -
# Input sentence: ['i followed him.']
# Decoded sentence:  je l'ai vu . _end
# Original Sentence ["start_ je l'ai suivi. _end"]
# -
# Input sentence: ['what if i fail?']
# Decoded sentence:  ai-je fait mal
# Original Sentence ["start_ que se passe-t-il si j'échoue\u202f? _end"]
# -
# Input sentence: ['tom is rude.']
# Decoded sentence:  tom est paresseux
# Original Sentence ['start_ tom est impoli. _end']
# -
# Input sentence: ['stay calm.']
# Decoded sentence:  reste tranquille
# Original Sentence ['start_ garde ton calme. _end']
# -
# Input sentence: ['it was night.']
# Decoded sentence:  c'était . _end
# Original Sentence ['start_ il faisait nuit. _end']
# -
# Input sentence: ["i'm stuffed."]
# Decoded sentence:  je suis paresseux
# Original Sentence ['start_ je suis gavée. _end']
# -
# Input sentence: ['i bribed them.']
# Decoded sentence:  j'ai été perdu
# Original Sentence ['start_ je les ai soudoyées. _end']
# -
# Input sentence: ['grab a spoon.']
# Decoded sentence:  une tom . _end
# Original Sentence ['start_ attrape une cuillère. _end']
# -
# Input sentence: ['i feel unwell.']
# Decoded sentence:  je me sens mal
# Original Sentence ['start_ je ne me sens pas bien. _end']
# -
# Input sentence: ["let's not talk."]
# Decoded sentence:  n'est pas moi
# Original Sentence ['start_ ne parlons pas. _end']
# -
# Input sentence: ['do as you want.']
# Decoded sentence:  faites comme il
# Original Sentence ['start_ fais comme tu veux. _end']
# -
# Input sentence: ['happy birthday!']
# Decoded sentence:  bien bonne ! _end
# Original Sentence ['start_ bon anniversaire\u202f! _end']
# -
# Input sentence: ['buy me a drink.']
# Decoded sentence:  comme c'est un
# Original Sentence ['start_ paie-moi un coup ! _end']
# -
# Input sentence: ['science is fun.']
# Decoded sentence:  c'est bizarre
# Original Sentence ['start_ la science est amusante. _end']
# -
# Input sentence: ["you're rich."]
# Decoded sentence:  vous êtes matinale
# Original Sentence ['start_ vous êtes riche. _end']
# -
# Input sentence: ['are you insane?']
# Decoded sentence:  êtes-vous énervé
# Original Sentence ['start_ tu es folle\u202f? _end']
# -
# Input sentence: ['i made a list.']
# Decoded sentence:  j'ai un chien
# Original Sentence ["start_ j'ai dressé une liste. _end"]
# -
# Input sentence: ['get a haircut.']
# Decoded sentence:  fais un peu prudente
# Original Sentence ['start_ va te faire couper les cheveux ! _end']
# -
# Input sentence: ['i dislike eggs.']
# Decoded sentence:  je déteste les
# Original Sentence ["start_ j'ai une aversion pour les œufs. _end"]
# -
# Input sentence: ['do you get it?']
# Decoded sentence:  tu me suis ? _end
# Original Sentence ['start_ tu captes ? _end']
# -
# Input sentence: ['he got the job.']
# Decoded sentence:  il a fait une
# Original Sentence ['start_ il a eu le poste. _end']
# -
# Input sentence: ['i followed you.']
# Decoded sentence:  je vous ai sauvé
# Original Sentence ["start_ je t'ai suivie. _end"]
# -
# Input sentence: ["don't bother."]
# Decoded sentence:  ne me suis pas
# Original Sentence ['start_ ne dérange pas. _end']
# -
# Input sentence: ["i'm finicky."]
# Decoded sentence:  je suis trop paresseux
# Original Sentence ['start_ je suis méticuleuse. _end']
# -
# Input sentence: ['who killed tom?']
# Decoded sentence:  qui a été maison
# Original Sentence ['start_ qui a tué tom ? _end']
# -
# Input sentence: ['i want a pony.']
# Decoded sentence:  je veux un boulot
# Original Sentence ['start_ je veux un poney. _end']
# -
# Input sentence: ['smoke appeared.']
# Decoded sentence:  j'adore la maison
# Original Sentence ['start_ de la fumée apparut. _end']
# -
# Input sentence: ['i hate parties.']
# Decoded sentence:  je déteste les
# Original Sentence ['start_ je déteste les fêtes. _end']
# -
# Input sentence: ['i had an idea.']
# Decoded sentence:  je l'ai fait une
# Original Sentence ["start_ j'ai eu une idée. _end"]
# -
# Input sentence: ['we can do that.']
# Decoded sentence:  nous pouvons y
# Original Sentence ['start_ nous pouvons faire ça. _end']
# -
# Input sentence: ["you're nuts!"]
# Decoded sentence:  vous êtes malade
# Original Sentence ['start_ vous êtes dingue ! _end']
# -
# Input sentence: ['show it to me.']
# Decoded sentence:  ça ça . _end
# Original Sentence ['start_ montrez-le-moi. _end']
# -
# Input sentence: ['i was late.']
# Decoded sentence:  j'étais en train
# Original Sentence ["start_ j'étais en retard. _end"]
# -
# Input sentence: ['tom sighed.']
# Decoded sentence:  tom a été largué
# Original Sentence ['start_ tom soupira. _end']
# -
# Input sentence: ["i'm not alone."]
# Decoded sentence:  je ne suis pas
# Original Sentence ['start_ je ne suis pas seule. _end']
# -
# Input sentence: ["i'm not tired."]
# Decoded sentence:  je ne suis pas
# Original Sentence ['start_ je ne suis pas fatigué. _end']
# -
# Input sentence: ['i was lucky.']
# Decoded sentence:  j'étais en train
# Original Sentence ["start_ j'ai eu de la chance. _end"]
# -
# Input sentence: ['where were you?']
# Decoded sentence:  où ? _end
# Original Sentence ['start_ où étais-tu\u202f? _end']
# -
# Input sentence: ['here we are.']
# Decoded sentence:  nous nous sommes
# Original Sentence ['start_ nous y voilà ! _end']
# -
# Input sentence: ["i'm addicted."]
# Decoded sentence:  je suis paresseux
# Original Sentence ["start_ j'ai une assuétude. _end"]
# -
# Input sentence: ["we're at war."]
# Decoded sentence:  nous sommes en
# Original Sentence ['start_ nous sommes en guerre. _end']
# -
# Input sentence: ["it's a problem."]
# Decoded sentence:  c'est un livre
# Original Sentence ["start_ c'est un problème. _end"]
# -
# Input sentence: ["she's a model."]
# Decoded sentence:  elle est un chic
# Original Sentence ["start_ c'est un mannequin. _end"]
# -
# Input sentence: ['i never drink.']
# Decoded sentence:  je me sens bien
# Original Sentence ['start_ je ne bois jamais. _end']
# -
# Input sentence: ['i like you.']
# Decoded sentence:  je vous j'aime
# Original Sentence ["start_ je t'aime. _end"]
# -
# Input sentence: ['i have no idea.']
# Decoded sentence:  je ne ai pas fait
# Original Sentence ["start_ je n'ai aucune idée. _end"]
# -
# Input sentence: ['study hard.']
# Decoded sentence:  bien . _end
# Original Sentence ['start_ étudie avec application. _end']
# -
# Input sentence: ["we're sneaky."]
# Decoded sentence:  nous sommes trop
# Original Sentence ['start_ nous sommes sournoises. _end']
# -
# Input sentence: ['i said no.']
# Decoded sentence:  je ne suis dit
# Original Sentence ["start_ j'ai dit non. _end"]
# -
# Input sentence: ['stop them.']
# Decoded sentence:  arrête de nouveau
# Original Sentence ['start_ arrêtez-les. _end']
# -
# Input sentence: ['here comes tom.']
# Decoded sentence:  tom en train de
# Original Sentence ['start_ voilà tom. _end']
# -
# Input sentence: ['who hired you?']
# Decoded sentence:  qui a été faire
# Original Sentence ['start_ qui vous a recrutés ? _end']
# -
# Input sentence: ['how do i look?']
# Decoded sentence:  comment me me
# Original Sentence ["start_ de quoi ai-je l'air ? _end"]
# -
# Input sentence: ['did anyone care?']
# Decoded sentence:  qui va fait ?
# Original Sentence ["start_ quiconque s'en est-il soucié ? _end"]
# -
# Input sentence: ['this is his.']
# Decoded sentence:  c'est le mien
# Original Sentence ["start_ c'est la sienne. _end"]
# -
# Input sentence: ['i said get out.']
# Decoded sentence:  j'ai dit tom .
# Original Sentence ['start_ je vous ai dit de sortir. _end']
# -
# Input sentence: ['help yourself.']
# Decoded sentence:  arrête de nouveau
# Original Sentence ['start_ servez-vous. _end']
# -
# Input sentence: ["they're clean."]
# Decoded sentence:  ils sont flics
# Original Sentence ['start_ ils sont propres. _end']
# -
# Input sentence: ['am i wrong?']
# Decoded sentence:  suis-je fait ?
# Original Sentence ['start_ me trompé-je\u202f? _end']
# -
# Input sentence: ["she's nice."]
# Decoded sentence:  elle est en train
# Original Sentence ['start_ elle est gentille. _end']
# -
# Input sentence: ['we want jobs.']
# Decoded sentence:  nous sommes en
# Original Sentence ['start_ nous voulons des emplois. _end']
# -
# Input sentence: ['that is mine.']
# Decoded sentence:  c'est le mien
# Original Sentence ["start_ c'est le mien. _end"]
# -
# Input sentence: ['i have to go.']
# Decoded sentence:  il me faut partir
# Original Sentence ['start_ je dois partir. _end']
# -
# Input sentence: ['is this art?']
# Decoded sentence:  est-ce l'amour
# Original Sentence ["start_ est-ce de l'art\xa0? _end"]
# -
# Input sentence: ['draw a circle.']
# Decoded sentence:  une tom . _end
# Original Sentence ['start_ tracez un cercle ! _end']
# -
# Input sentence: ['i tried that.']
# Decoded sentence:  je l'ai fait .
# Original Sentence ["start_ j'ai essayé ça. _end"]
# -
# Input sentence: ['i believed you.']
# Decoded sentence:  je vous ai sauvé
# Original Sentence ['start_ je vous ai crus. _end']
# -
# Input sentence: ["it's nothing."]
# Decoded sentence:  c'est bizarre
# Original Sentence ["start_ ce n'est rien. _end"]
# -
# Input sentence: ["i'm unbiased."]
# Decoded sentence:  je suis paresseux
# Original Sentence ['start_ je suis impartial. _end']
# -
# Input sentence: ["i'm sleepy!"]
# Decoded sentence:  je suis ! _end
# Original Sentence ['start_ je suis fatigué ! _end']
# -
# Input sentence: ['she is dead.']
# Decoded sentence:  elle est en train
# Original Sentence ['start_ elle est morte. _end']
# -
# Input sentence: ["they're coming."]
# Decoded sentence:  ils sont en train
# Original Sentence ["start_ ils sont en train d'arriver. _end"]
# -
# Input sentence: ['he let me go.']
# Decoded sentence:  il m'a mis à la
# Original Sentence ["start_ il m'a laissée partir. _end"]
# -
# Input sentence: ['we all know it.']
# Decoded sentence:  nous nous sommes
# Original Sentence ['start_ nous le savons toutes. _end']
# -
# Input sentence: ['they struggled.']
# Decoded sentence:  ils ont ont perdu
# Original Sentence ['start_ ils ont morflé. _end']
# -
# Input sentence: ['what did i win?']
# Decoded sentence:  ai-je fait mal
# Original Sentence ["start_ qu'est-ce que j'ai gagné ? _end"]
# -
# ...
# Original Sentence ["start_ j'ai conclu un accord. _end"]
# -
# Input sentence: ["i'll grab it."]
# Decoded sentence:  je me sens de
# Original Sentence ["start_ je l'attraperai. _end"]
# -
# Input sentence: ["i'm free now."]
# Decoded sentence:  je suis en train
# Original Sentence ['start_ je suis libre maintenant. _end']
# -
# Input sentence: ['tom was fired.']
# Decoded sentence:  tom était mort
# Original Sentence ['start_ thomas a été licencié. _end']
# -
# Input sentence: ['make it larger.']
# Decoded sentence:  ça . _end
# Original Sentence ['start_ élargissez-le. _end']
# -
# Input sentence: ['i like milk.']
# Decoded sentence:  j'aime les êtes
# Original Sentence ["start_ j'aime le lait. _end"]
# -
# Input sentence: ["he's demented."]
# Decoded sentence:  il est devenu
# Original Sentence ['start_ il est fou. _end']
# -
# Input sentence: ['check that.']
# Decoded sentence:  ça . _end
# Original Sentence ['start_ regarde ça. _end']
# -
# Input sentence: ['he will come.']
# Decoded sentence:  il a besoin de
# Original Sentence ['start_ il devrait arriver. _end']
# -
# Input sentence: ["i'll try it."]
# Decoded sentence:  je vais le temps
# Original Sentence ["start_ je l'essayerai. _end"]
# -
# Input sentence: ['we were beaten.']
# Decoded sentence:  nous avons été
# Original Sentence ['start_ nous avons été battus. _end']
# -
# Input sentence: ['i remember.']
# Decoded sentence:  je me sens bien
# Original Sentence ["start_ je m'en souviens. _end"]
# -
# Input sentence: ['they look cool.']
# Decoded sentence:  ils ont l'air
# Original Sentence ["start_ ils ont l'air détendus. _end"]
# -
# Input sentence: ['i finally won.']
# Decoded sentence:  j'ai été vu .
# Original Sentence ["start_ j'ai fini par l'emporter. _end"]
# -
# Input sentence: ["i'm sensitive."]
# Decoded sentence:  je suis faible
# Original Sentence ['start_ je suis sensible. _end']
# -
# Input sentence: ['are they dead?']
# Decoded sentence:  sont-ils sont
# Original Sentence ['start_ sont-ils morts\u202f? _end']
# -
# Input sentence: ['many thanks.']
# Decoded sentence:  regarde la vie
# Original Sentence ['start_ merci vraiment. _end']
# -
# Input sentence: ["it's brand new."]
# Decoded sentence:  c'est un livre
# Original Sentence ['start_ il est tout neuf. _end']
# -
# Input sentence: ['tom drowned.']
# Decoded sentence:  tom a été largué
# Original Sentence ["start_ tom s'est noyé. _end"]
# -
# Input sentence: ['he made me go.']
# Decoded sentence:  il a eu de moi
# Original Sentence ["start_ il m'a fait partir. _end"]
# -
# Input sentence: ["it's garbage."]
# Decoded sentence:  c'est du vôtre
# Original Sentence ['start_ ce sont des détritus. _end']
# -
# Input sentence: ['you must go.']
# Decoded sentence:  vous pouvez partir
# Original Sentence ["start_ il faut que tu t'en ailles. _end"]
# -
# Input sentence: ['i hate soccer.']
# Decoded sentence:  je déteste les
# Original Sentence ['start_ je déteste le football. _end']
# -
# Input sentence: ['get out.']
# Decoded sentence:  va de vous est
# Original Sentence ['start_ casse-toi. _end']
# -
# Input sentence: ["he doesn't lie."]
# Decoded sentence:  il ne sait pas
# Original Sentence ['start_ il ne ment pas. _end']
# -
# Input sentence: ["i'm not asleep."]
# Decoded sentence:  je ne suis pas
# Original Sentence ['start_ je ne suis pas endormie. _end']
# -
# Input sentence: ['never give up.']
# Decoded sentence:  il se a l'air
# Original Sentence ["start_ n'abandonne jamais. _end"]
# -
# Input sentence: ["that's so hard."]
# Decoded sentence:  c'est de pas si
# Original Sentence ["start_ c'est tellement dur ! _end"]
# -
# Input sentence: ['she choked him.']
# Decoded sentence:  elle le monde
# Original Sentence ["start_ elle l'a étranglé. _end"]
# -
# Input sentence: ['i feel giddy.']
# Decoded sentence:  je me sens mal
# Original Sentence ['start_ je suis pris de vertiges. _end']
# -
# Input sentence: ['bring a date.']
# Decoded sentence:  une seconde !
# Original Sentence ['start_ amène une copine ! _end']
# -
# Input sentence: ['he has gone out.']
# Decoded sentence:  il a perdu . _end
# Original Sentence ['start_ il est sorti. _end']
# -
# Input sentence: ['show us around.']
# Decoded sentence:  à tom . _end
# Original Sentence ['start_ faites-nous faire le tour. _end']
# -
# Input sentence: ['get out of here.']
# Decoded sentence:  va de vous est
# Original Sentence ["start_ sortez d'ici ! _end"]
# -
# Input sentence: ["don't complain."]
# Decoded sentence:  ne te fais pas
# Original Sentence ['start_ ne vous plaignez pas. _end']
# -
# Input sentence: ["you're lazy."]
# Decoded sentence:  vous êtes êtes
# Original Sentence ['start_ vous êtes paresseuses. _end']
# -
# Input sentence: ['go slow.']
# Decoded sentence:  va tranquille
# Original Sentence ['start_ va doucement ! _end']
# -
# Input sentence: ["it's obsolete."]
# Decoded sentence:  c'est neuf . _end
# Original Sentence ["start_ c'est dépassé. _end"]
# -
# Input sentence: ['how old is he?']
# Decoded sentence:  ce que c'est un
# Original Sentence ['start_ quel âge a-t-il\u202f? _end']
# -
# Input sentence: ["we're all safe."]
# Decoded sentence:  nous sommes en
# Original Sentence ['start_ nous sommes tous en sécurité. _end']
# -
# Input sentence: ['i was sleepy.']
# Decoded sentence:  j'étais en train
# Original Sentence ["start_ j'avais envie de dormir. _end"]
# -
# Input sentence: ["it's bedtime."]
# Decoded sentence:  c'est devenu de
# Original Sentence ['start_ il est temps de dormir. _end']
# -
# Input sentence: ['let me check.']
# Decoded sentence:  laissez-moi parler
# Original Sentence ['start_ laissez-moi contrôler. _end']
# -
# Input sentence: ['that was quick.']
# Decoded sentence:  c'était devenu
# Original Sentence ["start_ c'était rapide. _end"]
# -
# Input sentence: ['i must go.']
# Decoded sentence:  je dois y aller
# Original Sentence ["start_ il me faut m'en aller. _end"]
# -
# Input sentence: ['it was locked.']
# Decoded sentence:  il a été nez .
# Original Sentence ["start_ c'était verrouillé. _end"]
# -
# Input sentence: ['no one escaped.']
# Decoded sentence:  personne ne l'a
# Original Sentence ["start_ personne n'en a réchappé. _end"]
# -
# Input sentence: ["i'm not rich."]
# Decoded sentence:  je ne suis pas
# Original Sentence ['start_ je ne suis pas riche. _end']
# -
# Input sentence: ["you're big."]
# Decoded sentence:  vous êtes grande
# Original Sentence ['start_ vous êtes grand. _end']
# -
# Input sentence: ['he was english.']
# Decoded sentence:  il était devenu
# Original Sentence ['start_ il était anglais. _end']
# -
# Input sentence: ['shut your eyes.']
# Decoded sentence:  restez tranquille
# Original Sentence ['start_ fermez les yeux. _end']
# -
# Input sentence: ["no one's here."]
# Decoded sentence:  personne ne n'est
# Original Sentence ["start_ personne n'est ici. _end"]
# -
# Input sentence: ['money talks.']
# Decoded sentence:  fais de nouveau
# Original Sentence ["start_ l'argent est roi. _end"]
# -
# Input sentence: ['we succeeded!']
# Decoded sentence:  nous avons été
# Original Sentence ['start_ nous avons réussi\u202f! _end']
# -
# Input sentence: ["i'm shocked."]
# Decoded sentence:  je suis désolée
# Original Sentence ['start_ je suis choquée. _end']
# -
# Input sentence: ['sit down!']
# Decoded sentence:  ! _end
# Original Sentence ['start_ assieds-toi ! _end']
# -
# Input sentence: ['can we go?']
# Decoded sentence:  pouvons-nous partir
# Original Sentence ['start_ pouvons-nous y aller ? _end']
# -
# Input sentence: ['the cat is wet.']
# Decoded sentence:  la chien est crédule
# Original Sentence ['start_ le chat est mouillé. _end']
# -
# Input sentence: ['they let me go.']
# Decoded sentence:  ils m'ont laissée
# Original Sentence ["start_ elles m'ont laissé partir. _end"]
# -
# Input sentence: ['it came apart.']
# Decoded sentence:  ça a été largué
# Original Sentence ["start_ c'est cassé. _end"]
# -
# Input sentence: ['get a job.']
# Decoded sentence:  prenez un peu
# Original Sentence ['start_ trouvez un boulot ! _end']
# -
# Input sentence: ['look here.']
# Decoded sentence:  à la maison .
# Original Sentence ['start_ regarde ici. _end']
# -
# Input sentence: ['run for it!']
# Decoded sentence:  prends à le faire
# Original Sentence ['start_ taillez-vous ! _end']
# -
# Input sentence: ["i'm astonished."]
# Decoded sentence:  je suis réveillé
# Original Sentence ['start_ je suis stupéfaite. _end']
# [[["'start_", 'nous', 'avons', 'réussi\\u202f', '!', '_end', "'"]], [['``', 'start_', "quelqu'un", 'est-il', 'mort', '?', '_end', "''"]], [["'start_", 'tu', 'me', 'fais', 'peur', '.', '_end', "'"]], [["'start_", 'je', 'suis', 'vannée', '.', '_end', "'"]], [['``', 'start_', 'je', 'ne', "l'ai", 'pas', 'fait', '.', '_end', "''"]], [['``', 'start_', "j'étais", 'sobre', '.', '_end', "''"]], [["'start_", 'êtes-vous', 'chauve', '?', '_end', "'"]], [["'start_", 'nous', 'restâmes', 'silencieux', '.', '_end', "'"]], [["'start_", 'je', 'veux', 'laisser', 'tomber', '.', '_end', "'"]], [["'start_", 'est-ce', 'les', 'tiennes', '?', '_end', "'"]], [["'start_", 'je', 'suis', 'rationnelle', '.', '_end', "'"]], [["'start_", 'je', 'ne', 'suis', 'pas', 'fort', '.', '_end', "'"]], [["'start_", 'comment', 'va', 'ton', 'boulot\\u202f', '?', '_end', "'"]], [["'start_", 'je', 'le', 'sais', '.', '_end', "'"]], [['``', 'start_', "c'est", 'super', '.', '_end', "''"]], [["'start_", 'vous', 'avez', 'fait', 'cela', '.', '_end', "'"]], [["'start_", 'je', 'la', 'connais', '.', '_end', "'"]], [["'start_", 'soyez', 'satisfaite', '!', '_end', "'"]], [["'start_", 'ça', 'suffit', '.', '_end', "'"]], [['``', 'start_', 'il', "n'a", 'pas', "d'argent", '.', '_end', "''"]], [["'start_", 'soyez', 'prudentes', '!', '_end', "'"]], [["'start_", 'dites', 'simplement', 'non', '!', '_end', "'"]], [["'start_", 'ferme', 'les', 'yeux', '.', '_end', "'"]], [["'start_", 'venez\\u202f', '!', '_end', "'"]], [['``', 'start_', "j'adore", 'mon', 'foyer', '.', '_end', "''"]], [['``', 'start_', 'il', "m'aide", '.', '_end', "''"]], [['``', 'start_', 'je', "l'ai", 'trouvé', '.', '_end', "''"]], [["'start_", 'je', 'le', 'gronderai', '.', '_end', "'"]], [["'start_", 'te', 'fies-tu', 'à', 'moi', '?', '_end', "'"]], [["'start_", 'vous', 'êtes', 'précis', '.', '_end', "'"]], [['``', 'start_', "c'est", 'un', 'dvd', '.', '_end', "''"]], [["'start_", 'elles', 'sont', 'de', 'retour', '.', '_end', "'"]], [["'start_", 'dommage\\u202f', '!', '_end', "'"]], [["'start_", 'sois', 'impitoyable', '!', '_end', "'"]], [['``', 'start_', "n'ayez", 'pas', 'peur', '.', '_end', "''"]], [["'start_", 'thomas', 'est', 'mourant', '.', '_end', "'"]], [["'start_", 'qui', 'sont-ils\\u202f', '?', '_end', "'"]], [['``', 'start_', "c'est", 'encombrant', '.', '_end', "''"]], [["'start_", 'je', 'suis', 'pensionné', '.', '_end', "'"]], [["'start_", 'pleut-il', '?', '_end', "'"]], [["'start_", 'vous', 'êtes', 'sournoises', '.', '_end', "'"]], [['``', 'start_', "j'ai", 'tellement', 'froid', '.', '_end', "''"]], [["'start_", 'nous', 'mourrons', 'de', 'faim', '.', '_end', "'"]], [["'start_", 'venez', 'à', 'nous', '.', '_end', "'"]], [['``', 'start_', 'laisse-moi', "t'aider", '!', '_end', "''"]], [["'start_", 'es-tu', 'envieux', '?', '_end', "'"]], [['``', 'start_', 'je', "t'en", 'prie', '!', '_end', "''"]], [['``', 'start_', 'il', "s'en", 'alla', '.', '_end', "''"]], [["'start_", 'continue', 'à', 'rouler', '!', '_end', "'"]], [['``', 'start_', "j'en", 'ai', 'besoin', '.', '_end', "''"]], [["'start_", 'elle', 'est', 'adorable', '.', '_end', "'"]], [['``', 'start_', "j'obéirai", '.', '_end', "''"]], [["'start_", 'qui', 'a', 'fait', 'ça', '?', '_end', "'"]], [["'start_", 'nous', 'devons', 'y', 'aller', '.', '_end', "'"]], [["'start_", 'vous', 'êtes', 'si', 'méchants', '.', '_end', "'"]], [["'start_", 'je', 'vous', 'souhaite', 'le', 'bonjour\\u202f', '!', '_end', "'"]], [["'start_", 'tom', 'partit', '.', '_end', "'"]], [["'start_", 'je', 'vais', 'bien', '.', '_end', "'"]], [["'start_", 'elle', 'est', 'venue', 'seule', '.', '_end', "'"]], [["'start_", 'donnez-moi', 'la', 'clé', '.', '_end', "'"]], [["'start_", 'ne', 'partez', 'pas', '!', '_end', "'"]], [["'start_", 'je', 'passe', 'avant', 'toi', '.', '_end', "'"]], [["'start_", 'je', 'me', 'sens', 'perdue', '.', '_end', "'"]], [["'start_", 'tom', 'sait', 'ça', '.', '_end', "'"]], [["'start_", 'il', 'se', 'mit', 'debout', '.', '_end', "'"]], [['``', 'start_', "j'ai", 'demandé', 'à', 't ...
# [['start_', 'nous', 'avons', 'besoin', '_end'], ['start_', 'qui', 'a', 'fait', 'mal', '_end'], ['start_', 'vous', 'me', 'prie', '.', '_end'], ['start_', 'je', 'suis', 'crevé', '_end'], ['start_', 'je', 'ne', 'suis', 'pas', '_end'], ['start_', "j'étais", 'en', 'train', '_end'], ['start_', 'êtes-vous', 'énervé', '_end'], ['start_', 'nous', 'avons', 'perdu', '_end'], ['start_', 'je', 'veux', 'la', 'maison', '_end'], ['start_', 'êtes-vous', 'sont', '_end'], ['start_', 'je', 'suis', 'célibataire', '_end'], ['start_', 'je', 'ne', 'suis', 'pas', '_end'], ['start_', "c'est", 'tom', '?', '_end', '_end'], ['start_', 'je', 'le', 'peux', '.', '_end', '_end'], ['start_', "c'est", 'de', 'nouveau', '_end'], ['start_', 'tu', 'peux', 'ça', '.', '_end', '_end'], ['start_', 'je', 'me', 'sens', 'bien', '_end'], ['start_', 'soyez', 'prudent', '_end'], ['start_', "c'est", 'juste', '.', '_end'], ['start_', 'il', 'a', 'fait', 'de', 'fait', '_end'], ['start_', 'soyez', 'prudent', '_end'], ['start_', 'ne', 'le', "n'est", 'pas', '_end'], ['start_', 'restez', 'tranquille', '_end'], ['start_', 'viens', '!', '_end', '_end'], ['start_', "j'adore", 'mon', 'boulot', '_end'], ['start_', 'il', 'est', 'là', '.', '_end', '_end'], ['start_', 'je', "l'ai", 'fait', 'de', '_end'], ['start_', 'je', 'serai', 'en', 'train', '_end'], ['start_', 'est-ce', 'que', 'tu', '_end'], ['start_', 'tu', 'es', '.', '_end', '_end'], ['start_', "c'est", 'un', 'livre', '_end'], ['start_', 'ils', 'sont', 'en', 'train', '_end'], ['start_', 'quelle', 'voilà', '!', '_end'], ['start_', 'soyez', 'prudent', '_end'], ['start_', 'ne', 'sois', 'pas', 'naïve', '_end'], ['start_', 'tom', 'est', 'en', 'train', '_end'], ['start_', 'qui', 'est', '?', '_end', '_end'], ['start_', "c'est", 'devenu', 'elle', '_end'], ['start_', 'je', 'suis', 'en', 'train', '_end'], ['start_', 'est-ce', 'que', 'ça', '_end'], ['start_', 'vous', 'êtes', 'sournois', '_end'], ['start_', 'je', 'me', 'sens', 'mal', '_end'], ['start_', 'nous', 'nous', 'sommes', '_end'], ['start_', 'venez', '!', '_end', '_end'], ['start_', 'laissez-moi', 'partir', '_end'], ['start_', 'êtes-vous', 'énervé', '_end'], ['start_', 'je', 'vous', 'prie', '!', '_end'], ['start_', 'il', 'a', 'eu', 'de', 'fait', '_end'], ['start_', '!', '_end', '_end'], ['start_', "j'ai", 'besoin', 'de', '_end'], ['start_', 'elle', 'est', 'en', 'train', '_end'], ['start_', 'je', 'veux', 'de', 'le', '_end'], ['start_', 'qui', "l'a", 'fait', '?', '_end'], ['start_', 'nous', 'nous', 'faut', '_end'], ['start_', 'vous', 'êtes', 'si', 'en', '_end'], ['start_', 'bonne', 'bonne', 'journée', '_end'], ['start_', 'tom', 'est', 'mort', '.', '_end'], ['start_', 'je', 'suis', 'en', 'train', '_end'], ['start_', 'elle', 'a', 'aimé', 'ça', '_end'], ['start_', 'ne', 'peux', 'pas', '!', '_end'], ['start_', 'ne', 'me', 'suis', 'pas', '_end'], ['start_', 'je', 'vous', 'ai', 'sauvé', '_end'], ['start_', 'je', 'me', 'sens', 'mal', '_end'], ['start_', 'tom', 'fait', 'confiance', '_end'], ['start_', 'il', 'a', 'eu', 'de', 'fait', '_end'], ['start_', "j'ai", 'dit', 'tom', '.', '_end'], ['start_', 'regarde', 'avec', 'moi', '_end'], ['start_', 'êtes-vous', 'sûr', '_end'], ['start_', 'je', 'suis', 'très', 'trop', '_end'], ['start_', 'il', "n'est", 'pas', 'à', '_end'], ['start_', 'sois', 'avec', 'moi', '_end'], ['start_', 'il', 'a', 'été', 'largué', '_end'], ['start_', 'ça', '!', '_end', '_end'], ['start_', 'je', 'suis', 'réveillé', '_end'], ['start_', 'je', 'suis', 'juste', '_end'], ['start_', 'nous', 'sommes', 'en', '_end'], ['start_', 'ils', 'ont', 'été', 'eu', '_end'], ['start_', 'je', 'ne', 'ai', 'vu', 'pas', '_end'], ['start_', 'il', 'a', 'eu', 'de', 'fait', '_end'], ['start_', 'prenez', 'la', 'mienne', '_end'], ['start_', 'je', 'veux', 'une', 'il', '_end'], ['start_', 'je', 'veux', 'y', 'aller', '_end'], ['start_', 'est-ce', 'que', 'tom', '_end'], ['start_', 'arrête', 'de', 'hurler', '_end'], ['start_', '?', '_end', '_end'], ['start_', 'nous', 'sommes', 'trop', '_end'], ['start_', 'je', 'ne', 's ...
# BLEU-1: 0.317933
# BLEU-2: 0.183142
# BLEU-3: 0.120772
# BLEU-4: 0.056879

# %% [markdown]
# # Section 4 Attention
#
# ---

# %% [markdown]
# ** Task 5 (40 Marks) **sequence2sequence
#
# * Extend the existing Seq2Seq model with an attention mechanism [Discussed in Class]
# * Create sequence2sequence model with attention (15 marks)
# * Train the model with the same data from Section 1 (10 marks)
# * Translate the evaluation using the sequence2sequence attention model (10 marks)
# * Evaluate the translations made with the sequence2sequence attention model and compare it with the model without attention using BLEU (5 marks)

# %% [markdown]
# **Attention Model**
# An attentional mechanism has lately been used to improve neural machine translation (NMT) by selectively focusing on parts of the source sentence during translation. It is very effective for the long sentence while using in encoder decoder. It works like the real time translator where it is not the case to get all the hidden state  of encoding the source sentence and then decode depending on that state.
#
# **Advantage**
# 1. For the long sentences it is very effective it will concentrate on the selective part of the sentence to focus on.
# 2. Depending on the weight that is given it is very easy to understand which parts of the sentence will be given more stress.
# 3. There can be local attention or global attention depending on which translation can be done from source to target languages.
#
# **Mechanism**
# There are many mechanism which can be found to implement on the encoder and decoder model. Among them I have found one paper where the attention mechanism has been described with Global dot product based attention mechanism based on the previous hidden state of encoder and decoder.  I have referenced the paper in the reference section.
# The idea of a global attentional model is to consider all the hidden states of the encoder when deriving the context vector.
# Here are the steps which are followed to get the attention of the words where to focus on while translating:-
#
# 1.   First I have taken the output of the decoder and the output of the decoder state. These two states will be used to make where to give the attention with weight. Now there are multiple ways to do the weights. According to the paper as we are taking the softmax of the dot product of the outputs. Bascially these will give a probability distirbution weights to the each of the encoder output and the decoder output. These can be treated as attention score which will then be feed into context vector.
# 2.   After getting the attention score we are feeding this to a context vector which is getting the attention we got in the previous step and the encoder output.
# 3. Now the context vector is being concatenate with the decoder output which has been then passed into timedistributed dense layer having activation function "tanh".
# 4. Then this data has been fitted into timedistributed softmax function which will calculate the probability distirbution of the output words sequence based on which we will predict the outut words of the french sentence and then will return the output sentence.
#
# **Decoder part for Test Data**
# Once the model has been trained, the input sequence of test data has been passed sentence wise to get the decoder sequence of the target data. the idea behind the decoding is:-
# 1. The sentence wise test data sequence has been passed into decode_sequence_attention function.
# 2. A encoder input matrix has been made which is same as the input sequence only shape has been defined.
# 3. A decode sequence matrix carries the first word as start to denote that that is starting of the sentence and then predict the sequence of the output and taking the maximum of it.
# 4. Then putting all together in the same array of decode matrix we use the reverse matrix to get the word out of the sequence.
#
# In this way my decode sequence is working.
#
# **Comparison with encoder decoder according to bleu score**
# Now once the model has been build I have translated my whole test data set to get the translated sentences and then defined the blue score for that. On comparison I can see the comparison of the blue scores of the encoder- decoder model and with attention
#
# Without Attention:-
# BLEU-1: 0.317933
# BLEU-2: 0.183142
# BLEU-3: 0.120772
# BLEU-4: 0.056879
#
# With Attention:-
# BLEU-1: 0.389593
# BLEU-2: 0.274304
# BLEU-3: 0.168985
# BLEU-4: 0.076661
#
# We can see that the 1-gram bleu score is high in the Attention encode-decoder model than the without attention encoder-decoder model. That means the words are better when predicting the translation with attention. Also the bigram matches are in high number in attention encoder-decoder model.
#
# On comparison we can see that the bleu score for every n-gram is better in attention model than the encoder-decoder model without attention.

# %%
#This code has been written to make the encoder model. Here I have used the keras embedding layer and fixed them with the glove embedding matrix.
#There are total 50 cells taken for the lstm and I have sliced the encoder to take the last state which will be the input in the decoder.
import numpy as np
import keras, tensorflow
from keras.models import Model
from keras.layers import Input, LSTM, Dense
from keras.layers import Embedding
# encoder code goes here
encoder_inputs = Input(shape=(None,))
en_x=  Embedding(num_source_tokens,
                            50,
                            weights=[embedding_matrix],
                            input_length=max_source_seq_length,
                            trainable=False)(encoder_inputs)
encoder = LSTM(50, return_sequences=True)(en_x)
encoder_last = encoder[:,-1,:]

# %%
#This code has been written to make the decoder model. I have passed the target language data through the keras inbuilt embedding layer as I do not
#have the embedding for the French sentence. I have putter mask_zero=true as a part of 0 padding. This very helpful when the length of the 
#sequences are not the same. The number of cells fot the lstm is 50 which has been kept. The initial state of the decoder is the last hidden state and
#the cell state of the encider which has been passed.
decoder_input = Input(shape=(None,))

dex=  Embedding(num_target_tokens, 50, mask_zero=True)

final_dex= dex(decoder_input)
decoder = LSTM(latent_dim, return_sequences=True)(final_dex,initial_state=[encoder_last, encoder_last])

# %%
#In this part I have introduced the concept of attention and context vector. The attention has been made with the dot product of the encoder and decoder
#output and then passed it through softmax. The softmax function has given the probability distribution which has been taken as attention weights.
#The attention then multiplied with the encoder to get the context vector. Conext vector is then concatenated with the decoder vector which will be put into
#decoder output. Then with the help of timedistribution layer of keras and activation function tanh I have trained the model and taking the highest probability 
#word with the help of softmax 
from keras.layers import Activation, dot, concatenate
from keras.layers import Input, Embedding, LSTM, TimeDistributed, Dense
from keras.models import Model, load_model


attention = dot([decoder, encoder], axes=[2, 2])
print(attention)
attention = Activation('softmax', name='attention')(attention)
print('attention', attention)

context = dot([attention, encoder], axes=[2,1])
print('context', context)

decoder_combined_context = concatenate([context, decoder])
print('decoder_combined_context', decoder_combined_context)

# Has another weight + tanh layer as described in equation (5) of the paper
output = TimeDistributed(Dense(50, activation="tanh"))(decoder_combined_context)
output = TimeDistributed(Dense(num_target_tokens, activation="softmax"))(output)
print('output', output)
# Out:
# Tensor("dot_3/MatMul:0", shape=(?, ?, ?), dtype=float32)
# attention Tensor("attention_1/truediv:0", shape=(?, ?, ?), dtype=float32)
# context Tensor("dot_4/MatMul:0", shape=(?, ?, 50), dtype=float32)
# decoder_combined_context Tensor("concatenate_2/concat:0", shape=(?, ?, 100), dtype=float32)
# output Tensor("time_distributed_4/Reshape_1:0", shape=(?, ?, 4585), dtype=float32)

# %%
#Here I am making the model with the encoder input and decoder input. The loss is categorical crossentropy and the optimizer is rmsprop.
#The accuract matrix has been taken to see the accuracy in training and validation
model= Model(inputs=[encoder_inputs, decoder_input],outputs=output)
model.compile(optimizer='rmsprop',loss='categorical_crossentropy', metrics=['acc'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, None, 50)     229250      input_4[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 6, 50)        105300      input_3[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, None, 50)     20200       embedding_4[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 6, 50)        20200       embedding_3[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, None, 6)      0           lstm_4[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# attention (Activation)          (None, None, 6)      0           dot_3[0][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, None, 50)     0           attention[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, 100)    0           dot_4[0][0]
#                                                                  lstm_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, None, 50)     5050        concatenate_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, None, 4585)   233835      time_distributed_3[0][0]
# ==================================================================================================
# Total params: 613,835
# Trainable params: 508,535
# Non-trainable params: 105,300
# __________________________________________________________________________________________________

# %%
#Here I am fitting the data into model to train the model with the words
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=64,
          epochs=50,
          validation_split=0.05)
# Out:
# Train on 7599 samples, validate on 400 samples
# Epoch 1/50
# 7599/7599 [==============================] - 8s 1ms/step - loss: 4.7961 - acc: 0.1387 - val_loss: 4.2409 - val_acc: 0.1422
# Epoch 2/50
# 7599/7599 [==============================] - 6s 819us/step - loss: 3.9782 - acc: 0.1969 - val_loss: 3.8021 - val_acc: 0.2662
# Epoch 3/50
# 7599/7599 [==============================] - 6s 747us/step - loss: 3.5087 - acc: 0.2936 - val_loss: 3.4743 - val_acc: 0.3058
# Epoch 4/50
# 7599/7599 [==============================] - 6s 750us/step - loss: 3.2495 - acc: 0.3154 - val_loss: 3.3438 - val_acc: 0.3181
# Epoch 5/50
# 7599/7599 [==============================] - 6s 754us/step - loss: 3.0821 - acc: 0.3511 - val_loss: 3.1819 - val_acc: 0.3727
# Epoch 6/50
# 7599/7599 [==============================] - 6s 753us/step - loss: 2.9396 - acc: 0.3803 - val_loss: 3.0830 - val_acc: 0.3861
# Epoch 7/50
# 7599/7599 [==============================] - 6s 744us/step - loss: 2.8260 - acc: 0.3968 - val_loss: 2.9932 - val_acc: 0.4024
# Epoch 8/50
# 7599/7599 [==============================] - 6s 757us/step - loss: 2.7305 - acc: 0.4122 - val_loss: 2.9238 - val_acc: 0.4218
# Epoch 9/50
# 7599/7599 [==============================] - 6s 754us/step - loss: 2.6510 - acc: 0.4253 - val_loss: 2.8476 - val_acc: 0.4322
# Epoch 10/50
# 7599/7599 [==============================] - 6s 747us/step - loss: 2.5829 - acc: 0.4354 - val_loss: 2.7821 - val_acc: 0.4403
# Epoch 11/50
# 7599/7599 [==============================] - 6s 745us/step - loss: 2.5259 - acc: 0.4442 - val_loss: 2.7387 - val_acc: 0.4375
# Epoch 12/50
# 7599/7599 [==============================] - 6s 743us/step - loss: 2.4753 - acc: 0.4517 - val_loss: 2.7151 - val_acc: 0.4530
# Epoch 13/50
# 7599/7599 [==============================] - 6s 747us/step - loss: 2.4289 - acc: 0.4588 - val_loss: 2.6702 - val_acc: 0.4520
# Epoch 14/50
# 7599/7599 [==============================] - 6s 744us/step - loss: 2.3882 - acc: 0.4660 - val_loss: 2.6376 - val_acc: 0.4585
# Epoch 15/50
# 7599/7599 [==============================] - 6s 841us/step - loss: 2.3505 - acc: 0.4719 - val_loss: 2.6253 - val_acc: 0.4667
# Epoch 16/50
# 7599/7599 [==============================] - 6s 808us/step - loss: 2.3138 - acc: 0.4768 - val_loss: 2.5959 - val_acc: 0.4639
# Epoch 17/50
# 7599/7599 [==============================] - 6s 742us/step - loss: 2.2800 - acc: 0.4817 - val_loss: 2.5849 - val_acc: 0.4817
# Epoch 18/50
# 7599/7599 [==============================] - 6s 747us/step - loss: 2.2487 - acc: 0.4860 - val_loss: 2.5642 - val_acc: 0.4756
# Epoch 19/50
# 7599/7599 [==============================] - 6s 751us/step - loss: 2.2191 - acc: 0.4907 - val_loss: 2.5382 - val_acc: 0.4754
# Epoch 20/50
# 7599/7599 [==============================] - 6s 744us/step - loss: 2.1930 - acc: 0.4952 - val_loss: 2.5209 - val_acc: 0.4852
# Epoch 21/50
# 7599/7599 [==============================] - 6s 747us/step - loss: 2.1671 - acc: 0.5005 - val_loss: 2.5195 - val_acc: 0.4731
# Epoch 22/50
# 7599/7599 [==============================] - 6s 743us/step - loss: 2.1431 - acc: 0.5029 - val_loss: 2.5186 - val_acc: 0.4837
# Epoch 23/50
# 7599/7599 [==============================] - 6s 741us/step - loss: 2.1204 - acc: 0.5065 - val_loss: 2.5095 - val_acc: 0.4815
# Epoch 24/50
# 7599/7599 [==============================] - 6s 745us/step - loss: 2.0993 - acc: 0.5097 - val_loss: 2.4887 - val_acc: 0.4881
# Epoch 25/50
# 7599/7599 [==============================] - 6s 742us/step - loss: 2.0809 - acc: 0.5127 - val_loss: 2.4875 - val_acc: 0.4880
# Epoch 26/50
# 7599/7599 [==============================] - 6s 743us/step - loss: 2.0596 - acc: 0.5172 - val_loss: 2.4805 - val_acc: 0.4856
# Epoch 27/50
# 7599/7599 [==============================] - 6s 752us/step - loss: 2.0415 - acc: 0.5210 - val_loss: 2.4770 - val_acc: 0.4837
# Epoch 28/50
# 7599/7599 [==============================] - 6s 747us/step - loss: 2.0215 - acc: 0.5233 - val_loss: 2.4525 - val_acc: 0.4877
# Epoch 29/50
# 7599/7599 [==============================] - 6s 840us/step - loss: 2.0038 - acc: 0.5252 - val_loss: 2.4698 - val_acc: 0.4900
# Epoch 30/50
# 7599/7599 [==============================] - 6s 798us/step - loss: 1.9845 - acc: 0.5308 - val_loss: 2.4406 - val_acc: 0.4957
# Epoch 31/50
# 7599/7599 [==============================] - 6s 750us/step - loss: 1.9667 - acc: 0.5319 - val_loss: 2.4379 - val_acc: 0.4941
# Epoch 32/50
# 7599/7599 [==============================] - 6s 742us/step - loss: 1.9444 - acc: 0.5338 - val_loss: 2.4362 - val_acc: 0.4871
# Epoch 33/50
# 7599/7599 [==============================] - 6s 742us/step - loss: 1.9187 - acc: 0.5372 - val_loss: 2.3902 - val_acc: 0.4916
# Epoch 34/50
# 7599/7599 [==============================] - 6s 745us/step - loss: 1.8969 - acc: 0.5383 - val_loss: 2.3807 - val_acc: 0.4934
# Epoch 35/50
# 7599/7599 [==============================] - 6s 745us/step - loss: 1.8780 - acc: 0.5414 - val_loss: 2.3719 - val_acc: 0.4932
# Epoch 36/50
# 7599/7599 [==============================] - 6s 735us/step - loss: 1.8601 - acc: 0.5444 - val_loss: 2.3667 - val_acc: 0.4941
# Epoch 37/50
# 7599/7599 [==============================] - 6s 751us/step - loss: 1.8441 - acc: 0.5468 - val_loss: 2.3563 - val_acc: 0.4902
# Epoch 38/50
# 7599/7599 [==============================] - 6s 823us/step - loss: 1.8296 - acc: 0.5493 - val_loss: 2.3509 - val_acc: 0.4958
# Epoch 39/50
# 7599/7599 [==============================] - 7s 856us/step - loss: 1.8149 - acc: 0.5523 - val_loss: 2.3595 - val_acc: 0.4983
# Epoch 40/50
# 7599/7599 [==============================] - 6s 748us/step - loss: 1.8023 - acc: 0.5537 - val_loss: 2.3569 - val_acc: 0.4961
# Epoch 41/50
# 7599/7599 [==============================] - 6s 748us/step - loss: 1.7880 - acc: 0.5559 - val_loss: 2.3457 - val_acc: 0.4957
# Epoch 42/50
# 7599/7599 [==============================] - 6s 767us/step - loss: 1.7757 - acc: 0.5578 - val_loss: 2.3429 - val_acc: 0.4965
# Epoch 43/50
# 7599/7599 [==============================] - 7s 856us/step - loss: 1.7625 - acc: 0.5603 - val_loss: 2.3513 - val_acc: 0.4973
# Epoch 44/50
# 7599/7599 [==============================] - 6s 774us/step - loss: 1.7478 - acc: 0.5622 - val_loss: 2.3301 - val_acc: 0.4940
# Epoch 45/50
# 7599/7599 [==============================] - 6s 745us/step - loss: 1.7357 - acc: 0.5634 - val_loss: 2.3442 - val_acc: 0.4974
# Epoch 46/50
# 7599/7599 [==============================] - 6s 746us/step - loss: 1.7234 - acc: 0.5665 - val_loss: 2.3458 - val_acc: 0.4958
# Epoch 47/50
# 7599/7599 [==============================] - 6s 748us/step - loss: 1.7119 - acc: 0.5684 - val_loss: 2.3337 - val_acc: 0.4929
# Epoch 48/50
# 7599/7599 [==============================] - 6s 749us/step - loss: 1.7009 - acc: 0.5705 - val_loss: 2.3344 - val_acc: 0.4970
# Epoch 49/50
# 7599/7599 [==============================] - 6s 750us/step - loss: 1.6928 - acc: 0.5709 - val_loss: 2.3501 - val_acc: 0.4941
# Epoch 50/50
# 7599/7599 [==============================] - 6s 745us/step - loss: 1.6811 - acc: 0.5744 - val_loss: 2.3324 - val_acc: 0.5002

# %%
#To generate the words from the sequence I have written this reverse code
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
#This code I have written to get the decoded output sentence. The input is coming from the test data part and is fitting into enoced sequence matrix.
#The first word is hardcoded as "start_" to be predicted to denote the start of the sentence. Then with the help of trained model I am predicting the 
#sequence. The the decoder sequence input has been passed to get the words output till the word "_end" will come denoting the end of the sentence.
def decode_sequence_attention(input_seq):
    decoded_sentence = ''
    encoder_input = input_seq.reshape(1,max_source_seq_length)
    #print(encoder_input)
    decoder_input = np.zeros(shape=(len(encoder_input), max_target_seq_length))
    decoder_input[:,0] = target_token_index['start_']
    for i in range(1, max_target_seq_length):
        output = model.predict([encoder_input, decoder_input]).argmax(axis=2)
        decoder_input[:,i] = output[:,i]
    for k in decoder_input[0]:
        if (reverse_target_char_index[k] == '_end'):
            decoded_sentence += ' '+reverse_target_char_index[k]
            break
        decoded_sentence += ' '+reverse_target_char_index[k]
    return decoded_sentence

# %%
#Here I am calling the decode function for the entire test set and giving the input the sequence of the words for test set.
#The model is giving the decoded output sequence from the same.
#I have used the NLTK library for the copus blue score calculation as a whole to be calucalted. This score is cumulative score.
#Cumulative scores refer to the calculation of individual n-gram scores at all orders from 1 to n and weighting them by calculating the weighted geometric mean.
#The weights for the BLEU-4 are 1/4 (25%) or 0.25 for each of the 1-gram, 2-gram, 3-gram and 4-gram scores
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.bleu_score import sentence_bleu
actual, predicted, ss = list(), list(),list()
for seq_index in range(len(encoder_input_data_test)):
    input_seq = encoder_input_data_test[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence_attention(input_seq)
    print('-')
    print('Input sentence:', input_texts_test[seq_index: seq_index + 1])
    print('Decoded sentence:', decoded_sentence)
    print('Original Sentence',target_texts_test[seq_index: seq_index + 1])
    actual.append([nltk.word_tokenize(str(target_texts_test[seq_index: seq_index + 1])[1:-1])])
    predicted.append(nltk.word_tokenize(str(decoded_sentence)))
    # calculate BLEU score
print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))
# Out:
# -
# Input sentence: ["let's pray."]
# Decoded sentence:  start_ je le voir . _end
# Original Sentence ['start_ prions ! _end']
# -
# Input sentence: ['when was that?']
# Decoded sentence:  start_ est-il fait ? _end
# Original Sentence ["start_ c'était quand\xa0? _end"]
# -
# Input sentence: ['i have no idea.']
# Decoded sentence:  start_ je n'ai pas une . _end
# Original Sentence ["start_ je n'en ai aucune idée. _end"]
# -
# Input sentence: ['be a man.']
# Decoded sentence:  start_ soyez un voiture ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ sois un homme ! _end']
# -
# Input sentence: ["i'm so hungry."]
# Decoded sentence:  start_ je suis très heureux . _end
# Original Sentence ["start_ j'ai tellement faim. _end"]
# -
# Input sentence: ["i'm a child."]
# Decoded sentence:  start_ je suis un chien . _end
# Original Sentence ['start_ je suis un enfant. _end']
# -
# Input sentence: ['tom is weak.']
# Decoded sentence:  start_ tom est en train de travailler . _end
# Original Sentence ['start_ tom est faible. _end']
# -
# Input sentence: ["i'll take one."]
# Decoded sentence:  start_ je vais le temps . _end
# Original Sentence ["start_ j'en prendrai une. _end"]
# -
# Input sentence: ['he has a maid.']
# Decoded sentence:  start_ il a un chien . _end
# Original Sentence ['start_ il a une servante. _end']
# -
# Input sentence: ['i survived.']
# Decoded sentence:  start_ je l'ai de été . _end
# Original Sentence ["start_ j'ai survécu. _end"]
# -
# Input sentence: ['i got upset.']
# Decoded sentence:  start_ j'ai été mal . _end
# Original Sentence ['start_ je me suis fâché. _end']
# -
# Input sentence: ["you're sloshed."]
# Decoded sentence:  start_ vous êtes ! ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ t'es bourré. _end"]
# -
# Input sentence: ['cows eat grass.']
# Decoded sentence:  start_ les êtes sont sont êtes-vous d'accord . _end
# Original Sentence ["start_ les vaches se nourrissent d'herbe. _end"]
# -
# Input sentence: ['were you shot?']
# Decoded sentence:  start_ êtes-vous blessé ? _end
# Original Sentence ['start_ vous a-t-on tiré dessus ? _end']
# -
# Input sentence: ['am i hired?']
# Decoded sentence:  start_ suis-je en train de moi ? _end
# Original Sentence ['start_ suis-je engagée ? _end']
# -
# Input sentence: ['this is boring.']
# Decoded sentence:  start_ c'est bizarre . _end
# Original Sentence ["start_ c'est ennuyeux. _end"]
# -
# Input sentence: ['are you mad?']
# Decoded sentence:  start_ êtes-vous blessé ? _end
# Original Sentence ['start_ êtes-vous fou ? _end']
# -
# Input sentence: ["don't complain."]
# Decoded sentence:  start_ ne me fais pas ! ! ! ! ! ! ! !
# Original Sentence ['start_ ne te plains pas. _end']
# -
# Input sentence: ['have a look.']
# Decoded sentence:  start_ reste ! ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ jetez un œil ! _end']
# -
# Input sentence: ["who's that?"]
# Decoded sentence:  start_ qui est là ? _end
# Original Sentence ['start_ qui est-ce\u202f? _end']
# -
# Input sentence: ['wonderful!']
# Decoded sentence:  start_ à la bonne _end
# Original Sentence ['start_ magnifique\u202f! _end']
# -
# Input sentence: ["it's complex."]
# Decoded sentence:  start_ c'est la mien . _end
# Original Sentence ["start_ c'est compliqué. _end"]
# -
# Input sentence: ["tom's cooking."]
# Decoded sentence:  start_ tom est déteste mary . _end
# Original Sentence ['start_ tom cuisine. _end']
# -
# Input sentence: ['can you help me?']
# Decoded sentence:  start_ pouvez-vous me voir ? _end
# Original Sentence ["start_ peux-tu m'aider ? _end"]
# -
# Input sentence: ['they gave up.']
# Decoded sentence:  start_ elles ont eu de lui . _end
# Original Sentence ['start_ ils abandonnèrent. _end']
# -
# Input sentence: ['yes, we can go.']
# Decoded sentence:  start_ ne le pouvons ? _end
# Original Sentence ['start_ oui, nous pouvons partir. _end']
# -
# Input sentence: ["i'll need this."]
# Decoded sentence:  start_ je le temps . _end
# Original Sentence ['start_ je vais avoir besoin de ceci. _end']
# -
# Input sentence: ["you're sad."]
# Decoded sentence:  start_ vous êtes mal . _end
# Original Sentence ['start_ tu es triste. _end']
# -
# Input sentence: ['you did it!']
# Decoded sentence:  start_ vous avez vu . _end
# Original Sentence ["start_ c'est toi qui l'as fait ! _end"]
# -
# Input sentence: ["she's pregnant."]
# Decoded sentence:  start_ elle est en train de pleurer . _end
# Original Sentence ['start_ elle attend un heureux événement. _end']
# -
# Input sentence: ['everyone smiled.']
# Decoded sentence:  start_ tout le monde a de monde été . _end
# Original Sentence ['start_ tout le monde sourit. _end']
# -
# Input sentence: ['watch the door.']
# Decoded sentence:  start_ prends la porte ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ surveille la porte ! _end']
# -
# Input sentence: ['i feel ashamed.']
# Decoded sentence:  start_ je me sens bien . _end
# Original Sentence ['start_ je me sens honteuse. _end']
# -
# Input sentence: ['what a waste!']
# Decoded sentence:  start_ quel quelle _end
# Original Sentence ['start_ quel gâchis ! _end']
# -
# Input sentence: ['guess who won.']
# Decoded sentence:  start_ personne ne l'ai _end
# Original Sentence ['start_ devine qui a gagné. _end']
# -
# Input sentence: ['i woke you up.']
# Decoded sentence:  start_ je vous ai besoin . _end
# Original Sentence ["start_ je t'ai réveillée. _end"]
# -
# Input sentence: ['pick a date.']
# Decoded sentence:  start_ une arme ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ choisis une date ! _end']
# -
# Input sentence: ['wake up.']
# Decoded sentence:  start_ venez à nous ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ réveillez-vous ! _end']
# -
# Input sentence: ['i want to help.']
# Decoded sentence:  start_ je veux y aller . _end
# Original Sentence ['start_ je veux aider. _end']
# -
# Input sentence: ['i am diabetic.']
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis diabétique. _end']
# -
# Input sentence: ['thanks a lot.']
# Decoded sentence:  start_ bonne bonne _end
# Original Sentence ['start_ mille mercis. _end']
# -
# Input sentence: ["i'm homesick."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ["start_ j'ai le mal du pays. _end"]
# -
# Input sentence: ["they're spies."]
# Decoded sentence:  start_ ils sont en train de mourir . _end
# Original Sentence ['start_ ce sont des espionnes. _end']
# -
# Input sentence: ['are you sincere?']
# Decoded sentence:  start_ êtes-vous êtes-vous ? _end
# Original Sentence ['start_ es-tu sincère ? _end']
# -
# Input sentence: ["don't leave us."]
# Decoded sentence:  start_ ne nous je sommes pas d'accord . _end
# Original Sentence ['start_ ne nous quittez pas ! _end']
# -
# Input sentence: ['be careful.']
# Decoded sentence:  start_ soyez prudente ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ soyez prudent ! _end']
# -
# Input sentence: ['go look for it.']
# Decoded sentence:  start_ viens le chercher . _end
# Original Sentence ['start_ va le chercher\u202f! _end']
# -
# Input sentence: ['i go to work.']
# Decoded sentence:  start_ je le temps . _end
# Original Sentence ['start_ je vais au travail. _end']
# -
# Input sentence: ['i have a dream.']
# Decoded sentence:  start_ j'ai un chien . _end
# Original Sentence ["start_ j'ai un rêve. _end"]
# -
# Input sentence: ["i'll buy it."]
# Decoded sentence:  start_ je le où je suis . _end
# Original Sentence ["start_ je l'achèterai. _end"]
# -
# Input sentence: ["i'd rather die."]
# Decoded sentence:  start_ je suis très occupé . _end
# Original Sentence ['start_ je préférerais mourir. _end']
# -
# Input sentence: ["i'll cancel."]
# Decoded sentence:  start_ je vais ai train de toi . _end
# Original Sentence ["start_ j'annulerai. _end"]
# -
# Input sentence: ['i am lazy.']
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis paresseuse. _end']
# -
# Input sentence: ['tom drowned.']
# Decoded sentence:  start_ tom est en train de travailler . _end
# Original Sentence ['start_ tom se noya. _end']
# -
# Input sentence: ['just forget it.']
# Decoded sentence:  start_ ça ça ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ oubliez ! _end']
# -
# Input sentence: ["i'm hungry!"]
# Decoded sentence:  start_ je suis prêt ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ j'ai faim ! _end"]
# -
# Input sentence: ["i'm no fool."]
# Decoded sentence:  start_ je ne suis pas un ? _end
# Original Sentence ['start_ je ne suis pas une idiote. _end']
# -
# Input sentence: ["they're clean."]
# Decoded sentence:  start_ elles sont en train de mourir . _end
# Original Sentence ['start_ elles sont propres. _end']
# -
# Input sentence: ['i love french.']
# Decoded sentence:  start_ j'adore le musique . _end
# Original Sentence ["start_ j'adore le français. _end"]
# -
# Input sentence: ['what fun!']
# Decoded sentence:  start_ c'est bien ! ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ qu'est-ce qu'on s'est marrés ! _end"]
# -
# Input sentence: ["i can't sing."]
# Decoded sentence:  start_ je ne peux pas à la maison . _end
# Original Sentence ['start_ je ne sais pas chanter. _end']
# -
# Input sentence: ['tom felt safe.']
# Decoded sentence:  start_ tom était en train de travailler . _end
# Original Sentence ["start_ tom s'est senti en sécurité. _end"]
# -
# Input sentence: ["they're wrong."]
# Decoded sentence:  start_ ils sont bien . _end
# Original Sentence ['start_ ils ont tort ! _end']
# -
# Input sentence: ['i called you.']
# Decoded sentence:  start_ je vous ai fait . _end
# Original Sentence ['start_ je vous ai appelé. _end']
# -
# Input sentence: ['you must do it.']
# Decoded sentence:  start_ tu peux en aller . _end
# Original Sentence ['start_ vous devez le faire. _end']
# -
# Input sentence: ["i've got you."]
# Decoded sentence:  start_ je vous ai fait . _end
# Original Sentence ['start_ je vous ai eu. _end']
# -
# Input sentence: ['come back home.']
# Decoded sentence:  start_ viens ici ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ reviens à la maison. _end']
# -
# Input sentence: ["it's ours."]
# Decoded sentence:  start_ c'est de la mien . _end
# Original Sentence ["start_ c'est la nôtre. _end"]
# -
# Input sentence: ["i'm chubby."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis grassouillette. _end']
# -
# Input sentence: ['they struggled.']
# Decoded sentence:  start_ elles ont eu de la chance . _end
# Original Sentence ['start_ elles ont morflé. _end']
# -
# Input sentence: ['run!']
# Decoded sentence:  start_ à la maison ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ courez\u202f! _end']
# -
# Input sentence: ['did that work?']
# Decoded sentence:  start_ ça a fait ? _end
# Original Sentence ['start_ ça a marché ? _end']
# -
# Input sentence: ["he's a big boy."]
# Decoded sentence:  start_ c'est un chien . _end
# Original Sentence ['start_ c’est un grand garçon. _end']
# -
# Input sentence: ['i want to work.']
# Decoded sentence:  start_ je veux le aller . _end
# Original Sentence ['start_ je veux travailler. _end']
# -
# Input sentence: ['use them all.']
# Decoded sentence:  start_ elles sont ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ utilise-les tous ! _end']
# -
# Input sentence: ['where is paris?']
# Decoded sentence:  start_ où est ? _end
# Original Sentence ['start_ où se trouve paris ? _end']
# -
# Input sentence: ['he is an actor.']
# Decoded sentence:  start_ il est un livre . _end
# Original Sentence ["start_ c'est un acteur. _end"]
# -
# Input sentence: ['he will come.']
# Decoded sentence:  start_ il nous pas du temps . _end
# Original Sentence ['start_ il devrait arriver. _end']
# -
# Input sentence: ['come down here.']
# Decoded sentence:  start_ viens ici ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ descends ici ! _end']
# -
# Input sentence: ['i made these.']
# Decoded sentence:  start_ j'ai des il pas . _end
# Original Sentence ["start_ j'ai confectionné ceux-ci. _end"]
# -
# Input sentence: ["that's alright."]
# Decoded sentence:  start_ c'est la temps . _end
# Original Sentence ["start_ ce n'est pas grave. _end"]
# -
# Input sentence: ['i will return.']
# Decoded sentence:  start_ je l'ai besoin de moi . _end
# Original Sentence ['start_ je reviendrai. _end']
# -
# Input sentence: ['loosen up.']
# Decoded sentence:  start_ arrête . _end
# Original Sentence ['start_ échauffez-vous ! _end']
# -
# Input sentence: ['i need a job.']
# Decoded sentence:  start_ j'ai besoin de mon chien . _end
# Original Sentence ["start_ j'ai besoin d'un boulot. _end"]
# -
# Input sentence: ['be yourself.']
# Decoded sentence:  start_ soyez _end
# Original Sentence ['start_ sois toi-même. _end']
# -
# Input sentence: ['you seem busy.']
# Decoded sentence:  start_ vous avez l'air occupé . _end
# Original Sentence ['start_ vous semblez occupées. _end']
# -
# Input sentence: ['i need a crew.']
# Decoded sentence:  start_ j'ai besoin de ma travail . _end
# Original Sentence ['start_ il me faut un équipage. _end']
# -
# Input sentence: ['were you hurt?']
# Decoded sentence:  start_ êtes-vous blessé ? _end
# Original Sentence ['start_ as-tu été blessée ? _end']
# -
# Input sentence: ["we'll be there."]
# Decoded sentence:  start_ nous ne sommes pas ici . _end
# Original Sentence ['start_ nous y serons. _end']
# -
# Input sentence: ["that's his."]
# Decoded sentence:  start_ c'est la temps . _end
# Original Sentence ['start_ ce sont les siens. _end']
# -
# Input sentence: ['good job!']
# Decoded sentence:  start_ bien bien ? _end
# Original Sentence ['start_ bon boulot\u202f! _end']
# -
# Input sentence: ['i love myself.']
# Decoded sentence:  start_ j'adore le j'adore . _end
# Original Sentence ["start_ je m'aime. _end"]
# -
# Input sentence: ['you look smart.']
# Decoded sentence:  start_ tu as l'air mal . _end
# Original Sentence ["start_ vous avez l'air intelligentes. _end"]
# -
# Input sentence: ['drive on.']
# Decoded sentence:  start_ la porte ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ avance ! _end']
# -
# Input sentence: ["i'm contagious."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis contagieuse. _end']
# -
# Input sentence: ["it's the best."]
# Decoded sentence:  start_ c'est mon fait . _end
# Original Sentence ["start_ c'est la meilleure. _end"]
# -
# Input sentence: ['i waited up.']
# Decoded sentence:  start_ je me suis en train de mourir . _end
# Original Sentence ["start_ j'ai veillé. _end"]
# -
# Input sentence: ['you are morons.']
# Decoded sentence:  start_ vous êtes des yeux . _end
# Original Sentence ['start_ vous êtes des attardés mentaux. _end']
# -
# Input sentence: ['see above.']
# Decoded sentence:  start_ restez , vous est . _end
# Original Sentence ['start_ voyez ci-dessus. _end']
# -
# Input sentence: ["it's dead."]
# Decoded sentence:  start_ il est ici . _end
# Original Sentence ['start_ elle est morte. _end']
# -
# Input sentence: ["you're clever."]
# Decoded sentence:  start_ vous êtes ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ vous êtes maline. _end']
# -
# Input sentence: ['tie your shoe.']
# Decoded sentence:  start_ attrape ton lacet . _end
# Original Sentence ['start_ nouez votre chaussure. _end']
# -
# Input sentence: ['what an idiot!']
# Decoded sentence:  start_ quel quelle _end
# Original Sentence ['start_ quel idiot. _end']
# -
# Input sentence: ['are you on dope?']
# Decoded sentence:  start_ êtes-vous en train de toi ? _end
# Original Sentence ['start_ êtes-vous drogués ? _end']
# -
# Input sentence: ['i surrender.']
# Decoded sentence:  start_ je l'ai de été . _end
# Original Sentence ['start_ je me rends. _end']
# -
# Input sentence: ["let's try this."]
# Decoded sentence:  start_ laissez-moi voir . _end
# Original Sentence ['start_ essayons ça. _end']
# -
# Input sentence: ['he was speaking.']
# Decoded sentence:  start_ il était en train de pleurer . _end
# Original Sentence ['start_ il était en train de parler. _end']
# -
# Input sentence: ['i outrank you.']
# Decoded sentence:  start_ je vous ai prie . _end
# Original Sentence ['start_ je passe avant toi. _end']
# -
# Input sentence: ["i'm not tall."]
# Decoded sentence:  start_ je ne suis pas un . _end
# Original Sentence ['start_ je ne suis pas grand. _end']
# -
# Input sentence: ['i can wait.']
# Decoded sentence:  start_ je peux en aller . _end
# Original Sentence ['start_ je peux attendre. _end']
# -
# Input sentence: ['who will pay?']
# Decoded sentence:  start_ qui veut nous ? _end
# Original Sentence ['start_ qui va payer\u202f? _end']
# -
# Input sentence: ["that's a shame."]
# Decoded sentence:  start_ c'est un voiture . _end
# Original Sentence ["start_ c'est honteux. _end"]
# -
# Input sentence: ["i'm too busy."]
# Decoded sentence:  start_ je suis très malade . _end
# Original Sentence ['start_ je suis trop affairé. _end']
# -
# Input sentence: ['are you home?']
# Decoded sentence:  start_ êtes-vous à la maison ? _end
# Original Sentence ['start_ es-tu chez toi ? _end']
# -
# Input sentence: ["it's no joke."]
# Decoded sentence:  start_ ce n'est pas un ! ! ! ! ! ! ! !
# Original Sentence ["start_ ce n'est pas une blague. _end"]
# -
# Input sentence: ['they fell.']
# Decoded sentence:  start_ ils ont se sont en train de sécurité . _end
# Original Sentence ['start_ elles sont tombées. _end']
# -
# Input sentence: ['you may go.']
# Decoded sentence:  start_ tu peux y aller . _end
# Original Sentence ['start_ vous pouvez vous en aller. _end']
# -
# Input sentence: ["i've upset you."]
# Decoded sentence:  start_ je vous ai fait . _end
# Original Sentence ['start_ je vous ai contrariés. _end']
# -
# Input sentence: ['is this legal?']
# Decoded sentence:  start_ est-ce que c'est est-ce ? _end
# Original Sentence ['start_ est-ce licite ? _end']
# -
# Input sentence: ['me, too.']
# Decoded sentence:  start_ tu as vu . _end
# Original Sentence ['start_ moi aussi. _end']
# -
# Input sentence: ['who built it?']
# Decoded sentence:  start_ qui a à qui ? _end
# Original Sentence ["start_ qui l'a bâti ? _end"]
# -
# Input sentence: ['speak quietly.']
# Decoded sentence:  start_ elles ont était de monde était de fois . _end
# Original Sentence ['start_ parle à voix basse. _end']
# -
# Input sentence: ['this is huge.']
# Decoded sentence:  start_ c'est la voiture . _end
# Original Sentence ["start_ c'est énorme. _end"]
# -
# Input sentence: ['you want this?']
# Decoded sentence:  start_ vous y a-t-il à vous ? _end
# Original Sentence ['start_ veux-tu ceci ? _end']
# -
# Input sentence: ['bring a date.']
# Decoded sentence:  start_ prends une voiture . _end
# Original Sentence ['start_ amène une copine ! _end']
# -
# Input sentence: ['are you relaxed?']
# Decoded sentence:  start_ êtes-vous êtes-vous ? _end
# Original Sentence ['start_ êtes-vous détendu ? _end']
# -
# Input sentence: ['what a hassle!']
# Decoded sentence:  start_ quel quelle _end
# Original Sentence ['start_ quelle histoire ! _end']
# -
# Input sentence: ["i'm not hurt."]
# Decoded sentence:  start_ je ne suis pas en sécurité . _end
# Original Sentence ['start_ je ne suis pas blessée. _end']
# -
# Input sentence: ['please smile.']
# Decoded sentence:  start_ s'il te plaît , s'il te plaît ! ! ! ! !
# Original Sentence ['start_ souriez, je vous prie ! _end']
# -
# Input sentence: ["don't panic!"]
# Decoded sentence:  start_ ne me fais pas ! ! ! ! ! ! ! !
# Original Sentence ['start_ ne panique pas\xa0! _end']
# -
# Input sentence: ["i don't get it."]
# Decoded sentence:  start_ je ne peux pas le faire . _end
# Original Sentence ['start_ je capte pas. _end']
# -
# Input sentence: ["i can't get in."]
# Decoded sentence:  start_ je ne peux pas en sécurité . _end
# Original Sentence ['start_ je ne parviens pas à y entrer. _end']
# -
# Input sentence: ['welcome home.']
# Decoded sentence:  start_ reste la porte ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ bienvenue à la maison. _end']
# -
# Input sentence: ['what a drag!']
# Decoded sentence:  start_ quel quelle _end
# Original Sentence ['start_ quel boulet ! _end']
# -
# Input sentence: ['they smiled.']
# Decoded sentence:  start_ ils ont se été . _end
# Original Sentence ['start_ elles ont souri. _end']
# -
# Input sentence: ["you'd like tom."]
# Decoded sentence:  start_ vous vous va un ? _end
# Original Sentence ['start_ tu aimerais tom. _end']
# -
# Input sentence: ['tom is quiet.']
# Decoded sentence:  start_ tom est en train de travailler . _end
# Original Sentence ['start_ tom est silencieux. _end']
# -
# Input sentence: ['set tom free.']
# Decoded sentence:  start_ mon _end
# Original Sentence ['start_ libère tom. _end']
# -
# Input sentence: ['god sent a sign.']
# Decoded sentence:  start_ dieu va une j'adore . _end
# Original Sentence ['start_ dieu envoya une pancarte. _end']
# -
# Input sentence: ['i could help.']
# Decoded sentence:  start_ je dois m'en aller . _end
# Original Sentence ['start_ je pourrais aider. _end']
# -
# Input sentence: ['i have no kids.']
# Decoded sentence:  start_ je le ai pas de moi . _end
# Original Sentence ["start_ je n'ai pas d'enfants. _end"]
# -
# Input sentence: ['dogs can swim.']
# Decoded sentence:  start_ les hommes les fais . _end
# Original Sentence ['start_ les chiens savent nager. _end']
# -
# Input sentence: ['we succeeded.']
# Decoded sentence:  start_ nous avons été . _end
# Original Sentence ['start_ nous avons réussi. _end']
# -
# Input sentence: ['he saved us all.']
# Decoded sentence:  start_ il nous nous a nous suis d'accord . _end
# Original Sentence ['start_ il nous a tous sauvés. _end']
# -
# Input sentence: ['i want to go.']
# Decoded sentence:  start_ je veux y aller . _end
# Original Sentence ['start_ je veux y aller. _end']
# -
# Input sentence: ['i said not now.']
# Decoded sentence:  start_ je n'ai pas dit . _end
# Original Sentence ["start_ j'ai dit : pas maintenant. _end"]
# -
# Input sentence: ["you're naive."]
# Decoded sentence:  start_ vous êtes ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ vous êtes naïfs. _end']
# -
# Input sentence: ['can he do it?']
# Decoded sentence:  start_ pouvons-nous voir ? _end
# Original Sentence ['start_ est-il en mesure de le faire ? _end']
# -
# Input sentence: ['you hurt me.']
# Decoded sentence:  start_ tu me me fais . _end
# Original Sentence ['start_ vous me faites mal. _end']
# -
# Input sentence: ['thanks a heap.']
# Decoded sentence:  start_ une peu un peu de chambre . _end
# Original Sentence ['start_ des tonnes de mercis ! _end']
# -
# Input sentence: ["you're safe."]
# Decoded sentence:  start_ tu es en train de toi . _end
# Original Sentence ['start_ vous êtes sauves. _end']
# -
# Input sentence: ["let's continue."]
# Decoded sentence:  start_ faites-le ceci ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ continuons ! _end']
# -
# Input sentence: ['he is a teacher.']
# Decoded sentence:  start_ c'est un chien . _end
# Original Sentence ['start_ il est enseignant. _end']
# -
# Input sentence: ['can we come in?']
# Decoded sentence:  start_ pouvons-nous nous en aller ? _end
# Original Sentence ['start_ pouvons-nous entrer ? _end']
# -
# Input sentence: ['i got carded.']
# Decoded sentence:  start_ j'ai été fait de avoir la maison . _end
# Original Sentence ["start_ on m'a demandé ma carte d'identité pour vérifier mon âge. _end"]
# -
# Input sentence: ['go now.']
# Decoded sentence:  start_ va à la maison . _end
# Original Sentence ['start_ va, maintenant. _end']
# -
# Input sentence: ['i found these.']
# Decoded sentence:  start_ j'ai des temps . _end
# Original Sentence ["start_ j'ai trouvé ceux-ci. _end"]
# -
# Input sentence: ['i will work.']
# Decoded sentence:  start_ je le temps . _end
# Original Sentence ['start_ je travaillerai. _end']
# -
# Input sentence: ['this is life!']
# Decoded sentence:  start_ c'est de la voiture . _end
# Original Sentence ["start_ c'est la vie\u202f! _end"]
# -
# Input sentence: ['i like fishing.']
# Decoded sentence:  start_ j'aime le travail . _end
# Original Sentence ["start_ j'aime pêcher. _end"]
# -
# Input sentence: ['no one told me.']
# Decoded sentence:  start_ personne ne le dit . _end
# Original Sentence ["start_ personne ne me l'a dit. _end"]
# -
# Input sentence: ["we're fine."]
# Decoded sentence:  start_ nous sommes . _end
# Original Sentence ['start_ nous allons bien. _end']
# -
# Input sentence: ['i like cities.']
# Decoded sentence:  start_ j'aime le café . _end
# Original Sentence ["start_ j'aime les villes. _end"]
# -
# Input sentence: ['he was invited.']
# Decoded sentence:  start_ il a été il pas de pleurer . _end
# Original Sentence ['start_ il était invité. _end']
# -
# Input sentence: ['war is evil.']
# Decoded sentence:  start_ le voici est . _end
# Original Sentence ['start_ la guerre est mauvaise. _end']
# -
# Input sentence: ["don't remind me."]
# Decoded sentence:  start_ ne me fais pas de vous de mal . _end
# Original Sentence ['start_ ne me le rappelez pas ! _end']
# -
# Input sentence: ['i got bored.']
# Decoded sentence:  start_ je suis en train de mourir . _end
# Original Sentence ["start_ j'ai commencé à m'ennuyer. _end"]
# -
# Input sentence: ['have you slept?']
# Decoded sentence:  start_ êtes-vous en train de qui ? _end
# Original Sentence ['start_ as-tu dormi ? _end']
# -
# Input sentence: ['he works a lot.']
# Decoded sentence:  start_ il a besoin de travail . _end
# Original Sentence ['start_ il travaille beaucoup. _end']
# -
# Input sentence: ["he's so young."]
# Decoded sentence:  start_ il est trop grand . _end
# Original Sentence ['start_ il est tellement jeune. _end']
# -
# Input sentence: ["don't shoot!"]
# Decoded sentence:  start_ ne me fais pas ! ! ! ! ! ! ! !
# Original Sentence ['start_ ne tire pas ! _end']
# -
# Input sentence: ['eat everything.']
# Decoded sentence:  start_ les yeux . _end
# Original Sentence ['start_ mange tout. _end']
# -
# Input sentence: ['tom was upset.']
# Decoded sentence:  start_ tom a été fait . _end
# Original Sentence ['start_ tom était contrarié. _end']
# -
# Input sentence: ['i got fined.']
# Decoded sentence:  start_ j'ai été fait . _end
# Original Sentence ["start_ on m'a collé une amende. _end"]
# -
# Input sentence: ["they're cold."]
# Decoded sentence:  start_ elles sont en train de mourir . _end
# Original Sentence ['start_ elles sont froides. _end']
# -
# Input sentence: ['excuse me.']
# Decoded sentence:  start_ soyez ! ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ excuse-moi. _end']
# -
# Input sentence: ['she is old.']
# Decoded sentence:  start_ elle est à la maison . _end
# Original Sentence ['start_ elle est vieille. _end']
# -
# Input sentence: ["i've decided."]
# Decoded sentence:  start_ je l'ai vu . _end
# Original Sentence ["start_ j'ai décidé. _end"]
# -
# Input sentence: ['are we safe?']
# Decoded sentence:  start_ sommes-nous sommes-nous maison ? _end
# Original Sentence ['start_ sommes-nous en sécurité ? _end']
# -
# Input sentence: ['i was excited.']
# Decoded sentence:  start_ j'étais en train de moi . _end
# Original Sentence ["start_ j'étais excité. _end"]
# -
# Input sentence: ["i'm just lazy."]
# Decoded sentence:  start_ je suis très fatigué . _end
# Original Sentence ['start_ je suis juste paresseux. _end']
# -
# Input sentence: ['i believe it.']
# Decoded sentence:  start_ je le veux . _end
# Original Sentence ['start_ je le crois. _end']
# -
# Input sentence: ["it's cold."]
# Decoded sentence:  start_ c'est bien . _end
# Original Sentence ['start_ il fait froid. _end']
# -
# Input sentence: ['i love horses.']
# Decoded sentence:  start_ j'adore les déteste . _end
# Original Sentence ["start_ j'adore les chevaux. _end"]
# -
# Input sentence: ["we're not sure."]
# Decoded sentence:  start_ nous ne sommes pas en sécurité . _end
# Original Sentence ['start_ nous ne sommes pas sûrs. _end']
# -
# Input sentence: ['eat your peas.']
# Decoded sentence:  start_ merci de vous chambre . _end
# Original Sentence ['start_ mangez vos petits pois. _end']
# -
# Input sentence: ['all is still.']
# Decoded sentence:  start_ il est en sécurité . _end
# Original Sentence ['start_ tout est calme. _end']
# -
# Input sentence: ["i'm innocent."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis ingénu. _end']
# -
# Input sentence: ['open the doors.']
# Decoded sentence:  start_ prends la porte ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ ouvrez les portes ! _end']
# -
# Input sentence: ['he became rich.']
# Decoded sentence:  start_ il est en train de travailler . _end
# Original Sentence ['start_ il est devenu riche. _end']
# -
# Input sentence: ['i was naive.']
# Decoded sentence:  start_ j'ai été malade . _end
# Original Sentence ["start_ j'étais crédule. _end"]
# -
# Input sentence: ['tom is slow.']
# Decoded sentence:  start_ tom est fait tard . _end
# Original Sentence ['start_ tom est lent. _end']
# -
# Input sentence: ["that's evident."]
# Decoded sentence:  start_ c'est . _end
# Original Sentence ["start_ c'est manifeste. _end"]
# -
# Input sentence: ["you're a liar."]
# Decoded sentence:  start_ tu es un _end
# Original Sentence ['start_ vous êtes une menteuse. _end']
# -
# Input sentence: ['he avoids me.']
# Decoded sentence:  start_ il m'a fait de elle . _end
# Original Sentence ["start_ il m'évite. _end"]
# -
# Input sentence: ["i wasn't hired."]
# Decoded sentence:  start_ je ne suis pas en sécurité . _end
# Original Sentence ["start_ on ne m'a pas embauché. _end"]
# -
# Input sentence: ['you are good.']
# Decoded sentence:  start_ vous êtes en train de vous . _end
# Original Sentence ['start_ vous êtes bonne. _end']
# -
# Input sentence: ['he looked well.']
# Decoded sentence:  start_ il a l'air malade . _end
# Original Sentence ["start_ il avait l'air en bonne santé. _end"]
# -
# Input sentence: ["you're loaded."]
# Decoded sentence:  start_ vous êtes ! ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ t'es plein de fric. _end"]
# -
# Input sentence: ['turn it up.']
# Decoded sentence:  start_ laisse ceci . _end
# Original Sentence ['start_ montez-le. _end']
# -
# Input sentence: ['i like sweets.']
# Decoded sentence:  start_ j'aime les ? _end
# Original Sentence ["start_ j'aime les sucreries. _end"]
# -
# Input sentence: ['relax a moment.']
# Decoded sentence:  start_ un très une _end
# Original Sentence ['start_ détends-toi un instant ! _end']
# -
# Input sentence: ['you were shy.']
# Decoded sentence:  start_ vous monde étais en train de mourir . _end
# Original Sentence ['start_ vous étiez timide. _end']
# -
# Input sentence: ['he walked away.']
# Decoded sentence:  start_ il est en train de pleurer . _end
# Original Sentence ['start_ il partit. _end']
# -
# Input sentence: ['i feel happy.']
# Decoded sentence:  start_ je me sens bien . _end
# Original Sentence ['start_ je me sens heureux. _end']
# -
# Input sentence: ['be nice.']
# Decoded sentence:  start_ soyez soyez ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ soyez gentille ! _end']
# -
# Input sentence: ["it's close by."]
# Decoded sentence:  start_ il est en sécurité . _end
# Original Sentence ["start_ c'est à proximité. _end"]
# -
# Input sentence: ["let's end this."]
# Decoded sentence:  start_ je voir . _end
# Original Sentence ['start_ finissons ça. _end']
# -
# Input sentence: ['dogs bark.']
# Decoded sentence:  start_ les filles adore les il ! ! ! ! ! ! !
# Original Sentence ['start_ des chiens aboient. _end']
# -
# Input sentence: ["don't smile."]
# Decoded sentence:  start_ ne sois pas ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ ne souriez pas. _end']
# -
# Input sentence: ["don't wait up."]
# Decoded sentence:  start_ ne me fais pas de aller . _end
# Original Sentence ['start_ ne veillez pas. _end']
# -
# Input sentence: ["she's a model."]
# Decoded sentence:  start_ c'est un livre . _end
# Original Sentence ["start_ c'est un mannequin. _end"]
# -
# Input sentence: ["we'll try."]
# Decoded sentence:  start_ nous pouvons y aller . _end
# Original Sentence ['start_ nous essayerons. _end']
# -
# Input sentence: ["i'm sorry."]
# Decoded sentence:  start_ je suis à toi . _end
# Original Sentence ['start_ excusez-moi. _end']
# -
# Input sentence: ['did that work?']
# Decoded sentence:  start_ ça a fait ? _end
# Original Sentence ['start_ ça a fonctionné ? _end']
# -
# Input sentence: ["you're good."]
# Decoded sentence:  start_ vous êtes bien . _end
# Original Sentence ['start_ vous êtes bonnes. _end']
# -
# Input sentence: ['tom drowned.']
# Decoded sentence:  start_ tom est en train de travailler . _end
# Original Sentence ["start_ tom s'est noyé. _end"]
# -
# Input sentence: ['i want you.']
# Decoded sentence:  start_ je vous ai fait . _end
# Original Sentence ['start_ je te veux ! _end']
# -
# Input sentence: ['i do like you.']
# Decoded sentence:  start_ je vous ai fait le toi . _end
# Original Sentence ["start_ je t'apprécie vraiment. _end"]
# -
# Input sentence: ["i'll be back."]
# Decoded sentence:  start_ je vais le aller . _end
# Original Sentence ['start_ je reviendrai. _end']
# -
# Input sentence: ['i have food.']
# Decoded sentence:  start_ j'ai des vie . _end
# Original Sentence ['start_ je dispose de nourriture. _end']
# -
# Input sentence: ['ask anybody.']
# Decoded sentence:  start_ demande à qui non ! ! ! ! ! ! ! !
# Original Sentence ["start_ demandez à n'importe qui ! _end"]
# -
# Input sentence: ['are ghosts real?']
# Decoded sentence:  start_ es-tu en train de ? _end
# Original Sentence ['start_ les fantômes sont-ils réels\xa0? _end']
# -
# Input sentence: ['tom is joking.']
# Decoded sentence:  start_ tom est en train de travailler . _end
# Original Sentence ['start_ tom plaisante. _end']
# -
# Input sentence: ['tom took it.']
# Decoded sentence:  start_ tom a été . _end
# Original Sentence ["start_ tom l'a pris. _end"]
# -
# Input sentence: ['is that tom?']
# Decoded sentence:  start_ est-ce que tom est tom tom ? _end
# Original Sentence ['start_ est-ce tom\xa0? _end']
# -
# Input sentence: ['stay positive.']
# Decoded sentence:  start_ reste tranquille ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ reste positive ! _end']
# -
# Input sentence: ['can i touch it?']
# Decoded sentence:  start_ puis-je me voir ? _end
# Original Sentence ['start_ puis-je la toucher ? _end']
# -
# Input sentence: ['do you remember?']
# Decoded sentence:  start_ vous vous l'air ? _end
# Original Sentence ['start_ est-ce que vous vous souvenez\u202f? _end']
# -
# Input sentence: ['will you go?']
# Decoded sentence:  start_ comment est-ce à voir ? _end
# Original Sentence ['start_ irez-vous ? _end']
# -
# Input sentence: ['feed the bird.']
# Decoded sentence:  start_ les filles sont . _end
# Original Sentence ["start_ nourris l'oiseau\u202f! _end"]
# -
# Input sentence: ['who are they?']
# Decoded sentence:  start_ qui sommes-nous ? _end
# Original Sentence ['start_ qui sont-elles\u202f? _end']
# -
# Input sentence: ['i lost my key.']
# Decoded sentence:  start_ j'ai la déteste mon travail . _end
# Original Sentence ['start_ je perdis la clef. _end']
# -
# Input sentence: ["i'm too busy."]
# Decoded sentence:  start_ je suis très malade . _end
# Original Sentence ['start_ je suis trop affairée. _end']
# -
# Input sentence: ['he shall die.']
# Decoded sentence:  start_ il a des il pas courir . _end
# Original Sentence ['start_ il doit mourir. _end']
# -
# Input sentence: ['lighten up.']
# Decoded sentence:  start_ arrête de vous de yeux . _end
# Original Sentence ['start_ relaxe ! _end']
# -
# Input sentence: ['we kept quiet.']
# Decoded sentence:  start_ nous sommes en train de . _end
# Original Sentence ['start_ nous restâmes silencieux. _end']
# -
# Input sentence: ["you're nuts!"]
# Decoded sentence:  start_ vous êtes ! ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ t'es dingue ! _end"]
# -
# Input sentence: ["i'm surprised."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis surprise. _end']
# -
# Input sentence: ["i'm fasting."]
# Decoded sentence:  start_ je suis au lit . _end
# Original Sentence ['start_ je suis à la diète. _end']
# -
# Input sentence: ['he looks well.']
# Decoded sentence:  start_ il est trop elle . _end
# Original Sentence ["start_ il a l'air en bonne santé. _end"]
# -
# Input sentence: ['tom is a crook.']
# Decoded sentence:  start_ tom est un . _end
# Original Sentence ['start_ tom est un escroc. _end']
# -
# Input sentence: ["we're in pain."]
# Decoded sentence:  start_ nous sommes en train de la maison . _end
# Original Sentence ['start_ nous souffrons. _end']
# -
# Input sentence: ['this is mine.']
# Decoded sentence:  start_ c'est la voiture . _end
# Original Sentence ["start_ c'est le mien. _end"]
# -
# Input sentence: ["i'm a genius."]
# Decoded sentence:  start_ je suis un héros . _end
# Original Sentence ['start_ je suis un génie. _end']
# -
# Input sentence: ['i love nature.']
# Decoded sentence:  start_ j'adore le j'adore . _end
# Original Sentence ["start_ j'adore la nature. _end"]
# -
# Input sentence: ["it's unlikely."]
# Decoded sentence:  start_ c'est c'est . _end
# Original Sentence ["start_ c'est improbable. _end"]
# -
# Input sentence: ['go to the store.']
# Decoded sentence:  start_ allez au lit ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ va au magasin ! _end']
# -
# Input sentence: ['everybody knew.']
# Decoded sentence:  start_ nous avez été . _end
# Original Sentence ['start_ tout le monde savait. _end']
# -
# Input sentence: ["i'm forgetful."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis étourdie. _end']
# -
# Input sentence: ['did i wake you?']
# Decoded sentence:  start_ ai-je fait le ? _end
# Original Sentence ['start_ vous ai-je réveillés ? _end']
# -
# Input sentence: ['run for it!']
# Decoded sentence:  start_ prends la porte ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ prenez vos jambes à vos cous ! _end']
# -
# Input sentence: ["who's winning?"]
# Decoded sentence:  start_ qui est là ? _end
# Original Sentence ["start_ qui l'emporte ? _end"]
# -
# Input sentence: ['i read books.']
# Decoded sentence:  start_ j'adore les _end
# Original Sentence ['start_ je lis des livres. _end']
# -
# Input sentence: ['he loves coffee.']
# Decoded sentence:  start_ il aime le il que je a train de pleurer . _end
# Original Sentence ['start_ il adore le café. _end']
# -
# Input sentence: ['we surrendered.']
# Decoded sentence:  start_ nous nous sommes en train de sécurité . _end
# Original Sentence ['start_ nous nous sommes rendues. _end']
# -
# Input sentence: ['tom knew.']
# Decoded sentence:  start_ tom a été . _end
# Original Sentence ['start_ tom savait. _end']
# -
# Input sentence: ['this is his.']
# Decoded sentence:  start_ c'est la voiture . _end
# Original Sentence ["start_ c'est la sienne. _end"]
# -
# Input sentence: ['am i boring you?']
# Decoded sentence:  start_ suis-je en train de ? _end
# Original Sentence ['start_ est-ce que je vous ennuie ? _end']
# -
# Input sentence: ['i felt excited.']
# Decoded sentence:  start_ je me suis senti mal . _end
# Original Sentence ['start_ je me sentais énervé. _end']
# -
# Input sentence: ['who built it?']
# Decoded sentence:  start_ qui a à qui ? _end
# Original Sentence ["start_ qui l'a construit\u202f? _end"]
# -
# Input sentence: ['did you drop it?']
# Decoded sentence:  start_ l'as-tu fait ? _end
# Original Sentence ["start_ l'avez-vous débarqué ? _end"]
# -
# Input sentence: ['no one cheated.']
# Decoded sentence:  start_ personne ne le ce pas . _end
# Original Sentence ['start_ personne ne tricha. _end']
# -
# Input sentence: ['she helps us.']
# Decoded sentence:  start_ il a besoin de moi . _end
# Original Sentence ['start_ elle nous aide. _end']
# -
# Input sentence: ['tom draws well.']
# Decoded sentence:  start_ tom va des il pas . _end
# Original Sentence ['start_ tom dessine bien. _end']
# -
# Input sentence: ["i'm too drunk."]
# Decoded sentence:  start_ je suis très malade . _end
# Original Sentence ['start_ je suis trop saoul. _end']
# -
# Input sentence: ['throw the dice.']
# Decoded sentence:  start_ une c'est ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ jetez le dé. _end']
# -
# Input sentence: ['turn the page.']
# Decoded sentence:  start_ prenez la maison . _end
# Original Sentence ['start_ tourne la page. _end']
# -
# Input sentence: ['no way!']
# Decoded sentence:  start_ c'est ! ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ hors de question ! _end']
# -
# Input sentence: ['dance with me.']
# Decoded sentence:  start_ regarde bien . _end
# Original Sentence ['start_ dansez avec moi. _end']
# -
# Input sentence: ["he can't do it."]
# Decoded sentence:  start_ il ne le ne sait pas . _end
# Original Sentence ['start_ il est incapable de le faire. _end']
# -
# Input sentence: ["you're famous."]
# Decoded sentence:  start_ vous êtes bien . _end
# Original Sentence ['start_ tu es connue. _end']
# -
# Input sentence: ["we're helpless."]
# Decoded sentence:  start_ nous sommes en train de nous ! ! ! ! ! !
# Original Sentence ['start_ nous sommes impuissants. _end']
# -
# Input sentence: ['i beg you.']
# Decoded sentence:  start_ je vous le aller . _end
# Original Sentence ['start_ je vous en conjure. _end']
# -
# Input sentence: ['do you remember?']
# Decoded sentence:  start_ vous vous l'air ? _end
# Original Sentence ['start_ tu te souviens\u202f? _end']
# -
# Input sentence: ['i ran outside.']
# Decoded sentence:  start_ je l'ai train de travailler . _end
# Original Sentence ["start_ j'ai couru à l'extérieur. _end"]
# -
# Input sentence: ['he dozed off.']
# Decoded sentence:  start_ il a été deux . _end
# Original Sentence ["start_ il s'est endormi. _end"]
# -
# Input sentence: ['a car hit tom.']
# Decoded sentence:  start_ tom est une voiture . _end
# Original Sentence ['start_ tom a été heurté par une voiture. _end']
# -
# Input sentence: ["don't be upset."]
# Decoded sentence:  start_ ne sois pas si malade . _end
# Original Sentence ['start_ ne sois pas contrariée ! _end']
# -
# Input sentence: ['be respectful.']
# Decoded sentence:  start_ soyez prudente ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ sois respectueux ! _end']
# -
# Input sentence: ['air the futon.']
# Decoded sentence:  start_ la porte ici . _end
# Original Sentence ['start_ aérez le futon ! _end']
# -
# Input sentence: ['we need rules.']
# Decoded sentence:  start_ nous avons besoin de toi . _end
# Original Sentence ['start_ il nous faut des règles. _end']
# -
# Input sentence: ['i said yes.']
# Decoded sentence:  start_ je l'ai dit ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ j'ai dit oui. _end"]
# -
# Input sentence: ['i feel alive.']
# Decoded sentence:  start_ je me sens mal à moi . _end
# Original Sentence ['start_ je me sens vivant. _end']
# -
# Input sentence: ['they let me go.']
# Decoded sentence:  start_ ils m'ont laissé partir . _end
# Original Sentence ["start_ elles m'ont laissée m'en aller. _end"]
# -
# Input sentence: ['anybody will do.']
# Decoded sentence:  start_ personne le faire . _end
# Original Sentence ["start_ n'importe qui fera l'affaire. _end"]
# -
# Input sentence: ['i must see you.']
# Decoded sentence:  start_ je peux y aller . _end
# Original Sentence ['start_ il me faut vous voir. _end']
# -
# Input sentence: ['you need a job.']
# Decoded sentence:  start_ tu es un j'aime ! ! ! ! ! ! ! !
# Original Sentence ['start_ il te faut un boulot. _end']
# -
# Input sentence: ['tom is happy.']
# Decoded sentence:  start_ tom est en sécurité . _end
# Original Sentence ['start_ tom est content. _end']
# -
# Input sentence: ["i'm so unlucky!"]
# Decoded sentence:  start_ je suis pas heureux . _end
# Original Sentence ["start_ quelle poisse j'ai\u202f! _end"]
# -
# Input sentence: ["he's an outlaw."]
# Decoded sentence:  start_ c'est un chien . _end
# Original Sentence ["start_ c'est un hors-la-loi. _end"]
# -
# Input sentence: ['were you busy?']
# Decoded sentence:  start_ êtes-vous blessé ? _end
# Original Sentence ['start_ étais-tu occupé ? _end']
# -
# Input sentence: ["that's evident."]
# Decoded sentence:  start_ c'est . _end
# Original Sentence ["start_ c'est visible. _end"]
# -
# Input sentence: ['i like oysters.']
# Decoded sentence:  start_ j'aime les déteste . _end
# Original Sentence ["start_ j'aime les huîtres. _end"]
# -
# Input sentence: ['is it yours?']
# Decoded sentence:  start_ est-ce que c'est à la maison ? _end
# Original Sentence ['start_ est-ce à toi\u202f? _end']
# -
# Input sentence: ['i was pleased.']
# Decoded sentence:  start_ j'étais en train de moi . _end
# Original Sentence ["start_ j'ai été content. _end"]
# -
# Input sentence: ["you're silly."]
# Decoded sentence:  start_ vous êtes ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ vous êtes idiote. _end']
# -
# Input sentence: ['come join us.']
# Decoded sentence:  start_ venez nous vous en train de vous . _end
# Original Sentence ['start_ viens nous rejoindre ! _end']
# -
# Input sentence: ['i want cash.']
# Decoded sentence:  start_ je veux le temps . _end
# Original Sentence ['start_ je veux du liquide. _end']
# -
# Input sentence: ['stop arguing.']
# Decoded sentence:  start_ arrête de vous . _end
# Original Sentence ['start_ arrête de te quereller ! _end']
# -
# Input sentence: ["we'll starve."]
# Decoded sentence:  start_ nous en es ? _end
# Original Sentence ['start_ nous mourrons de faim. _end']
# -
# Input sentence: ['we all cried.']
# Decoded sentence:  start_ nous nous sommes . _end
# Original Sentence ['start_ nous avons toutes pleuré. _end']
# -
# Input sentence: ['i guarantee it.']
# Decoded sentence:  start_ je ne suis pas de . _end
# Original Sentence ['start_ je le garantis. _end']
# -
# Input sentence: ['bring it here.']
# Decoded sentence:  start_ prenez la voiture ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ apportez-le ici. _end']
# -
# Input sentence: ["they're babies."]
# Decoded sentence:  start_ elles sont en train de mourir . _end
# Original Sentence ['start_ ce sont des bébés. _end']
# -
# Input sentence: ['i was relaxed.']
# Decoded sentence:  start_ j'étais en train de mourir . _end
# Original Sentence ["start_ j'étais détendue. _end"]
# -
# Input sentence: ["i'm the killer."]
# Decoded sentence:  start_ je suis un héros . _end
# Original Sentence ['start_ je suis le tueur. _end']
# -
# Input sentence: ['did tom find it?']
# Decoded sentence:  start_ tom a l'air fait ? _end
# Original Sentence ["start_ tom l'a-t-il trouvé\xa0? _end"]
# -
# Input sentence: ['it stinks.']
# Decoded sentence:  start_ ça a fait de ça . _end
# Original Sentence ['start_ ça pue. _end']
# -
# Input sentence: ['he needs you.']
# Decoded sentence:  start_ il a besoin de toi . _end
# Original Sentence ['start_ il a besoin de vous. _end']
# -
# Input sentence: ["don't interrupt."]
# Decoded sentence:  start_ ne sois pas ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ n'interrompez pas ! _end"]
# -
# Input sentence: ['i phoned.']
# Decoded sentence:  start_ j'ai des j'étais . _end
# Original Sentence ["start_ j'ai téléphoné. _end"]
# -
# Input sentence: ['how do i look?']
# Decoded sentence:  start_ comment ne sait pas ? _end
# Original Sentence ["start_ de quoi ai-je l'air ? _end"]
# -
# Input sentence: ['it made sense.']
# Decoded sentence:  start_ ça a fait de ça . _end
# Original Sentence ["start_ c'était logique. _end"]
# -
# Input sentence: ["it's missing."]
# Decoded sentence:  start_ il est en de . _end
# Original Sentence ['start_ ça fait défaut. _end']
# -
# Input sentence: ["don't ask me."]
# Decoded sentence:  start_ ne me fais pas . _end
# Original Sentence ["start_ ce n'est pas à moi qu'il faut le demander. _end"]
# -
# Input sentence: ["he's not going."]
# Decoded sentence:  start_ il n'est pas à lui . _end
# Original Sentence ["start_ il n'y va pas. _end"]
# -
# Input sentence: ["it's what i am."]
# Decoded sentence:  start_ ce n'est pas ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ c'est ce que je suis. _end"]
# -
# Input sentence: ['i got scammed.']
# Decoded sentence:  start_ j'ai été malade . _end
# Original Sentence ["start_ j'ai été arnaqué. _end"]
# -
# Input sentence: ["i'm not sure."]
# Decoded sentence:  start_ je ne suis pas en sécurité . _end
# Original Sentence ["start_ je n'en suis pas certain. _end"]
# -
# Input sentence: ['we like tom.']
# Decoded sentence:  start_ nous vous a de tom . _end
# Original Sentence ['start_ nous aimons bien tom. _end']
# -
# Input sentence: ['he is no fool.']
# Decoded sentence:  start_ il n'est pas à faire . _end
# Original Sentence ["start_ il n'est pas idiot. _end"]
# -
# Input sentence: ['no one knew it.']
# Decoded sentence:  start_ personne ne le n'est pas . _end
# Original Sentence ['start_ personne ne le sut. _end']
# -
# Input sentence: ['i understand.']
# Decoded sentence:  start_ il me faut . _end
# Original Sentence ['start_ je comprends. _end']
# -
# Input sentence: ['try to resist.']
# Decoded sentence:  start_ essaie de nouveau . _end
# Original Sentence ['start_ essayez de résister. _end']
# -
# Input sentence: ["i'm psyched."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis remonté. _end']
# -
# Input sentence: ['am i included?']
# Decoded sentence:  start_ suis-je en train de moi ? _end
# Original Sentence ['start_ suis-je incluse ? _end']
# -
# Input sentence: ['try this cake.']
# Decoded sentence:  start_ essaie de . _end
# Original Sentence ['start_ essayez ce gâteau. _end']
# -
# Input sentence: ["i'm on my way."]
# Decoded sentence:  start_ je suis à la maison . _end
# Original Sentence ['start_ je suis en chemin. _end']
# -
# Input sentence: ["you're so mean."]
# Decoded sentence:  start_ vous êtes si fait . _end
# Original Sentence ['start_ vous êtes si méchant. _end']
# -
# Input sentence: ['do i stink?']
# Decoded sentence:  start_ vous ai-je fait le ? _end
# Original Sentence ['start_ est-ce que je pue ? _end']
# -
# Input sentence: ['hurry up, guys.']
# Decoded sentence:  start_ viens , nous pas de nous ! ! ! ! ! !
# Original Sentence ['start_ magnez-vous, les mecs ! _end']
# -
# Input sentence: ['hi, guys.']
# Decoded sentence:  start_ le sont est ? _end
# Original Sentence ['start_ salut, les mecs ! _end']
# -
# Input sentence: ['i like tom.']
# Decoded sentence:  start_ j'aime tom . _end
# Original Sentence ["start_ j'aime tom. _end"]
# -
# Input sentence: ['i tried hard.']
# Decoded sentence:  start_ j'ai des temps . _end
# Original Sentence ["start_ j'ai essayé de toutes mes forces. _end"]
# -
# Input sentence: ["i'm meditating."]
# Decoded sentence:  start_ je suis en train de toi . _end
# ...
# Original Sentence ["start_ j'irai me changer. _end"]
# -
# Input sentence: ["we can't fail."]
# Decoded sentence:  start_ nous ne pouvons pas en sécurité . _end
# Original Sentence ['start_ nous ne pouvons pas échouer. _end']
# -
# Input sentence: ['are you young?']
# Decoded sentence:  start_ êtes-vous blessé ? _end
# Original Sentence ['start_ êtes-vous jeune ? _end']
# -
# Input sentence: ['he shot at me.']
# Decoded sentence:  start_ il m'a m'a train de pleurer . _end
# Original Sentence ['start_ il me tira dessus. _end']
# -
# Input sentence: ["you're skinny."]
# Decoded sentence:  start_ vous êtes en train de vous . _end
# Original Sentence ['start_ vous êtes maigrichon. _end']
# -
# Input sentence: ['abandon ship!']
# Decoded sentence:  start_ arrête de hurler ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ abandonnez le navire ! _end']
# -
# Input sentence: ["we're sloshed."]
# Decoded sentence:  start_ nous sommes en train de mourir . _end
# Original Sentence ['start_ nous sommes bourrés. _end']
# -
# Input sentence: ['be a good girl.']
# Decoded sentence:  start_ soyez un homme ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ sois une chic fille ! _end']
# -
# Input sentence: ["you're a liar."]
# Decoded sentence:  start_ tu es un _end
# Original Sentence ['start_ vous êtes un menteur. _end']
# -
# Input sentence: ["don't wait."]
# Decoded sentence:  start_ ne sois pas en sécurité . _end
# Original Sentence ["start_ n'attendez pas ! _end"]
# -
# Input sentence: ['everyone gasps.']
# Decoded sentence:  start_ tout le monde ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ tout le monde est en haleine. _end']
# -
# Input sentence: ['i like r & b.']
# Decoded sentence:  start_ tom a besoin de travail . _end
# Original Sentence ["start_ j'aime le r&b. _end"]
# -
# Input sentence: ["i wasn't hired."]
# Decoded sentence:  start_ je ne suis pas en sécurité . _end
# Original Sentence ["start_ on ne m'a pas recruté. _end"]
# -
# Input sentence: ['i felt safe.']
# Decoded sentence:  start_ je me suis senti mal . _end
# Original Sentence ['start_ je me suis senti en sécurité. _end']
# -
# Input sentence: ["let's begin."]
# Decoded sentence:  start_ laisse tomber . _end
# Original Sentence ['start_ commençons ! _end']
# -
# Input sentence: ['any questions?']
# Decoded sentence:  start_ est-ce que je plaît ? _end
# Original Sentence ['start_ des questions ? _end']
# -
# Input sentence: ["i'm the best."]
# Decoded sentence:  start_ je suis à la maison . _end
# Original Sentence ['start_ je suis le meilleur. _end']
# -
# Input sentence: ['we can try it.']
# Decoded sentence:  start_ nous pouvons y aller . _end
# Original Sentence ["start_ nous pouvons l'essayer. _end"]
# -
# Input sentence: ['i cut myself.']
# Decoded sentence:  start_ je me ai fait tomber . _end
# Original Sentence ['start_ je me suis coupée. _end']
# -
# Input sentence: ['i rescheduled.']
# Decoded sentence:  start_ je l'ai train de mourir . _end
# Original Sentence ["start_ j'ai décalé. _end"]
# -
# Input sentence: ['he let us go.']
# Decoded sentence:  start_ il nous a nous aller . _end
# Original Sentence ['start_ il nous laissa partir. _end']
# -
# Input sentence: ['are you jealous?']
# Decoded sentence:  start_ êtes-vous êtes-vous ? _end
# Original Sentence ['start_ es-tu jalouse ? _end']
# -
# Input sentence: ["i'll be brief."]
# Decoded sentence:  start_ je vais la _end
# Original Sentence ['start_ je serai bref. _end']
# -
# Input sentence: ["i'm canadian."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis canadien. _end']
# -
# Input sentence: ['can you swim?']
# Decoded sentence:  start_ pouvez-vous marcher ? _end
# Original Sentence ['start_ est-ce que tu sais nager ? _end']
# -
# Input sentence: ["i'm going home."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je rentre chez moi. _end']
# -
# Input sentence: ['keep looking.']
# Decoded sentence:  start_ reste tranquille . _end
# Original Sentence ['start_ continuez à regarder ! _end']
# -
# Input sentence: ['she could die.']
# Decoded sentence:  start_ elle se pourrait pas . _end
# Original Sentence ["start_ il se pourrait qu'elle meure. _end"]
# -
# Input sentence: ['bring him in.']
# Decoded sentence:  start_ prenez la maison . _end
# Original Sentence ['start_ fais-le entrer. _end']
# -
# Input sentence: ["we're ruthless."]
# Decoded sentence:  start_ nous sommes en train de vous . _end
# Original Sentence ['start_ nous sommes impitoyables. _end']
# -
# Input sentence: ['take me home.']
# Decoded sentence:  start_ laissez-moi le maison . _end
# Original Sentence ['start_ amène-moi à la maison. _end']
# -
# Input sentence: ["i'm quiet."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis tranquille. _end']
# -
# Input sentence: ["that's strange."]
# Decoded sentence:  start_ c'est drôle . _end
# Original Sentence ["start_ c'est étrange. _end"]
# -
# Input sentence: ['can i see this?']
# Decoded sentence:  start_ puis-je voir ceci ? _end
# Original Sentence ['start_ puis-je voir ça ? _end']
# -
# Input sentence: ['which is mine?']
# Decoded sentence:  start_ est-ce un ? _end
# Original Sentence ['start_ lequel est le mien ? _end']
# -
# Input sentence: ["that's free."]
# Decoded sentence:  start_ c'est ceci . _end
# Original Sentence ["start_ c'est gratuit. _end"]
# -
# Input sentence: ['this is odd.']
# Decoded sentence:  start_ c'est . _end
# Original Sentence ["start_ c'est bizarre. _end"]
# -
# Input sentence: ['warn tom.']
# Decoded sentence:  start_ tom tom . _end
# Original Sentence ['start_ avertis tom. _end']
# -
# Input sentence: ["you're crazy."]
# Decoded sentence:  start_ vous êtes ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ tu es cinglé. _end']
# -
# Input sentence: ['i trusted you.']
# Decoded sentence:  start_ je vous ai confiance . _end
# Original Sentence ["start_ je t'ai fait confiance. _end"]
# -
# Input sentence: ['i love you all.']
# Decoded sentence:  start_ je vous ai besoin . _end
# Original Sentence ['start_ je vous adore tous. _end']
# -
# Input sentence: ['are you on dope?']
# Decoded sentence:  start_ êtes-vous en train de toi ? _end
# Original Sentence ['start_ êtes-vous droguée ? _end']
# -
# Input sentence: ['i was trapped.']
# Decoded sentence:  start_ j'étais en train de moi . _end
# Original Sentence ["start_ j'ai été piégé. _end"]
# -
# Input sentence: ["tom won't mind."]
# Decoded sentence:  start_ tom ne n'est pas en sécurité . _end
# Original Sentence ['start_ ça ne dérangera pas tom. _end']
# -
# Input sentence: ['back off!']
# Decoded sentence:  start_ arrête de s'il vous yeux . _end
# Original Sentence ['start_ recule\u2009! _end']
# -
# Input sentence: ['tom laughed.']
# Decoded sentence:  start_ tom a de yeux . _end
# Original Sentence ['start_ tom rit. _end']
# -
# Input sentence: ['how nice!']
# Decoded sentence:  start_ comme c'est bizarre ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ c'est du joli ! _end"]
# -
# Input sentence: ['i hate losing.']
# Decoded sentence:  start_ je déteste le déteste . _end
# Original Sentence ['start_ je déteste perdre. _end']
# -
# Input sentence: ['i can hear you.']
# Decoded sentence:  start_ je peux que je vous fait . _end
# Original Sentence ["start_ j'arrive à t'entendre. _end"]
# -
# Input sentence: ["i'm on strike."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis en grève. _end']
# -
# Input sentence: ['take your time.']
# Decoded sentence:  start_ va votre chercher . _end
# Original Sentence ['start_ prenez votre temps. _end']
# -
# Input sentence: ['i had some fun.']
# Decoded sentence:  start_ je me suis senti . _end
# Original Sentence ['start_ je me suis amusé. _end']
# -
# Input sentence: ['he has a video.']
# Decoded sentence:  start_ il a un voiture . _end
# Original Sentence ['start_ il détient une vidéo. _end']
# -
# Input sentence: ['who wants this?']
# Decoded sentence:  start_ qui veut ça ? _end
# Original Sentence ['start_ qui veut ça ? _end']
# -
# Input sentence: ['he seems happy.']
# Decoded sentence:  start_ il est trop malade . _end
# Original Sentence ['start_ il semble heureux. _end']
# -
# Input sentence: ['i will come.']
# Decoded sentence:  start_ je le temps . _end
# Original Sentence ['start_ je viendrai. _end']
# -
# Input sentence: ['prices went up.']
# Decoded sentence:  start_ reste est dans la sécurité . _end
# Original Sentence ['start_ les prix ont augmenté. _end']
# -
# Input sentence: ['turn on the tv.']
# Decoded sentence:  start_ prenez une ici . _end
# Original Sentence ['start_ allume la télé. _end']
# -
# Input sentence: ["i'm voting no."]
# Decoded sentence:  start_ je suis pas à toi . _end
# Original Sentence ['start_ je vote non. _end']
# -
# Input sentence: ['keep driving.']
# Decoded sentence:  start_ reste tranquille . _end
# Original Sentence ['start_ continuez à rouler ! _end']
# -
# Input sentence: ['i volunteered.']
# Decoded sentence:  start_ je l'ai de monde qui suis ! ! ! ! ! !
# Original Sentence ['start_ je me suis portée volontaire. _end']
# -
# Input sentence: ['tom smokes.']
# Decoded sentence:  start_ tom a confiance . _end
# Original Sentence ['start_ tom fume. _end']
# -
# Input sentence: ["i wasn't hired."]
# Decoded sentence:  start_ je ne suis pas en sécurité . _end
# Original Sentence ["start_ on ne m'a pas recrutée. _end"]
# -
# Input sentence: ["it's not mine."]
# Decoded sentence:  start_ ce n'est pas à moi . _end
# Original Sentence ["start_ ce n'est pas la mienne. _end"]
# -
# Input sentence: ['he has a book.']
# Decoded sentence:  start_ il a un il est une . _end
# Original Sentence ["start_ il dispose d'un livre. _end"]
# -
# Input sentence: ["you're no fun."]
# Decoded sentence:  start_ vous êtes si heureux . _end
# Original Sentence ["start_ tu n'es pas drôle. _end"]
# -
# Input sentence: ['i hate winter.']
# Decoded sentence:  start_ je déteste les déteste . _end
# Original Sentence ["start_ je déteste l'hiver. _end"]
# -
# Input sentence: ['who phoned?']
# Decoded sentence:  start_ qui a de la monde qui a ? _end
# Original Sentence ['start_ qui est-ce qui a téléphoné ? _end']
# -
# Input sentence: ['is this art?']
# Decoded sentence:  start_ est-ce de l'amour ? _end
# Original Sentence ["start_ est-ce de l'art\xa0? _end"]
# -
# Input sentence: ['do as he says.']
# Decoded sentence:  start_ ne sois pas là . _end
# Original Sentence ['start_ faites comme il dit. _end']
# -
# Input sentence: ['i felt good.']
# Decoded sentence:  start_ je me suis senti mal . _end
# Original Sentence ['start_ je me sentais bien. _end']
# -
# Input sentence: ["we're not sure."]
# Decoded sentence:  start_ nous ne sommes pas en sécurité . _end
# Original Sentence ["start_ nous n'en sommes pas sûres. _end"]
# -
# Input sentence: ['are you envious?']
# Decoded sentence:  start_ êtes-vous blessé ? _end
# Original Sentence ['start_ êtes-vous envieuses ? _end']
# -
# Input sentence: ["you're grumpy."]
# Decoded sentence:  start_ vous êtes en train de vous . _end
# Original Sentence ['start_ vous êtes grognon. _end']
# -
# Input sentence: ['back off!']
# Decoded sentence:  start_ arrête de s'il vous yeux . _end
# Original Sentence ['start_ reculez. _end']
# -
# Input sentence: ['he lost face.']
# Decoded sentence:  start_ il a fait du temps . _end
# Original Sentence ['start_ il a perdu la face. _end']
# -
# Input sentence: ["i can't eat."]
# Decoded sentence:  start_ je ne peux pas en sécurité . _end
# Original Sentence ['start_ je ne peux pas manger. _end']
# -
# Input sentence: ['look for clues.']
# Decoded sentence:  start_ regarde ça . _end
# Original Sentence ['start_ cherchez des indices. _end']
# -
# Input sentence: ["you're not fat."]
# Decoded sentence:  start_ tu es si . _end
# Original Sentence ["start_ vous n'êtes pas grosses. _end"]
# -
# Input sentence: ["i'll treat you."]
# Decoded sentence:  start_ je vous ai l'air en sécurité . _end
# Original Sentence ['start_ ce sera pour moi. _end']
# -
# Input sentence: ["it's ours."]
# Decoded sentence:  start_ c'est de la mien . _end
# Original Sentence ["start_ c'est le nôtre. _end"]
# -
# Input sentence: ['here he comes.']
# Decoded sentence:  start_ le voici . _end
# Original Sentence ['start_ le voici qui vient. _end']
# -
# Input sentence: ['tom is skiing.']
# Decoded sentence:  start_ tom est en train de travailler . _end
# Original Sentence ['start_ tom skie. _end']
# -
# Input sentence: ['come up here.']
# Decoded sentence:  start_ venez ici ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ approche. _end']
# -
# Input sentence: ['trust no one.']
# Decoded sentence:  start_ personne n'est un mien . _end
# Original Sentence ['start_ ne fais confiance à personne ! _end']
# -
# Input sentence: ['keep tom safe.']
# Decoded sentence:  start_ tom en en sécurité . _end
# Original Sentence ['start_ protège tom. _end']
# -
# Input sentence: ['go to the store.']
# Decoded sentence:  start_ allez au lit ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ rendez-vous au magasin ! _end']
# -
# Input sentence: ["tom's coming."]
# Decoded sentence:  start_ tom est en train de travailler . _end
# Original Sentence ['start_ tom arrive. _end']
# -
# Input sentence: ["i'm not mean."]
# Decoded sentence:  start_ je ne suis pas fait un . _end
# Original Sentence ['start_ je ne suis pas méchante. _end']
# -
# Input sentence: ['find the cat.']
# Decoded sentence:  start_ prends le travail . _end
# Original Sentence ['start_ trouve le chat. _end']
# -
# Input sentence: ["i'm certain."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis sûr. _end']
# -
# Input sentence: ['we lost.']
# Decoded sentence:  start_ nous avons été . _end
# Original Sentence ['start_ nous fûmes défaites. _end']
# -
# Input sentence: ["that's a crime."]
# Decoded sentence:  start_ c'est un est ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ c'est un délit. _end"]
# -
# Input sentence: ["i'm untalented."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis dépourvu de talent. _end']
# -
# Input sentence: ['bring the kids.']
# Decoded sentence:  start_ va ton filles ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ amène les enfants. _end']
# -
# Input sentence: ['i must protest.']
# Decoded sentence:  start_ il me faut des il . _end
# Original Sentence ['start_ il me faut soulever une protestation. _end']
# -
# Input sentence: ['you did it!']
# Decoded sentence:  start_ vous avez vu . _end
# Original Sentence ["start_ c'est vous qui l'avez fait ! _end"]
# -
# Input sentence: ['are you doctors?']
# Decoded sentence:  start_ êtes-vous en train de toi ? _end
# Original Sentence ['start_ êtes-vous médecins ? _end']
# -
# Input sentence: ['i saw you.']
# Decoded sentence:  start_ je vous ai fait . _end
# Original Sentence ['start_ je te vis. _end']
# -
# Input sentence: ['i never win.']
# Decoded sentence:  start_ je me suis fait mal . _end
# Original Sentence ['start_ je ne gagne jamais. _end']
# -
# Input sentence: ['get off of me.']
# Decoded sentence:  start_ laissez-moi chercher ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ lâche-moi. _end']
# -
# Input sentence: ["i'm ambitious."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je suis ambitieux. _end']
# -
# Input sentence: ['i went hiking.']
# Decoded sentence:  start_ je suis en train de travailler . _end
# Original Sentence ['start_ je suis parti en excursion. _end']
# -
# Input sentence: ["i'm a baker."]
# Decoded sentence:  start_ je suis un _end
# Original Sentence ['start_ je suis boulangère. _end']
# -
# Input sentence: ["it's our car."]
# Decoded sentence:  start_ c'est mon fait ! ! ! ! ! ! ! ! !
# Original Sentence ["start_ c'est notre voiture. _end"]
# -
# Input sentence: ["i'm not a fan."]
# Decoded sentence:  start_ je suis un si . _end
# Original Sentence ['start_ je ne fais pas partie de ses admirateurs. _end']
# -
# Input sentence: ["she's a model."]
# Decoded sentence:  start_ c'est un livre . _end
# Original Sentence ['start_ elle est mannequin. _end']
# -
# Input sentence: ['i corrected it.']
# Decoded sentence:  start_ je l'ai vu . _end
# Original Sentence ["start_ je l'ai corrigée. _end"]
# -
# Input sentence: ['i want answers.']
# Decoded sentence:  start_ je veux nous . _end
# Original Sentence ['start_ je veux des réponses. _end']
# -
# Input sentence: ["i'm staying."]
# Decoded sentence:  start_ je suis en train de toi . _end
# Original Sentence ['start_ je reste. _end']
# -
# Input sentence: ["we'll check."]
# Decoded sentence:  start_ nous avons train de toi . _end
# Original Sentence ['start_ nous vérifierons. _end']
# BLEU-1: 0.389593
# BLEU-2: 0.274304
# BLEU-3: 0.168985
# BLEU-4: 0.076661

# %%
#This code I have written to show how the individual predicted sentences blue scores are. I have taken the sentence blue funtion of nltk and shown sentence
#wise. The bleu score is cumulative score.
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.bleu_score import sentence_bleu
actual, predicted, ss = list(), list(),list()
for seq_index in range(10):
    input_seq = encoder_input_data_test[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts_test[seq_index: seq_index + 1])
    print('Decoded sentence:', decoded_sentence)
    print('Original Sentence',target_texts_test[seq_index: seq_index + 1])
    actual.append([nltk.word_tokenize(str(target_texts_test[seq_index: seq_index + 1])[1:-1])])
    predicted.append(nltk.word_tokenize(str(decoded_sentence)))
    a = [nltk.word_tokenize(str(target_texts_test[seq_index: seq_index + 1])[1:-1])]
    b = nltk.word_tokenize(str(decoded_sentence))
    print(a)
    print(b)
    # calculate BLEU score
    print('BLEU-1: %f' % sentence_bleu(a, b, weights=(1.0, 0, 0, 0)))
    print('BLEU-2: %f' % sentence_bleu(a, b, weights=(0.5, 0.5, 0, 0)))
    print('BLEU-3: %f' % sentence_bleu(a, b, weights=(0.3, 0.3, 0.3, 0)))
    print('BLEU-4: %f' % sentence_bleu(a, b, weights=(0.25, 0.25, 0.25, 0.25)))
# Out:
# -
# Input sentence: ["i'll pray hard."]
# Decoded sentence:  start_ je vous ai laissé tomber . _end
# Original Sentence ['start_ je prierai de toutes mes forces. _end']
# [["'start_", 'je', 'prierai', 'de', 'toutes', 'mes', 'forces', '.', '_end', "'"]]
# ['start_', 'je', 'vous', 'ai', 'laissé', 'tomber', '.', '_end']
# BLEU-1: 0.292050
# BLEU-2: 0.180257
# BLEU-3: 0.323673
# BLEU-4: 0.374679
# -
# Input sentence: ['come over!']
# Decoded sentence:  start_ venez ! ! ! ! ! ! ! ! ! ! !
# Original Sentence ['start_ venez\u202f! _end']
# [["'start_", 'venez\\u202f', '!', '_end', "'"]]
# ['start_', 'venez', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!']
# BLEU-1: 0.076923
# BLEU-2: 0.277350
# BLEU-3: 0.463252
# BLEU-4: 0.526640
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# -
# Input sentence: ['we were lucky.']
# Decoded sentence:  start_ nous nous sommes nous sommes . _end
# Original Sentence ['start_ nous étions chanceux. _end']
# [["'start_", 'nous', 'étions', 'chanceux', '.', '_end', "'"]]
# ['start_', 'nous', 'nous', 'sommes', 'nous', 'sommes', '.', '_end']
# BLEU-1: 0.375000
# BLEU-2: 0.231455
# BLEU-3: 0.415604
# BLEU-4: 0.481098
# -
# Input sentence: ["i'm not strong."]
# Decoded sentence:  start_ je ne suis pas un ? _end
# Original Sentence ['start_ je ne suis pas forte. _end']
# [["'start_", 'je', 'ne', 'suis', 'pas', 'forte', '.', '_end', "'"]]
# ['start_', 'je', 'ne', 'suis', 'pas', 'un', '?', '_end']
# BLEU-1: 0.551561
# BLEU-2: 0.456736
# BLEU-3: 0.427511
# BLEU-4: 0.322601
# -
# Input sentence: ["i'm well."]
# Decoded sentence:  start_ je suis en train de travailler . _end
# Original Sentence ['start_ je vais bien. _end']
# [["'start_", 'je', 'vais', 'bien', '.', '_end', "'"]]
# ['start_', 'je', 'suis', 'en', 'train', 'de', 'travailler', '.', '_end']
# BLEU-1: 0.333333
# BLEU-2: 0.204124
# BLEU-3: 0.385422
# BLEU-4: 0.451801
# -
# Input sentence: ["don't fret."]
# Decoded sentence:  start_ ne vous ne pouvons pas pas . _end
# Original Sentence ['start_ te tracasse pas. _end']
# [["'start_", 'te', 'tracasse', 'pas', '.', '_end', "'"]]
# ['start_', 'ne', 'vous', 'ne', 'pouvons', 'pas', 'pas', '.', '_end']
# BLEU-1: 0.333333
# BLEU-2: 0.288675
# BLEU-3: 0.264677
# BLEU-4: 0.330316
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# -
# Input sentence: ["tom'll quit."]
# Decoded sentence:  start_ tom va les chiens . _end
# Original Sentence ['start_ tom va arrêter. _end']
# [["'start_", 'tom', 'va', 'arrêter', '.', '_end', "'"]]
# ['start_', 'tom', 'va', 'les', 'chiens', '.', '_end']
# BLEU-1: 0.571429
# BLEU-2: 0.436436
# BLEU-3: 0.608068
# BLEU-4: 0.660633
# -
# Input sentence: ["i can't go out."]
# Decoded sentence:  start_ je ne peux pas partir . _end
# Original Sentence ['start_ je ne peux pas sortir. _end']
# [["'start_", 'je', 'ne', 'peux', 'pas', 'sortir', '.', '_end', "'"]]
# ['start_', 'je', 'ne', 'peux', 'pas', 'partir', '.', '_end']
# BLEU-1: 0.661873
# BLEU-2: 0.577730
# BLEU-3: 0.492248
# BLEU-4: 0.362824
# -
# Input sentence: ['drive carefully.']
# Decoded sentence:  start_ continuez à nouveau . _end
# Original Sentence ['start_ conduis avec prudence. _end']
# [["'start_", 'conduis', 'avec', 'prudence', '.', '_end', "'"]]
# ['start_', 'continuez', 'à', 'nouveau', '.', '_end']
# BLEU-1: 0.282161
# BLEU-2: 0.218561
# BLEU-3: 0.375656
# BLEU-4: 0.430125
# -
# Input sentence: ["he's a jerk."]
# Decoded sentence:  start_ il est trop une _end
# Original Sentence ["start_ c'est un pauvre type. _end"]
# [['``', 'start_', "c'est", 'un', 'pauvre', 'type', '.', '_end', "''"]]
# ['start_', 'il', 'est', 'trop', 'une', '_end']
# BLEU-1: 0.202177
# BLEU-2: 0.350181
# BLEU-3: 0.436231
# BLEU-4: 0.460864

# %% [markdown]
# **References**
# 1.https://arxiv.org/pdf/1508.04025.pdf
#
# 2.https://machinelearningmastery.com/define-encoder-decoder-sequence-sequence-model-neural-machine-translation-keras/
#
# 3.https://medium.com/@dev.elect.iitd/neural-machine-translation-using-word-level-seq2seq-model-47538cba8cd7
#
# 4.https://blog.keras.io/using-pre-trained-word-embeddings-in-a-keras-model.html
#
# 5.Lab 5 and Lab 7 from the lectures
#
# 6.https://machinelearningmastery.com/calculate-bleu-score-for-text-python/
#
# 7.https://machinelearningmastery.com/develop-neural-machine-translation-system-keras/
#
# 8.https://wanasit.github.io/attention-based-sequence-to-sequence-in-keras.html
